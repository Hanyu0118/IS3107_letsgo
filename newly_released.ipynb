# %% [markdown]
# # Extract New Releases
# - input json file
# - output albums (json), extract_date_album (date)

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials

# %%
credentials = json.load(open('authorization.json'))
client_id = credentials['client_id']
client_secret = credentials['client_secret']
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp

# %%
albums = sp.new_releases()['albums']['items']

# %%
albums
# Out:
# [{'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/164Uj4eKjl6zTBKfJLFKKK'},
#     'href': 'https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK',
#     'id': '164Uj4eKjl6zTBKfJLFKKK',
#     'name': 'JVKE',
#     'type': 'artist',
#     'uri': 'spotify:artist:164Uj4eKjl6zTBKfJLFKKK'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4fU1IAiidcbKjProAZuoLF'},
#   'href': 'https://api.spotify.com/v1/albums/4fU1IAiidcbKjProAZuoLF',
#   'id': '4fU1IAiidcbKjProAZuoLF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739a087af6a3bf8fa7d5db50e2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029a087af6a3bf8fa7d5db50e2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519a087af6a3bf8fa7d5db50e2',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'this is what losing someone feels like',
#   'release_date': '2023-03-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4fU1IAiidcbKjProAZuoLF'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oLeXFyACqeem2VImYeBFe'},
#     'href': 'https://api.spotify.com/v1/artists/4oLeXFyACqeem2VImYeBFe',
#     'id': '4oLeXFyACqeem2VImYeBFe',
#     'name': 'Fred again..',
#     'type': 'artist',
#     'uri': 'spotify:artist:4oLeXFyACqeem2VImYeBFe'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5he5w2lnU9x7JFhnwcekXX'},
#     'href': 'https://api.spotify.com/v1/artists/5he5w2lnU9x7JFhnwcekXX',
#     'id': '5he5w2lnU9x7JFhnwcekXX',
#     'name': 'Skrillex',
#     'type': 'artist',
#     'uri': 'spotify:artist:5he5w2lnU9x7JFhnwcekXX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Eu1txygG6nJttLHbZdQOh'},
#     'href': 'https://api.spotify.com/v1/artists/7Eu1txygG6nJttLHbZdQOh',
#     'id': '7Eu1txygG6nJttLHbZdQOh',
#     'name': 'Four Tet',
#     'type': 'artist',
#     'uri': 'spotify:artist:7Eu1txygG6nJttLHbZdQOh'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7J7redEXgOUEsUBXukhkUF'},
#   'href': 'https://api.spotify.com/v1/albums/7J7redEXgOUEsUBXukhkUF',
#   'id': '7J7redEXgOUEsUBXukhkUF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738170b4ad7333efd476380396',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028170b4ad7333efd476380396',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518170b4ad7333efd476380396',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Baby again..',
#   'release_date': '2023-03-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:7J7redEXgOUEsUBXukhkUF'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xq3BK55BJmutN0X7eTyQB'},
#     'href': 'https://api.spotify.com/v1/artists/5xq3BK55BJmutN0X7eTyQB',
#     'id': '5xq3BK55BJmutN0X7eTyQB',
#     'name': 'Jeff Satur',
#     'type': 'artist',
#     'uri': 'spotify:artist:5xq3BK55BJmutN0X7eTyQB'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4sNLO2KeOADZykYBkqclN1'},
#   'href': 'https://api.spotify.com/v1/albums/4sNLO2KeOADZykYBkqclN1',
#   'id': '4sNLO2KeOADZykYBkqclN1',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735b27a956e0a5862b4b3f7606',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025b27a956e0a5862b4b3f7606',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515b27a956e0a5862b4b3f7606',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Dum Dum',
#   'release_date': '2023-03-16',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'type': 'album',
#   'uri': 'spotify:album:4sNLO2KeOADZykYBkqclN1'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#     'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#     'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#     'name': 'Unknown Mortal Orchestra',
#     'type': 'artist',
#     'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1epwNzmWdqkBQQZpTa8KJD'},
#   'href': 'https://api.spotify.com/v1/albums/1epwNzmWdqkBQQZpTa8KJD',
#   'id': '1epwNzmWdqkBQQZpTa8KJD',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331b65d25e03fc22dfe5c66e5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231b65d25e03fc22dfe5c66e5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131b65d25e03fc22dfe5c66e5',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'V',
#   'release_date': '2023-03-17',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:1epwNzmWdqkBQQZpTa8KJD'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LlIWfvgWlDBXfxCvCFbuC'},
#     'href': 'https://api.spotify.com/v1/artists/7LlIWfvgWlDBXfxCvCFbuC',
#     'id': '7LlIWfvgWlDBXfxCvCFbuC',
#     'name': 'Eloise',
#     'type': 'artist',
#     'uri': 'spotify:artist:7LlIWfvgWlDBXfxCvCFbuC'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/18R7VI3JvO7576xdNNA4ni'},
#   'href': 'https://api.spotify.com/v1/albums/18R7VI3JvO7576xdNNA4ni',
#   'id': '18R7VI3JvO7576xdNNA4ni',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273897321d3ba574b09133769a6',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02897321d3ba574b09133769a6',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851897321d3ba574b09133769a6',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Therapist',
#   'release_date': '2023-03-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:18R7VI3JvO7576xdNNA4ni'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3FduEXHFSq8Hboekc8JMUR'},
#     'href': 'https://api.spotify.com/v1/artists/3FduEXHFSq8Hboekc8JMUR',
#     'id': '3FduEXHFSq8Hboekc8JMUR',
#     'name': 'Rayi Putra',
#     'type': 'artist',
#     'uri': 'spotify:artist:3FduEXHFSq8Hboekc8JMUR'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6VplqV6Wwip189eiaaDsq5'},
#   'href': 'https://api.spotify.com/v1/albums/6VplqV6Wwip189eiaaDsq5',
#   'id': '6VplqV6Wwip189eiaaDsq5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273ac90cfdeaa9c92b503d5e088',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02ac90cfdeaa9c92b503d5e088',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851ac90cfdeaa9c92b503d5e088',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Let You Down',
#   'release_date': '2023-03-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:6VplqV6Wwip189eiaaDsq5'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DZtdN4x13Amjw87cjdffb'},
#     'href': 'https://api.spotify.com/v1/artists/7DZtdN4x13Amjw87cjdffb',
#     'id': '7DZtdN4x13Amjw87cjdffb',
#     'name': '壞特 ?te',
#     'type': 'artist',
#     'uri': 'spotify:artist:7DZtdN4x13Amjw87cjdffb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/75b0z5Ptfy9aPPva87UFgS'},
#   'href': 'https://api.spotify.com/v1/albums/75b0z5Ptfy9aPPva87UFgS',
#   'id': '75b0z5Ptfy9aPPva87UFgS',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273ab8c293177e93bfb6ad5e33e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02ab8c293177e93bfb6ad5e33e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851ab8c293177e93bfb6ad5e33e',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Finally',
#   'release_date': '2023-03-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:75b0z5Ptfy9aPPva87UFgS'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6B9YF4eOv99klogeZUzkYM'},
#     'href': 'https://api.spotify.com/v1/artists/6B9YF4eOv99klogeZUzkYM',
#     'id': '6B9YF4eOv99klogeZUzkYM',
#     'name': 'Mirror',
#     'type': 'artist',
#     'uri': 'spotify:artist:6B9YF4eOv99klogeZUzkYM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7vawAmxGohhTYN53lzenQW'},
#   'href': 'https://api.spotify.com/v1/albums/7vawAmxGohhTYN53lzenQW',
#   'id': '7vawAmxGohhTYN53lzenQW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b521bea1923f57d4a5b6cada',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b521bea1923f57d4a5b6cada',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b521bea1923f57d4a5b6cada',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Rumours',
#   'release_date': '2023-03-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:7vawAmxGohhTYN53lzenQW'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#     'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#     'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#     'name': 'Tiësto',
#     'type': 'artist',
#     'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1cQUgdn5goiU3fbKc3aykV'},
#   'href': 'https://api.spotify.com/v1/albums/1cQUgdn5goiU3fbKc3aykV',
#   'id': '1cQUgdn5goiU3fbKc3aykV',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737d1c5ab158ea3e9a893cf96a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027d1c5ab158ea3e9a893cf96a',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517d1c5ab158ea3e9a893cf96a',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'All Nighter',
#   'release_date': '2023-03-09',
#   'release_date_precision': 'day',
#   'total_tracks': 7,
#   'type': 'album',
#   'uri': 'spotify:album:1cQUgdn5goiU3fbKc3aykV'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sOVNhUf8T3jiPhvFA6T7L'},
#     'href': 'https://api.spotify.com/v1/artists/5sOVNhUf8T3jiPhvFA6T7L',
#     'id': '5sOVNhUf8T3jiPhvFA6T7L',
#     'name': 'Kit Chan',
#     'type': 'artist',
#     'uri': 'spotify:artist:5sOVNhUf8T3jiPhvFA6T7L'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6GfnRKxq84fLBcAsKPddIP'},
#   'href': 'https://api.spotify.com/v1/albums/6GfnRKxq84fLBcAsKPddIP',
#   'id': '6GfnRKxq84fLBcAsKPddIP',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273a16808c9e4061e091dd04e22',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02a16808c9e4061e091dd04e22',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851a16808c9e4061e091dd04e22',
#     'width': 64}],
#   'is_playable': True,
#   'name': '想像空間 2011 Live 精選',
#   'release_date': '2023-03-10',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:6GfnRKxq84fLBcAsKPddIP'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#     'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#     'id': '7CajNmpbOovFoOoasH2HaY',
#     'name': 'Calvin Harris',
#     'type': 'artist',
#     'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0X2BH1fck6amBIoJhDVmmJ'},
#     'href': 'https://api.spotify.com/v1/artists/0X2BH1fck6amBIoJhDVmmJ',
#     'id': '0X2BH1fck6amBIoJhDVmmJ',
#     'name': 'Ellie Goulding',
#     'type': 'artist',
#     'uri': 'spotify:artist:0X2BH1fck6amBIoJhDVmmJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/22UyygZceCIfoE0RhENgKx'},
#   'href': 'https://api.spotify.com/v1/albums/22UyygZceCIfoE0RhENgKx',
#   'id': '22UyygZceCIfoE0RhENgKx',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c58e22815048f8dfb1aa8bd0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c58e22815048f8dfb1aa8bd0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c58e22815048f8dfb1aa8bd0',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Miracle (with Ellie Goulding)',
#   'release_date': '2023-03-10',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:22UyygZceCIfoE0RhENgKx'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6cEuCEZu7PAE9ZSzLLc2oQ'},
#     'href': 'https://api.spotify.com/v1/artists/6cEuCEZu7PAE9ZSzLLc2oQ',
#     'id': '6cEuCEZu7PAE9ZSzLLc2oQ',
#     'name': 'R3HAB',
#     'type': 'artist',
#     'uri': 'spotify:artist:6cEuCEZu7PAE9ZSzLLc2oQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1dXQpSjXcTO288b5D5IIE6'},
#     'href': 'https://api.spotify.com/v1/artists/1dXQpSjXcTO288b5D5IIE6',
#     'id': '1dXQpSjXcTO288b5D5IIE6',
#     'name': 'Now United',
#     'type': 'artist',
#     'uri': 'spotify:artist:1dXQpSjXcTO288b5D5IIE6'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0hxfJ0C3ggfGV0OmszUMOV'},
#   'href': 'https://api.spotify.com/v1/albums/0hxfJ0C3ggfGV0OmszUMOV',
#   'id': '0hxfJ0C3ggfGV0OmszUMOV',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d090d3159f3aea2d41dae15b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d090d3159f3aea2d41dae15b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d090d3159f3aea2d41dae15b',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Run Till Dark (with Now United)',
#   'release_date': '2023-03-10',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:0hxfJ0C3ggfGV0OmszUMOV'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ChF3i92IPZHduM7jN3dpg'},
#     'href': 'https://api.spotify.com/v1/artists/5ChF3i92IPZHduM7jN3dpg',
#     'id': '5ChF3i92IPZHduM7jN3dpg',
#     'name': 'Nicky Romero',
#     'type': 'artist',
#     'uri': 'spotify:artist:5ChF3i92IPZHduM7jN3dpg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0awl5piYwO0CDTHEkCjUhn'},
#     'href': 'https://api.spotify.com/v1/artists/0awl5piYwO0CDTHEkCjUhn',
#     'id': '0awl5piYwO0CDTHEkCjUhn',
#     'name': 'Nico & Vinz',
#     'type': 'artist',
#     'uri': 'spotify:artist:0awl5piYwO0CDTHEkCjUhn'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2iGZU0LNQmhZ5QbRDmCNZz'},
#   'href': 'https://api.spotify.com/v1/albums/2iGZU0LNQmhZ5QbRDmCNZz',
#   'id': '2iGZU0LNQmhZ5QbRDmCNZz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273655ea5cb4b4c30133390c1ed',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02655ea5cb4b4c30133390c1ed',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851655ea5cb4b4c30133390c1ed',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Forever',
#   'release_date': '2023-03-10',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'type': 'album',
#   'uri': 'spotify:album:2iGZU0LNQmhZ5QbRDmCNZz'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DjZI46mVZZZYmmmygRnTw'},
#     'href': 'https://api.spotify.com/v1/artists/1DjZI46mVZZZYmmmygRnTw',
#     'id': '1DjZI46mVZZZYmmmygRnTw',
#     'name': 'Reality Club',
#     'type': 'artist',
#     'uri': 'spotify:artist:1DjZI46mVZZZYmmmygRnTw'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/558sXmfEy2ay0wCIg6BFKG'},
#   'href': 'https://api.spotify.com/v1/albums/558sXmfEy2ay0wCIg6BFKG',
#   'id': '558sXmfEy2ay0wCIg6BFKG',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27338fc8bab044f7c9e3470e842',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0238fc8bab044f7c9e3470e842',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485138fc8bab044f7c9e3470e842',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Desire',
#   'release_date': '2023-03-10',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'type': 'album',
#   'uri': 'spotify:album:558sXmfEy2ay0wCIg6BFKG'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HvKzBgj4yphQfBJjBJrhL'},
#     'href': 'https://api.spotify.com/v1/artists/5HvKzBgj4yphQfBJjBJrhL',
#     'id': '5HvKzBgj4yphQfBJjBJrhL',
#     'name': 'Alice Longyu Gao',
#     'type': 'artist',
#     'uri': 'spotify:artist:5HvKzBgj4yphQfBJjBJrhL'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5YjuPPmMZy5VGjlesAPbHG'},
#   'href': 'https://api.spotify.com/v1/albums/5YjuPPmMZy5VGjlesAPbHG',
#   'id': '5YjuPPmMZy5VGjlesAPbHG',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27340786b94acc0a827543464d3',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0240786b94acc0a827543464d3',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485140786b94acc0a827543464d3',
#     'width': 64}],
#   'is_playable': True,
#   'name': "Let's Hope Heteros Fail, Learn and Retire",
#   'release_date': '2023-03-09',
#   'release_date_precision': 'day',
#   'total_tracks': 8,
#   'type': 'album',
#   'uri': 'spotify:album:5YjuPPmMZy5VGjlesAPbHG'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YFBqMMiIIL4XyiEwqySUQ'},
#     'href': 'https://api.spotify.com/v1/artists/2YFBqMMiIIL4XyiEwqySUQ',
#     'id': '2YFBqMMiIIL4XyiEwqySUQ',
#     'name': 'Protomartyr',
#     'type': 'artist',
#     'uri': 'spotify:artist:2YFBqMMiIIL4XyiEwqySUQ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/12nD6G0SKG9fB4SvWvOOEm'},
#   'href': 'https://api.spotify.com/v1/albums/12nD6G0SKG9fB4SvWvOOEm',
#   'id': '12nD6G0SKG9fB4SvWvOOEm',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273622164b60168bae3a93bcf16',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02622164b60168bae3a93bcf16',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851622164b60168bae3a93bcf16',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Make Way',
#   'release_date': '2023-03-07',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:12nD6G0SKG9fB4SvWvOOEm'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73jBynjsVtofjRpdpRAJGk'},
#     'href': 'https://api.spotify.com/v1/artists/73jBynjsVtofjRpdpRAJGk',
#     'id': '73jBynjsVtofjRpdpRAJGk',
#     'name': 'Dimitri Vegas & Like Mike',
#     'type': 'artist',
#     'uri': 'spotify:artist:73jBynjsVtofjRpdpRAJGk'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#     'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#     'id': '21E3waRsmPlU7jZsS13rcj',
#     'name': 'Ne-Yo',
#     'type': 'artist',
#     'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xSx2FM8mQnrfgM1QsHniB'},
#     'href': 'https://api.spotify.com/v1/artists/5xSx2FM8mQnrfgM1QsHniB',
#     'id': '5xSx2FM8mQnrfgM1QsHniB',
#     'name': 'Danna Paola',
#     'type': 'artist',
#     'uri': 'spotify:artist:5xSx2FM8mQnrfgM1QsHniB'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6dn1PltXAnQZB5i5jJoeN6'},
#   'href': 'https://api.spotify.com/v1/albums/6dn1PltXAnQZB5i5jJoeN6',
#   'id': '6dn1PltXAnQZB5i5jJoeN6',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273739c17c3d6a944de9d09b07d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02739c17c3d6a944de9d09b07d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851739c17c3d6a944de9d09b07d',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Mexico',
#   'release_date': '2023-03-03',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:6dn1PltXAnQZB5i5jJoeN6'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77AiFEVeAVj2ORpC85QVJs'},
#     'href': 'https://api.spotify.com/v1/artists/77AiFEVeAVj2ORpC85QVJs',
#     'id': '77AiFEVeAVj2ORpC85QVJs',
#     'name': 'Steve Aoki',
#     'type': 'artist',
#     'uri': 'spotify:artist:77AiFEVeAVj2ORpC85QVJs'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4sTQVOfp9vEMCemLw50sbu'},
#     'href': 'https://api.spotify.com/v1/artists/4sTQVOfp9vEMCemLw50sbu',
#     'id': '4sTQVOfp9vEMCemLw50sbu',
#     'name': 'Galantis',
#     'type': 'artist',
#     'uri': 'spotify:artist:4sTQVOfp9vEMCemLw50sbu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3LjhVl7GzYsza1biQjTpaN'},
#     'href': 'https://api.spotify.com/v1/artists/3LjhVl7GzYsza1biQjTpaN',
#     'id': '3LjhVl7GzYsza1biQjTpaN',
#     'name': 'Hayley Kiyoko',
#     'type': 'artist',
#     'uri': 'spotify:artist:3LjhVl7GzYsza1biQjTpaN'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6aRMTwvizxU03QnudEZ8Hu'},
#   'href': 'https://api.spotify.com/v1/albums/6aRMTwvizxU03QnudEZ8Hu',
#   'id': '6aRMTwvizxU03QnudEZ8Hu',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27366f3a10e6d0696289325abd1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0266f3a10e6d0696289325abd1',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485166f3a10e6d0696289325abd1',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Hungry Heart ft. Hayley Kiyoko',
#   'release_date': '2023-03-03',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'type': 'album',
#   'uri': 'spotify:album:6aRMTwvizxU03QnudEZ8Hu'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#     'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#     'id': '1IueXOQyABrMOprrzwQJWN',
#     'name': 'Sigala',
#     'type': 'artist',
#     'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1BEUkE2CSUgHTLSBMZdnFB'},
#     'href': 'https://api.spotify.com/v1/artists/1BEUkE2CSUgHTLSBMZdnFB',
#     'id': '1BEUkE2CSUgHTLSBMZdnFB',
#     'name': 'Mae Muller',
#     'type': 'artist',
#     'uri': 'spotify:artist:1BEUkE2CSUgHTLSBMZdnFB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dJCdUO0l0K2WXzrzjYpmC'},
#     'href': 'https://api.spotify.com/v1/artists/7dJCdUO0l0K2WXzrzjYpmC',
#     'id': '7dJCdUO0l0K2WXzrzjYpmC',
#     'name': 'Caity Baser',
#     'type': 'artist',
#     'uri': 'spotify:artist:7dJCdUO0l0K2WXzrzjYpmC'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/74tuwcpsRBZgjtQxja5vVb'},
#   'href': 'https://api.spotify.com/v1/albums/74tuwcpsRBZgjtQxja5vVb',
#   'id': '74tuwcpsRBZgjtQxja5vVb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331613cee58c7288f3b366007',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231613cee58c7288f3b366007',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131613cee58c7288f3b366007',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Feels This Good',
#   'release_date': '2023-03-03',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:74tuwcpsRBZgjtQxja5vVb'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2V431yZGG08uroH2CZAgur'},
#     'href': 'https://api.spotify.com/v1/artists/2V431yZGG08uroH2CZAgur',
#     'id': '2V431yZGG08uroH2CZAgur',
#     'name': 'Sarah de Warren',
#     'type': 'artist',
#     'uri': 'spotify:artist:2V431yZGG08uroH2CZAgur'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5B4kCOhcqTywB9YwXPfFtJ'},
#     'href': 'https://api.spotify.com/v1/artists/5B4kCOhcqTywB9YwXPfFtJ',
#     'id': '5B4kCOhcqTywB9YwXPfFtJ',
#     'name': 'Weird Genius',
#     'type': 'artist',
#     'uri': 'spotify:artist:5B4kCOhcqTywB9YwXPfFtJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/31hnvDgjFArB8Xbntl48ou'},
#   'href': 'https://api.spotify.com/v1/albums/31hnvDgjFArB8Xbntl48ou',
#   'id': '31hnvDgjFArB8Xbntl48ou',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273cde01dcbec122210cfa7ca40',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02cde01dcbec122210cfa7ca40',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851cde01dcbec122210cfa7ca40',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Sugar',
#   'release_date': '2023-02-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:31hnvDgjFArB8Xbntl48ou'}]

# %%
extract_date_album = date.today()

# %% [markdown]
# # Clean New Albums
# - input albums(json), extract_date_album (date)
# - output clean_albums (df)

# %%
import pandas as pd
from datetime import date

# %%
artists_id = [] # further division
available_markets = []
id = []
name = []
release_date = []
release_date_precision = []
total_tracks = []
# popularity = []

# %%
for i, album in enumerate(albums):
    available_markets.append(len(album['available_markets']))
    id.append(album['id'])
    name.append(album['name'])
    release_date.append(album['release_date'])
    release_date_precision.append(album['release_date_precision'])
    total_tracks.append(album['total_tracks'])
    
    aids = []
    for i, artist in enumerate(album['artists']):
        aids.append(artist['id'])
    artists_id.append(aids)

# %%
clean_albums = pd.DataFrame({
    'id': id,
    'name': name,
    'total_tracks': total_tracks,
    'available_markets': available_markets,
    'release_date': release_date,
    'release_date_precision': release_date_precision,
    'artists_id': artists_id
})
clean_albums['extract_date'] = extract_date_album
clean_albums
# Out:
#                         id                                       name  \
# 0   4fU1IAiidcbKjProAZuoLF     this is what losing someone feels like
# 1   7J7redEXgOUEsUBXukhkUF                               Baby again..
# 2   4sNLO2KeOADZykYBkqclN1                                    Dum Dum
# 3   1epwNzmWdqkBQQZpTa8KJD                                          V
# 4   18R7VI3JvO7576xdNNA4ni                                  Therapist
# 5   6VplqV6Wwip189eiaaDsq5                               Let You Down
# 6   75b0z5Ptfy9aPPva87UFgS                                    Finally
# 7   7vawAmxGohhTYN53lzenQW                                    Rumours
# 8   1cQUgdn5goiU3fbKc3aykV                                All Nighter
# 9   6GfnRKxq84fLBcAsKPddIP                          想像空間 2011 Live 精選
# 10  22UyygZceCIfoE0RhENgKx              Miracle (with Ellie Goulding)
# 11  0hxfJ0C3ggfGV0OmszUMOV            Run Till Dark (with Now United)
# 12  2iGZU0LNQmhZ5QbRDmCNZz                                    Forever
# 13  558sXmfEy2ay0wCIg6BFKG                                     Desire
# 14  5YjuPPmMZy5VGjlesAPbHG  Let's Hope Heteros Fail, Learn and Retire
# 15  12nD6G0SKG9fB4SvWvOOEm                                   Make Way
# 16  6dn1PltXAnQZB5i5jJoeN6                                     Mexico
# 17  6aRMTwvizxU03QnudEZ8Hu             Hungry Heart ft. Hayley Kiyoko
# 18  74tuwcpsRBZgjtQxja5vVb                            Feels This Good
# 19  31hnvDgjFArB8Xbntl48ou                                      Sugar
#
#     total_tracks  available_markets release_date release_date_precision  \
# 0              1                181   2023-03-17                    day
# 1              1                183   2023-03-17                    day
# 2              2                183   2023-03-16                    day
# 3             14                184   2023-03-17                    day
# 4              1                184   2023-03-15                    day
# 5              1                183   2023-03-17                    day
# 6              1                184   2023-03-17                    day
# 7              1                184   2023-03-17                    day
# 8              7                183   2023-03-09                    day
# 9             11                184   2023-03-10                    day
# 10             1                184   2023-03-10                    day
# 11             1                184   2023-03-10                    day
# 12             2                183   2023-03-10                    day
# 13             2                183   2023-03-10                    day
# 14             8                184   2023-03-09                    day
# 15             1                183   2023-03-07                    day
# 16             1                181   2023-03-03                    day
# 17             2                184   2023-03-03                    day
# 18             1                184   2023-03-03                    day
# 19             1                184   2023-02-28                    day
#
#                                            artists_id extract_date
# 0                            [164Uj4eKjl6zTBKfJLFKKK]   2023-03-22
# 1   [4oLeXFyACqeem2VImYeBFe, 5he5w2lnU9x7JFhnwcekX...   2023-03-22
# 2                            [5xq3BK55BJmutN0X7eTyQB]   2023-03-22
# 3                            [1LeVJ5GPeYDOVUjxx1y7Rp]   2023-03-22
# 4                            [7LlIWfvgWlDBXfxCvCFbuC]   2023-03-22
# 5                            [3FduEXHFSq8Hboekc8JMUR]   2023-03-22
# 6                            [7DZtdN4x13Amjw87cjdffb]   2023-03-22
# 7                            [6B9YF4eOv99klogeZUzkYM]   2023-03-22
# 8                            [2o5jDhtHVPhrJdv3cEQ99Z]   2023-03-22
# 9                            [5sOVNhUf8T3jiPhvFA6T7L]   2023-03-22
# 10   [7CajNmpbOovFoOoasH2HaY, 0X2BH1fck6amBIoJhDVmmJ]   2023-03-22
# 11   [6cEuCEZu7PAE9ZSzLLc2oQ, 1dXQpSjXcTO288b5D5IIE6]   2023-03-22
# 12   [5ChF3i92IPZHduM7jN3dpg, 0awl5piYwO0CDTHEkCjUhn]   2023-03-22
# 13                           [1DjZI46mVZZZYmmmygRnTw]   2023-03-22
# 14                           [5HvKzBgj4yphQfBJjBJrhL]   2023-03-22
# 15                           [2YFBqMMiIIL4XyiEwqySUQ]   2023-03-22
# 16  [73jBynjsVtofjRpdpRAJGk, 21E3waRsmPlU7jZsS13rc...   2023-03-22
# 17  [77AiFEVeAVj2ORpC85QVJs, 4sTQVOfp9vEMCemLw50sb...   2023-03-22
# 18  [1IueXOQyABrMOprrzwQJWN, 1BEUkE2CSUgHTLSBMZdnF...   2023-03-22
# 19   [2V431yZGG08uroH2CZAgur, 5B4kCOhcqTywB9YwXPfFtJ]   2023-03-22

# %% [markdown]
# # Load New Albums
# - input clean albums (df)
# - load
# - **end**
#
# Should drop artists_id and load

# %% [markdown]
# # Extract New Albums Full Info
# - input clean_albums (df)
# - output albums_full_info (json)

# %%
albums_full_info = sp.albums(clean_albums['id'].tolist())['albums']

# %%
albums_full_info
# Out:
# [{'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/164Uj4eKjl6zTBKfJLFKKK'},
#     'href': 'https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK',
#     'id': '164Uj4eKjl6zTBKfJLFKKK',
#     'name': 'JVKE',
#     'type': 'artist',
#     'uri': 'spotify:artist:164Uj4eKjl6zTBKfJLFKKK'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'copyrights': [{'text': '(C) 2023 JVKE MUSIC LLC under exclusive license to AWAL Recordings America, Inc.',
#     'type': 'C'},
#    {'text': '(P) 2023 JVKE MUSIC LLC under exclusive license to AWAL Recordings America, Inc.',
#     'type': 'P'}],
#   'external_ids': {'upc': '197188326906'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4fU1IAiidcbKjProAZuoLF'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/4fU1IAiidcbKjProAZuoLF',
#   'id': '4fU1IAiidcbKjProAZuoLF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739a087af6a3bf8fa7d5db50e2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029a087af6a3bf8fa7d5db50e2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519a087af6a3bf8fa7d5db50e2',
#     'width': 64}],
#   'label': 'JVKE',
#   'name': 'this is what losing someone feels like',
#   'popularity': 61,
#   'release_date': '2023-03-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/4fU1IAiidcbKjProAZuoLF/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/164Uj4eKjl6zTBKfJLFKKK'},
#        'href': 'https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK',
#        'id': '164Uj4eKjl6zTBKfJLFKKK',
#        'name': 'JVKE',
#        'type': 'artist',
#        'uri': 'spotify:artist:164Uj4eKjl6zTBKfJLFKKK'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 172325,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/38tKvVe3iURKRFm5X50zLZ'},
#      'href': 'https://api.spotify.com/v1/tracks/38tKvVe3iURKRFm5X50zLZ',
#      'id': '38tKvVe3iURKRFm5X50zLZ',
#      'is_local': False,
#      'name': 'this is what losing someone feels like',
#      'preview_url': 'https://p.scdn.co/mp3-preview/ef0a3eac0fdbf9b571712eebca8114f3ceb15864?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:38tKvVe3iURKRFm5X50zLZ'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 1},
#   'type': 'album',
#   'uri': 'spotify:album:4fU1IAiidcbKjProAZuoLF'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oLeXFyACqeem2VImYeBFe'},
#     'href': 'https://api.spotify.com/v1/artists/4oLeXFyACqeem2VImYeBFe',
#     'id': '4oLeXFyACqeem2VImYeBFe',
#     'name': 'Fred again..',
#     'type': 'artist',
#     'uri': 'spotify:artist:4oLeXFyACqeem2VImYeBFe'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5he5w2lnU9x7JFhnwcekXX'},
#     'href': 'https://api.spotify.com/v1/artists/5he5w2lnU9x7JFhnwcekXX',
#     'id': '5he5w2lnU9x7JFhnwcekXX',
#     'name': 'Skrillex',
#     'type': 'artist',
#     'uri': 'spotify:artist:5he5w2lnU9x7JFhnwcekXX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Eu1txygG6nJttLHbZdQOh'},
#     'href': 'https://api.spotify.com/v1/artists/7Eu1txygG6nJttLHbZdQOh',
#     'id': '7Eu1txygG6nJttLHbZdQOh',
#     'name': 'Four Tet',
#     'type': 'artist',
#     'uri': 'spotify:artist:7Eu1txygG6nJttLHbZdQOh'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'copyrights': [{'text': 'Under exclusive licence to Warner Music UK Limited .An Atlantic Records UK release, © 2023 Fred Gibson',
#     'type': 'C'},
#    {'text': 'Under exclusive licence to Warner Music UK Limited .An Atlantic Records UK release., ℗ 2023 Fred Gibson',
#     'type': 'P'}],
#   'external_ids': {'upc': '5054197600371'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7J7redEXgOUEsUBXukhkUF'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/7J7redEXgOUEsUBXukhkUF',
#   'id': '7J7redEXgOUEsUBXukhkUF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738170b4ad7333efd476380396',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028170b4ad7333efd476380396',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518170b4ad7333efd476380396',
#     'width': 64}],
#   'label': 'Atlantic Records UK',
#   'name': 'Baby again..',
#   'popularity': 64,
#   'release_date': '2023-03-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/7J7redEXgOUEsUBXukhkUF/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oLeXFyACqeem2VImYeBFe'},
#        'href': 'https://api.spotify.com/v1/artists/4oLeXFyACqeem2VImYeBFe',
#        'id': '4oLeXFyACqeem2VImYeBFe',
#        'name': 'Fred again..',
#        'type': 'artist',
#        'uri': 'spotify:artist:4oLeXFyACqeem2VImYeBFe'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5he5w2lnU9x7JFhnwcekXX'},
#        'href': 'https://api.spotify.com/v1/artists/5he5w2lnU9x7JFhnwcekXX',
#        'id': '5he5w2lnU9x7JFhnwcekXX',
#        'name': 'Skrillex',
#        'type': 'artist',
#        'uri': 'spotify:artist:5he5w2lnU9x7JFhnwcekXX'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Eu1txygG6nJttLHbZdQOh'},
#        'href': 'https://api.spotify.com/v1/artists/7Eu1txygG6nJttLHbZdQOh',
#        'id': '7Eu1txygG6nJttLHbZdQOh',
#        'name': 'Four Tet',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Eu1txygG6nJttLHbZdQOh'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 319963,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4zlbKky2yA657Sk5rekZoR'},
#      'href': 'https://api.spotify.com/v1/tracks/4zlbKky2yA657Sk5rekZoR',
#      'id': '4zlbKky2yA657Sk5rekZoR',
#      'is_local': False,
#      'name': 'Baby again..',
#      'preview_url': 'https://p.scdn.co/mp3-preview/60108f6eb9102afa78b517b6742a69e56a11e770?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:4zlbKky2yA657Sk5rekZoR'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 1},
#   'type': 'album',
#   'uri': 'spotify:album:7J7redEXgOUEsUBXukhkUF'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xq3BK55BJmutN0X7eTyQB'},
#     'href': 'https://api.spotify.com/v1/artists/5xq3BK55BJmutN0X7eTyQB',
#     'id': '5xq3BK55BJmutN0X7eTyQB',
#     'name': 'Jeff Satur',
#     'type': 'artist',
#     'uri': 'spotify:artist:5xq3BK55BJmutN0X7eTyQB'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'copyrights': [{'text': '© 2023 Wayfer Records', 'type': 'C'},
#    {'text': '℗ 2023 Wayfer Records', 'type': 'P'}],
#   'external_ids': {'upc': '5054197613050'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4sNLO2KeOADZykYBkqclN1'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/4sNLO2KeOADZykYBkqclN1',
#   'id': '4sNLO2KeOADZykYBkqclN1',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735b27a956e0a5862b4b3f7606',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025b27a956e0a5862b4b3f7606',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515b27a956e0a5862b4b3f7606',
#     'width': 64}],
#   'label': 'WM/Thailand',
#   'name': 'Dum Dum',
#   'popularity': 55,
#   'release_date': '2023-03-16',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/4sNLO2KeOADZykYBkqclN1/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xq3BK55BJmutN0X7eTyQB'},
#        'href': 'https://api.spotify.com/v1/artists/5xq3BK55BJmutN0X7eTyQB',
#        'id': '5xq3BK55BJmutN0X7eTyQB',
#        'name': 'Jeff Satur',
#        'type': 'artist',
#        'uri': 'spotify:artist:5xq3BK55BJmutN0X7eTyQB'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 195163,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4XhdM1Ku9JM4abVuRWAsgk'},
#      'href': 'https://api.spotify.com/v1/tracks/4XhdM1Ku9JM4abVuRWAsgk',
#      'id': '4XhdM1Ku9JM4abVuRWAsgk',
#      'is_local': False,
#      'name': 'Dum Dum',
#      'preview_url': 'https://p.scdn.co/mp3-preview/b71992abefa324ef7c1aa84b798216528cc81102?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:4XhdM1Ku9JM4abVuRWAsgk'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xq3BK55BJmutN0X7eTyQB'},
#        'href': 'https://api.spotify.com/v1/artists/5xq3BK55BJmutN0X7eTyQB',
#        'id': '5xq3BK55BJmutN0X7eTyQB',
#        'name': 'Jeff Satur',
#        'type': 'artist',
#        'uri': 'spotify:artist:5xq3BK55BJmutN0X7eTyQB'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 195163,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6McBFhOohQvx0zWkoISnap'},
#      'href': 'https://api.spotify.com/v1/tracks/6McBFhOohQvx0zWkoISnap',
#      'id': '6McBFhOohQvx0zWkoISnap',
#      'is_local': False,
#      'name': 'Dum Dum - English Version',
#      'preview_url': 'https://p.scdn.co/mp3-preview/fbe467b762a791694cae7a6b89900fff1f22d102?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:6McBFhOohQvx0zWkoISnap'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 2},
#   'type': 'album',
#   'uri': 'spotify:album:4sNLO2KeOADZykYBkqclN1'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#     'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#     'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#     'name': 'Unknown Mortal Orchestra',
#     'type': 'artist',
#     'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'copyrights': [{'text': '2023 Jagjaguwar', 'type': 'C'},
#    {'text': '2023 Jagjaguwar', 'type': 'P'}],
#   'external_ids': {'upc': '656605242262'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1epwNzmWdqkBQQZpTa8KJD'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/1epwNzmWdqkBQQZpTa8KJD',
#   'id': '1epwNzmWdqkBQQZpTa8KJD',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331b65d25e03fc22dfe5c66e5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231b65d25e03fc22dfe5c66e5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131b65d25e03fc22dfe5c66e5',
#     'width': 64}],
#   'label': 'Jagjaguwar',
#   'name': 'V',
#   'popularity': 59,
#   'release_date': '2023-03-17',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/1epwNzmWdqkBQQZpTa8KJD/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#        'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#        'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#        'name': 'Unknown Mortal Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 380880,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0xUeLKG6g1vGXSlHDsLKAf'},
#      'href': 'https://api.spotify.com/v1/tracks/0xUeLKG6g1vGXSlHDsLKAf',
#      'id': '0xUeLKG6g1vGXSlHDsLKAf',
#      'is_local': False,
#      'name': 'The Garden',
#      'preview_url': 'https://p.scdn.co/mp3-preview/f2e850217277b86445b5d03c0a21a2af69962057?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0xUeLKG6g1vGXSlHDsLKAf'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#        'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#        'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#        'name': 'Unknown Mortal Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 208720,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1LFaiknfJkpWsPPNjNVKIW'},
#      'href': 'https://api.spotify.com/v1/tracks/1LFaiknfJkpWsPPNjNVKIW',
#      'id': '1LFaiknfJkpWsPPNjNVKIW',
#      'is_local': False,
#      'name': 'Guilty Pleasures',
#      'preview_url': 'https://p.scdn.co/mp3-preview/25fadd62c0c872107731ed8feddd7ddba234865f?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:1LFaiknfJkpWsPPNjNVKIW'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#        'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#        'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#        'name': 'Unknown Mortal Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 277986,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7FpD6W73sZuEEp4dNRCwy9'},
#      'href': 'https://api.spotify.com/v1/tracks/7FpD6W73sZuEEp4dNRCwy9',
#      'id': '7FpD6W73sZuEEp4dNRCwy9',
#      'is_local': False,
#      'name': 'Meshuggah',
#      'preview_url': 'https://p.scdn.co/mp3-preview/7f91bf17e7a6fdabe9ed3b56d839db836362cb0b?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:7FpD6W73sZuEEp4dNRCwy9'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#        'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#        'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#        'name': 'Unknown Mortal Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 310973,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4Kga4UsecRjySf9xj2gQ0I'},
#      'href': 'https://api.spotify.com/v1/tracks/4Kga4UsecRjySf9xj2gQ0I',
#      'id': '4Kga4UsecRjySf9xj2gQ0I',
#      'is_local': False,
#      'name': 'The Widow',
#      'preview_url': 'https://p.scdn.co/mp3-preview/30a4d1402a2ad541646120e59c84637ff842a8cc?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:4Kga4UsecRjySf9xj2gQ0I'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#        'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#        'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#        'name': 'Unknown Mortal Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 244746,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4kgXwktpr7IqnhPo84v6ul'},
#      'href': 'https://api.spotify.com/v1/tracks/4kgXwktpr7IqnhPo84v6ul',
#      'id': '4kgXwktpr7IqnhPo84v6ul',
#      'is_local': False,
#      'name': 'In The Rear View',
#      'preview_url': 'https://p.scdn.co/mp3-preview/754d3c3e29b4ca6cfd35bd611b8c583852236b2a?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:4kgXwktpr7IqnhPo84v6ul'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#        'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#        'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#        'name': 'Unknown Mortal Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 215866,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0M2hckQzSt0AZFytuTC2Hp'},
#      'href': 'https://api.spotify.com/v1/tracks/0M2hckQzSt0AZFytuTC2Hp',
#      'id': '0M2hckQzSt0AZFytuTC2Hp',
#      'is_local': False,
#      'name': 'That Life',
#      'preview_url': 'https://p.scdn.co/mp3-preview/879cbbb368e7851e1089e91aba6477e5323d58e8?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:0M2hckQzSt0AZFytuTC2Hp'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#        'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#        'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#        'name': 'Unknown Mortal Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
# ...
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XC',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 223082,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1XXKon3zGTHj1LCTpwrWXE'},
#      'href': 'https://api.spotify.com/v1/tracks/1XXKon3zGTHj1LCTpwrWXE',
#      'id': '1XXKon3zGTHj1LCTpwrWXE',
#      'is_local': False,
#      'name': 'Hungry Heart ft. Hayley Kiyoko (Steve Aoki Bedroom Mix)',
#      'preview_url': 'https://p.scdn.co/mp3-preview/e35459c2f4dfec0e2be38013b65df57f57dc168a?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:1XXKon3zGTHj1LCTpwrWXE'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 2},
#   'type': 'album',
#   'uri': 'spotify:album:6aRMTwvizxU03QnudEZ8Hu'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#     'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#     'id': '1IueXOQyABrMOprrzwQJWN',
#     'name': 'Sigala',
#     'type': 'artist',
#     'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1BEUkE2CSUgHTLSBMZdnFB'},
#     'href': 'https://api.spotify.com/v1/artists/1BEUkE2CSUgHTLSBMZdnFB',
#     'id': '1BEUkE2CSUgHTLSBMZdnFB',
#     'name': 'Mae Muller',
#     'type': 'artist',
#     'uri': 'spotify:artist:1BEUkE2CSUgHTLSBMZdnFB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dJCdUO0l0K2WXzrzjYpmC'},
#     'href': 'https://api.spotify.com/v1/artists/7dJCdUO0l0K2WXzrzjYpmC',
#     'id': '7dJCdUO0l0K2WXzrzjYpmC',
#     'name': 'Caity Baser',
#     'type': 'artist',
#     'uri': 'spotify:artist:7dJCdUO0l0K2WXzrzjYpmC'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'copyrights': [{'text': '(P) 2023 Ministry of Sound Recordings Ltd./B1 Recordings GmbH. a Sony Music Entertainment Company',
#     'type': 'P'}],
#   'external_ids': {'upc': '196589502469'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/74tuwcpsRBZgjtQxja5vVb'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/74tuwcpsRBZgjtQxja5vVb',
#   'id': '74tuwcpsRBZgjtQxja5vVb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331613cee58c7288f3b366007',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231613cee58c7288f3b366007',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131613cee58c7288f3b366007',
#     'width': 64}],
#   'label': 'Ministry of Sound Recordings',
#   'name': 'Feels This Good',
#   'popularity': 47,
#   'release_date': '2023-03-03',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/74tuwcpsRBZgjtQxja5vVb/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#        'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#        'id': '1IueXOQyABrMOprrzwQJWN',
#        'name': 'Sigala',
#        'type': 'artist',
#        'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1BEUkE2CSUgHTLSBMZdnFB'},
#        'href': 'https://api.spotify.com/v1/artists/1BEUkE2CSUgHTLSBMZdnFB',
#        'id': '1BEUkE2CSUgHTLSBMZdnFB',
#        'name': 'Mae Muller',
#        'type': 'artist',
#        'uri': 'spotify:artist:1BEUkE2CSUgHTLSBMZdnFB'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dJCdUO0l0K2WXzrzjYpmC'},
#        'href': 'https://api.spotify.com/v1/artists/7dJCdUO0l0K2WXzrzjYpmC',
#        'id': '7dJCdUO0l0K2WXzrzjYpmC',
#        'name': 'Caity Baser',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dJCdUO0l0K2WXzrzjYpmC'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ExGrw6XpbtUAJHTLtUXUD'},
#        'href': 'https://api.spotify.com/v1/artists/2ExGrw6XpbtUAJHTLtUXUD',
#        'id': '2ExGrw6XpbtUAJHTLtUXUD',
#        'name': 'Stefflon Don',
#        'type': 'artist',
#        'uri': 'spotify:artist:2ExGrw6XpbtUAJHTLtUXUD'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 190609,
#      'explicit': True,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5JL0aPP9mvMHx0IGXqcI5C'},
#      'href': 'https://api.spotify.com/v1/tracks/5JL0aPP9mvMHx0IGXqcI5C',
#      'id': '5JL0aPP9mvMHx0IGXqcI5C',
#      'is_local': False,
#      'name': 'Feels This Good',
#      'preview_url': 'https://p.scdn.co/mp3-preview/e9513a2859d2ecd0edacf64ffb2d3aa9d01b5fe2?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:5JL0aPP9mvMHx0IGXqcI5C'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 1},
#   'type': 'album',
#   'uri': 'spotify:album:74tuwcpsRBZgjtQxja5vVb'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2V431yZGG08uroH2CZAgur'},
#     'href': 'https://api.spotify.com/v1/artists/2V431yZGG08uroH2CZAgur',
#     'id': '2V431yZGG08uroH2CZAgur',
#     'name': 'Sarah de Warren',
#     'type': 'artist',
#     'uri': 'spotify:artist:2V431yZGG08uroH2CZAgur'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5B4kCOhcqTywB9YwXPfFtJ'},
#     'href': 'https://api.spotify.com/v1/artists/5B4kCOhcqTywB9YwXPfFtJ',
#     'id': '5B4kCOhcqTywB9YwXPfFtJ',
#     'name': 'Weird Genius',
#     'type': 'artist',
#     'uri': 'spotify:artist:5B4kCOhcqTywB9YwXPfFtJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'copyrights': [{'text': '2023 Monstercat', 'type': 'C'},
#    {'text': '2023 Monstercat', 'type': 'P'}],
#   'external_ids': {'upc': '742779547170'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/31hnvDgjFArB8Xbntl48ou'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/31hnvDgjFArB8Xbntl48ou',
#   'id': '31hnvDgjFArB8Xbntl48ou',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273cde01dcbec122210cfa7ca40',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02cde01dcbec122210cfa7ca40',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851cde01dcbec122210cfa7ca40',
#     'width': 64}],
#   'label': 'Monstercat',
#   'name': 'Sugar',
#   'popularity': 34,
#   'release_date': '2023-02-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/31hnvDgjFArB8Xbntl48ou/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2V431yZGG08uroH2CZAgur'},
#        'href': 'https://api.spotify.com/v1/artists/2V431yZGG08uroH2CZAgur',
#        'id': '2V431yZGG08uroH2CZAgur',
#        'name': 'Sarah de Warren',
#        'type': 'artist',
#        'uri': 'spotify:artist:2V431yZGG08uroH2CZAgur'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5B4kCOhcqTywB9YwXPfFtJ'},
#        'href': 'https://api.spotify.com/v1/artists/5B4kCOhcqTywB9YwXPfFtJ',
#        'id': '5B4kCOhcqTywB9YwXPfFtJ',
#        'name': 'Weird Genius',
#        'type': 'artist',
#        'uri': 'spotify:artist:5B4kCOhcqTywB9YwXPfFtJ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XC',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 162519,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0rHT3KSdQn3JvGPwe5EH2Y'},
#      'href': 'https://api.spotify.com/v1/tracks/0rHT3KSdQn3JvGPwe5EH2Y',
#      'id': '0rHT3KSdQn3JvGPwe5EH2Y',
#      'is_local': False,
#      'name': 'Sugar',
#      'preview_url': 'https://p.scdn.co/mp3-preview/7097db0cbda270fd62c29d76d2f66b52115af5ae?cid=70b6029251944c06b7f4b7b9339a8f86',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0rHT3KSdQn3JvGPwe5EH2Y'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 1},
#   'type': 'album',
#   'uri': 'spotify:album:31hnvDgjFArB8Xbntl48ou'}]

# %% [markdown]
# # Get New Track IDs
# - input albums_full_info (json)
# - output new_track_ids (df)

# %%
track_id = []
album_id = []
artists_id = []
for i, album in enumerate(albums_full_info):
    for j, track in enumerate(album['tracks']['items']):
        track_id.append(track['id'])
        album_id.append(album['id'])
        artists_id.append(clean_albums.loc[i,'artists_id'])

# %%
new_track_ids = pd.DataFrame({
    'track_id': track_id,
    'album_id': album_id,
    'artists_id': artists_id
})
new_track_ids.head()
# Out:
#                  track_id                album_id  \
# 0  38tKvVe3iURKRFm5X50zLZ  4fU1IAiidcbKjProAZuoLF
# 1  4zlbKky2yA657Sk5rekZoR  7J7redEXgOUEsUBXukhkUF
# 2  4XhdM1Ku9JM4abVuRWAsgk  4sNLO2KeOADZykYBkqclN1
# 3  6McBFhOohQvx0zWkoISnap  4sNLO2KeOADZykYBkqclN1
# 4  0xUeLKG6g1vGXSlHDsLKAf  1epwNzmWdqkBQQZpTa8KJD
#
#                                           artists_id
# 0                           [164Uj4eKjl6zTBKfJLFKKK]
# 1  [4oLeXFyACqeem2VImYeBFe, 5he5w2lnU9x7JFhnwcekX...
# 2                           [5xq3BK55BJmutN0X7eTyQB]
# 3                           [5xq3BK55BJmutN0X7eTyQB]
# 4                           [1LeVJ5GPeYDOVUjxx1y7Rp]

# %% [markdown]
# # Extract New Track Info
# - input new_track_ids (df)
# - output new_tracks (list of dictionaries) and extract_date_track (date)

# %%
new_tracks = []
for i in range(0, len(new_track_ids), 50):
    new_tracks += sp.tracks(new_track_ids.iloc[i:i+50]['track_id'])['tracks']
new_tracks
# Out:
# [{'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/164Uj4eKjl6zTBKfJLFKKK'},
#      'href': 'https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK',
#      'id': '164Uj4eKjl6zTBKfJLFKKK',
#      'name': 'JVKE',
#      'type': 'artist',
#      'uri': 'spotify:artist:164Uj4eKjl6zTBKfJLFKKK'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4fU1IAiidcbKjProAZuoLF'},
#    'href': 'https://api.spotify.com/v1/albums/4fU1IAiidcbKjProAZuoLF',
#    'id': '4fU1IAiidcbKjProAZuoLF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739a087af6a3bf8fa7d5db50e2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029a087af6a3bf8fa7d5db50e2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519a087af6a3bf8fa7d5db50e2',
#      'width': 64}],
#    'name': 'this is what losing someone feels like',
#    'release_date': '2023-03-17',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:4fU1IAiidcbKjProAZuoLF'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/164Uj4eKjl6zTBKfJLFKKK'},
#     'href': 'https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK',
#     'id': '164Uj4eKjl6zTBKfJLFKKK',
#     'name': 'JVKE',
#     'type': 'artist',
#     'uri': 'spotify:artist:164Uj4eKjl6zTBKfJLFKKK'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 172325,
#   'explicit': False,
#   'external_ids': {'isrc': 'QM4TX2337201'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/38tKvVe3iURKRFm5X50zLZ'},
#   'href': 'https://api.spotify.com/v1/tracks/38tKvVe3iURKRFm5X50zLZ',
#   'id': '38tKvVe3iURKRFm5X50zLZ',
#   'is_local': False,
#   'name': 'this is what losing someone feels like',
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ef0a3eac0fdbf9b571712eebca8114f3ceb15864?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:38tKvVe3iURKRFm5X50zLZ'},
#  {'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oLeXFyACqeem2VImYeBFe'},
#      'href': 'https://api.spotify.com/v1/artists/4oLeXFyACqeem2VImYeBFe',
#      'id': '4oLeXFyACqeem2VImYeBFe',
#      'name': 'Fred again..',
#      'type': 'artist',
#      'uri': 'spotify:artist:4oLeXFyACqeem2VImYeBFe'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5he5w2lnU9x7JFhnwcekXX'},
#      'href': 'https://api.spotify.com/v1/artists/5he5w2lnU9x7JFhnwcekXX',
#      'id': '5he5w2lnU9x7JFhnwcekXX',
#      'name': 'Skrillex',
#      'type': 'artist',
#      'uri': 'spotify:artist:5he5w2lnU9x7JFhnwcekXX'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Eu1txygG6nJttLHbZdQOh'},
#      'href': 'https://api.spotify.com/v1/artists/7Eu1txygG6nJttLHbZdQOh',
#      'id': '7Eu1txygG6nJttLHbZdQOh',
#      'name': 'Four Tet',
#      'type': 'artist',
#      'uri': 'spotify:artist:7Eu1txygG6nJttLHbZdQOh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7J7redEXgOUEsUBXukhkUF'},
#    'href': 'https://api.spotify.com/v1/albums/7J7redEXgOUEsUBXukhkUF',
#    'id': '7J7redEXgOUEsUBXukhkUF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738170b4ad7333efd476380396',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028170b4ad7333efd476380396',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518170b4ad7333efd476380396',
#      'width': 64}],
#    'name': 'Baby again..',
#    'release_date': '2023-03-17',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:7J7redEXgOUEsUBXukhkUF'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oLeXFyACqeem2VImYeBFe'},
#     'href': 'https://api.spotify.com/v1/artists/4oLeXFyACqeem2VImYeBFe',
#     'id': '4oLeXFyACqeem2VImYeBFe',
#     'name': 'Fred again..',
#     'type': 'artist',
#     'uri': 'spotify:artist:4oLeXFyACqeem2VImYeBFe'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5he5w2lnU9x7JFhnwcekXX'},
#     'href': 'https://api.spotify.com/v1/artists/5he5w2lnU9x7JFhnwcekXX',
#     'id': '5he5w2lnU9x7JFhnwcekXX',
#     'name': 'Skrillex',
#     'type': 'artist',
#     'uri': 'spotify:artist:5he5w2lnU9x7JFhnwcekXX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Eu1txygG6nJttLHbZdQOh'},
#     'href': 'https://api.spotify.com/v1/artists/7Eu1txygG6nJttLHbZdQOh',
#     'id': '7Eu1txygG6nJttLHbZdQOh',
#     'name': 'Four Tet',
#     'type': 'artist',
#     'uri': 'spotify:artist:7Eu1txygG6nJttLHbZdQOh'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 319963,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHS2300215'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4zlbKky2yA657Sk5rekZoR'},
#   'href': 'https://api.spotify.com/v1/tracks/4zlbKky2yA657Sk5rekZoR',
#   'id': '4zlbKky2yA657Sk5rekZoR',
#   'is_local': False,
#   'name': 'Baby again..',
#   'popularity': 70,
#   'preview_url': 'https://p.scdn.co/mp3-preview/60108f6eb9102afa78b517b6742a69e56a11e770?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:4zlbKky2yA657Sk5rekZoR'},
#  {'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xq3BK55BJmutN0X7eTyQB'},
#      'href': 'https://api.spotify.com/v1/artists/5xq3BK55BJmutN0X7eTyQB',
#      'id': '5xq3BK55BJmutN0X7eTyQB',
#      'name': 'Jeff Satur',
#      'type': 'artist',
#      'uri': 'spotify:artist:5xq3BK55BJmutN0X7eTyQB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4sNLO2KeOADZykYBkqclN1'},
#    'href': 'https://api.spotify.com/v1/albums/4sNLO2KeOADZykYBkqclN1',
#    'id': '4sNLO2KeOADZykYBkqclN1',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735b27a956e0a5862b4b3f7606',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025b27a956e0a5862b4b3f7606',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515b27a956e0a5862b4b3f7606',
#      'width': 64}],
#    'name': 'Dum Dum',
#    'release_date': '2023-03-16',
#    'release_date_precision': 'day',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:4sNLO2KeOADZykYBkqclN1'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xq3BK55BJmutN0X7eTyQB'},
#     'href': 'https://api.spotify.com/v1/artists/5xq3BK55BJmutN0X7eTyQB',
#     'id': '5xq3BK55BJmutN0X7eTyQB',
#     'name': 'Jeff Satur',
#     'type': 'artist',
#     'uri': 'spotify:artist:5xq3BK55BJmutN0X7eTyQB'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 195163,
#   'explicit': False,
#   'external_ids': {'isrc': 'THW092300607'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4XhdM1Ku9JM4abVuRWAsgk'},
#   'href': 'https://api.spotify.com/v1/tracks/4XhdM1Ku9JM4abVuRWAsgk',
#   'id': '4XhdM1Ku9JM4abVuRWAsgk',
#   'is_local': False,
#   'name': 'Dum Dum',
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/b71992abefa324ef7c1aa84b798216528cc81102?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:4XhdM1Ku9JM4abVuRWAsgk'},
#  {'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xq3BK55BJmutN0X7eTyQB'},
#      'href': 'https://api.spotify.com/v1/artists/5xq3BK55BJmutN0X7eTyQB',
#      'id': '5xq3BK55BJmutN0X7eTyQB',
#      'name': 'Jeff Satur',
#      'type': 'artist',
#      'uri': 'spotify:artist:5xq3BK55BJmutN0X7eTyQB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4sNLO2KeOADZykYBkqclN1'},
#    'href': 'https://api.spotify.com/v1/albums/4sNLO2KeOADZykYBkqclN1',
#    'id': '4sNLO2KeOADZykYBkqclN1',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735b27a956e0a5862b4b3f7606',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025b27a956e0a5862b4b3f7606',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515b27a956e0a5862b4b3f7606',
#      'width': 64}],
#    'name': 'Dum Dum',
#    'release_date': '2023-03-16',
#    'release_date_precision': 'day',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:4sNLO2KeOADZykYBkqclN1'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xq3BK55BJmutN0X7eTyQB'},
#     'href': 'https://api.spotify.com/v1/artists/5xq3BK55BJmutN0X7eTyQB',
#     'id': '5xq3BK55BJmutN0X7eTyQB',
#     'name': 'Jeff Satur',
#     'type': 'artist',
#     'uri': 'spotify:artist:5xq3BK55BJmutN0X7eTyQB'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 195163,
#   'explicit': False,
#   'external_ids': {'isrc': 'THW092300608'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6McBFhOohQvx0zWkoISnap'},
#   'href': 'https://api.spotify.com/v1/tracks/6McBFhOohQvx0zWkoISnap',
#   'id': '6McBFhOohQvx0zWkoISnap',
#   'is_local': False,
#   'name': 'Dum Dum - English Version',
#   'popularity': 54,
#   'preview_url': 'https://p.scdn.co/mp3-preview/fbe467b762a791694cae7a6b89900fff1f22d102?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:6McBFhOohQvx0zWkoISnap'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#      'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#      'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#      'name': 'Unknown Mortal Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1epwNzmWdqkBQQZpTa8KJD'},
#    'href': 'https://api.spotify.com/v1/albums/1epwNzmWdqkBQQZpTa8KJD',
#    'id': '1epwNzmWdqkBQQZpTa8KJD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27331b65d25e03fc22dfe5c66e5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0231b65d25e03fc22dfe5c66e5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485131b65d25e03fc22dfe5c66e5',
#      'width': 64}],
#    'name': 'V',
#    'release_date': '2023-03-17',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:1epwNzmWdqkBQQZpTa8KJD'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#     'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#     'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#     'name': 'Unknown Mortal Orchestra',
#     'type': 'artist',
#     'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 380880,
#   'explicit': False,
#   'external_ids': {'isrc': 'US38Y2242201'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0xUeLKG6g1vGXSlHDsLKAf'},
#   'href': 'https://api.spotify.com/v1/tracks/0xUeLKG6g1vGXSlHDsLKAf',
#   'id': '0xUeLKG6g1vGXSlHDsLKAf',
#   'is_local': False,
#   'name': 'The Garden',
#   'popularity': 50,
#   'preview_url': 'https://p.scdn.co/mp3-preview/f2e850217277b86445b5d03c0a21a2af69962057?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0xUeLKG6g1vGXSlHDsLKAf'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#      'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#      'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#      'name': 'Unknown Mortal Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1epwNzmWdqkBQQZpTa8KJD'},
#    'href': 'https://api.spotify.com/v1/albums/1epwNzmWdqkBQQZpTa8KJD',
#    'id': '1epwNzmWdqkBQQZpTa8KJD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27331b65d25e03fc22dfe5c66e5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0231b65d25e03fc22dfe5c66e5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485131b65d25e03fc22dfe5c66e5',
#      'width': 64}],
#    'name': 'V',
#    'release_date': '2023-03-17',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:1epwNzmWdqkBQQZpTa8KJD'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#     'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#     'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#     'name': 'Unknown Mortal Orchestra',
#     'type': 'artist',
#     'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 208720,
#   'explicit': False,
#   'external_ids': {'isrc': 'US38Y2242202'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1LFaiknfJkpWsPPNjNVKIW'},
#   'href': 'https://api.spotify.com/v1/tracks/1LFaiknfJkpWsPPNjNVKIW',
#   'id': '1LFaiknfJkpWsPPNjNVKIW',
#   'is_local': False,
#   'name': 'Guilty Pleasures',
#   'popularity': 49,
#   'preview_url': 'https://p.scdn.co/mp3-preview/25fadd62c0c872107731ed8feddd7ddba234865f?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1LFaiknfJkpWsPPNjNVKIW'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#      'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#      'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#      'name': 'Unknown Mortal Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1epwNzmWdqkBQQZpTa8KJD'},
#    'href': 'https://api.spotify.com/v1/albums/1epwNzmWdqkBQQZpTa8KJD',
#    'id': '1epwNzmWdqkBQQZpTa8KJD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27331b65d25e03fc22dfe5c66e5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0231b65d25e03fc22dfe5c66e5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485131b65d25e03fc22dfe5c66e5',
#      'width': 64}],
#    'name': 'V',
#    'release_date': '2023-03-17',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:1epwNzmWdqkBQQZpTa8KJD'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#     'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#     'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#     'name': 'Unknown Mortal Orchestra',
#     'type': 'artist',
#     'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 277986,
#   'explicit': False,
#   'external_ids': {'isrc': 'US38Y2242203'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7FpD6W73sZuEEp4dNRCwy9'},
#   'href': 'https://api.spotify.com/v1/tracks/7FpD6W73sZuEEp4dNRCwy9',
#   'id': '7FpD6W73sZuEEp4dNRCwy9',
#   'is_local': False,
#   'name': 'Meshuggah',
#   'popularity': 49,
#   'preview_url': 'https://p.scdn.co/mp3-preview/7f91bf17e7a6fdabe9ed3b56d839db836362cb0b?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:7FpD6W73sZuEEp4dNRCwy9'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#      'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#      'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#      'name': 'Unknown Mortal Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1epwNzmWdqkBQQZpTa8KJD'},
#    'href': 'https://api.spotify.com/v1/albums/1epwNzmWdqkBQQZpTa8KJD',
#    'id': '1epwNzmWdqkBQQZpTa8KJD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27331b65d25e03fc22dfe5c66e5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0231b65d25e03fc22dfe5c66e5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485131b65d25e03fc22dfe5c66e5',
#      'width': 64}],
#    'name': 'V',
#    'release_date': '2023-03-17',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:1epwNzmWdqkBQQZpTa8KJD'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#     'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#     'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#     'name': 'Unknown Mortal Orchestra',
#     'type': 'artist',
#     'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 310973,
#   'explicit': False,
#   'external_ids': {'isrc': 'US38Y2242204'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4Kga4UsecRjySf9xj2gQ0I'},
#   'href': 'https://api.spotify.com/v1/tracks/4Kga4UsecRjySf9xj2gQ0I',
#   'id': '4Kga4UsecRjySf9xj2gQ0I',
#   'is_local': False,
#   'name': 'The Widow',
#   'popularity': 47,
#   'preview_url': 'https://p.scdn.co/mp3-preview/30a4d1402a2ad541646120e59c84637ff842a8cc?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:4Kga4UsecRjySf9xj2gQ0I'},
#  {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LeVJ5GPeYDOVUjxx1y7Rp'},
#      'href': 'https://api.spotify.com/v1/artists/1LeVJ5GPeYDOVUjxx1y7Rp',
#      'id': '1LeVJ5GPeYDOVUjxx1y7Rp',
#      'name': 'Unknown Mortal Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:1LeVJ5GPeYDOVUjxx1y7Rp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
# ...
#     'uri': 'spotify:artist:4sTQVOfp9vEMCemLw50sbu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3LjhVl7GzYsza1biQjTpaN'},
#     'href': 'https://api.spotify.com/v1/artists/3LjhVl7GzYsza1biQjTpaN',
#     'id': '3LjhVl7GzYsza1biQjTpaN',
#     'name': 'Hayley Kiyoko',
#     'type': 'artist',
#     'uri': 'spotify:artist:3LjhVl7GzYsza1biQjTpaN'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XC',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 223082,
#   'explicit': False,
#   'external_ids': {'isrc': 'USA2P2308963'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1XXKon3zGTHj1LCTpwrWXE'},
#   'href': 'https://api.spotify.com/v1/tracks/1XXKon3zGTHj1LCTpwrWXE',
#   'id': '1XXKon3zGTHj1LCTpwrWXE',
#   'is_local': False,
#   'name': 'Hungry Heart ft. Hayley Kiyoko (Steve Aoki Bedroom Mix)',
#   'popularity': 43,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e35459c2f4dfec0e2be38013b65df57f57dc168a?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1XXKon3zGTHj1LCTpwrWXE'},
#  {'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#      'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#      'id': '1IueXOQyABrMOprrzwQJWN',
#      'name': 'Sigala',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1BEUkE2CSUgHTLSBMZdnFB'},
#      'href': 'https://api.spotify.com/v1/artists/1BEUkE2CSUgHTLSBMZdnFB',
#      'id': '1BEUkE2CSUgHTLSBMZdnFB',
#      'name': 'Mae Muller',
#      'type': 'artist',
#      'uri': 'spotify:artist:1BEUkE2CSUgHTLSBMZdnFB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dJCdUO0l0K2WXzrzjYpmC'},
#      'href': 'https://api.spotify.com/v1/artists/7dJCdUO0l0K2WXzrzjYpmC',
#      'id': '7dJCdUO0l0K2WXzrzjYpmC',
#      'name': 'Caity Baser',
#      'type': 'artist',
#      'uri': 'spotify:artist:7dJCdUO0l0K2WXzrzjYpmC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/74tuwcpsRBZgjtQxja5vVb'},
#    'href': 'https://api.spotify.com/v1/albums/74tuwcpsRBZgjtQxja5vVb',
#    'id': '74tuwcpsRBZgjtQxja5vVb',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27331613cee58c7288f3b366007',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0231613cee58c7288f3b366007',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485131613cee58c7288f3b366007',
#      'width': 64}],
#    'name': 'Feels This Good',
#    'release_date': '2023-03-03',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:74tuwcpsRBZgjtQxja5vVb'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IueXOQyABrMOprrzwQJWN'},
#     'href': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN',
#     'id': '1IueXOQyABrMOprrzwQJWN',
#     'name': 'Sigala',
#     'type': 'artist',
#     'uri': 'spotify:artist:1IueXOQyABrMOprrzwQJWN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1BEUkE2CSUgHTLSBMZdnFB'},
#     'href': 'https://api.spotify.com/v1/artists/1BEUkE2CSUgHTLSBMZdnFB',
#     'id': '1BEUkE2CSUgHTLSBMZdnFB',
#     'name': 'Mae Muller',
#     'type': 'artist',
#     'uri': 'spotify:artist:1BEUkE2CSUgHTLSBMZdnFB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dJCdUO0l0K2WXzrzjYpmC'},
#     'href': 'https://api.spotify.com/v1/artists/7dJCdUO0l0K2WXzrzjYpmC',
#     'id': '7dJCdUO0l0K2WXzrzjYpmC',
#     'name': 'Caity Baser',
#     'type': 'artist',
#     'uri': 'spotify:artist:7dJCdUO0l0K2WXzrzjYpmC'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ExGrw6XpbtUAJHTLtUXUD'},
#     'href': 'https://api.spotify.com/v1/artists/2ExGrw6XpbtUAJHTLtUXUD',
#     'id': '2ExGrw6XpbtUAJHTLtUXUD',
#     'name': 'Stefflon Don',
#     'type': 'artist',
#     'uri': 'spotify:artist:2ExGrw6XpbtUAJHTLtUXUD'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 190609,
#   'explicit': True,
#   'external_ids': {'isrc': 'GBCEN2200083'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5JL0aPP9mvMHx0IGXqcI5C'},
#   'href': 'https://api.spotify.com/v1/tracks/5JL0aPP9mvMHx0IGXqcI5C',
#   'id': '5JL0aPP9mvMHx0IGXqcI5C',
#   'is_local': False,
#   'name': 'Feels This Good',
#   'popularity': 53,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e9513a2859d2ecd0edacf64ffb2d3aa9d01b5fe2?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5JL0aPP9mvMHx0IGXqcI5C'},
#  {'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2V431yZGG08uroH2CZAgur'},
#      'href': 'https://api.spotify.com/v1/artists/2V431yZGG08uroH2CZAgur',
#      'id': '2V431yZGG08uroH2CZAgur',
#      'name': 'Sarah de Warren',
#      'type': 'artist',
#      'uri': 'spotify:artist:2V431yZGG08uroH2CZAgur'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5B4kCOhcqTywB9YwXPfFtJ'},
#      'href': 'https://api.spotify.com/v1/artists/5B4kCOhcqTywB9YwXPfFtJ',
#      'id': '5B4kCOhcqTywB9YwXPfFtJ',
#      'name': 'Weird Genius',
#      'type': 'artist',
#      'uri': 'spotify:artist:5B4kCOhcqTywB9YwXPfFtJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/31hnvDgjFArB8Xbntl48ou'},
#    'href': 'https://api.spotify.com/v1/albums/31hnvDgjFArB8Xbntl48ou',
#    'id': '31hnvDgjFArB8Xbntl48ou',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273cde01dcbec122210cfa7ca40',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02cde01dcbec122210cfa7ca40',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851cde01dcbec122210cfa7ca40',
#      'width': 64}],
#    'name': 'Sugar',
#    'release_date': '2023-02-28',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:31hnvDgjFArB8Xbntl48ou'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2V431yZGG08uroH2CZAgur'},
#     'href': 'https://api.spotify.com/v1/artists/2V431yZGG08uroH2CZAgur',
#     'id': '2V431yZGG08uroH2CZAgur',
#     'name': 'Sarah de Warren',
#     'type': 'artist',
#     'uri': 'spotify:artist:2V431yZGG08uroH2CZAgur'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5B4kCOhcqTywB9YwXPfFtJ'},
#     'href': 'https://api.spotify.com/v1/artists/5B4kCOhcqTywB9YwXPfFtJ',
#     'id': '5B4kCOhcqTywB9YwXPfFtJ',
#     'name': 'Weird Genius',
#     'type': 'artist',
#     'uri': 'spotify:artist:5B4kCOhcqTywB9YwXPfFtJ'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XC',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 162519,
#   'explicit': False,
#   'external_ids': {'isrc': 'CA6D22300039'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0rHT3KSdQn3JvGPwe5EH2Y'},
#   'href': 'https://api.spotify.com/v1/tracks/0rHT3KSdQn3JvGPwe5EH2Y',
#   'id': '0rHT3KSdQn3JvGPwe5EH2Y',
#   'is_local': False,
#   'name': 'Sugar',
#   'popularity': 40,
#   'preview_url': 'https://p.scdn.co/mp3-preview/7097db0cbda270fd62c29d76d2f66b52115af5ae?cid=70b6029251944c06b7f4b7b9339a8f86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0rHT3KSdQn3JvGPwe5EH2Y'}]

# %%
extract_date_track = date.today()

# %% [markdown]
# # Clean New Track Info
# - input new_track_ids (df), new_tracks (list of dictionaries), extract_date_track (date)
# - output clean_new_tracks (df)
#
# We need id, name, extract date, popularity, explicit, available markets, (release date should refer to album table)

# %%
id = []
name = []
explicit = []
available_markets = []
popularity = []
album_id = []

for i, track in enumerate(new_tracks):
    id.append(track['id'])
    name.append(track['name'])
    available_markets.append(len(track['available_markets']))
    explicit.append((1 if track['explicit'] else 0))
    popularity.append(track['popularity'])
    album_id.append(new_track_ids.loc[i,'album_id'])

# %%
clean_new_tracks = pd.DataFrame({
    'id': id,
    'name': name,
    'explicit': explicit,
    'available_markets': available_markets,
    'popularity': popularity,
    'album_id': album_id
})
clean_new_tracks['artists_id'] = artists_id
clean_new_tracks['extract_date'] = extract_date_track
clean_new_tracks.head()
# Out:
#                        id                                    name  explicit  \
# 0  38tKvVe3iURKRFm5X50zLZ  this is what losing someone feels like         0
# 1  4zlbKky2yA657Sk5rekZoR                            Baby again..         0
# 2  4XhdM1Ku9JM4abVuRWAsgk                                 Dum Dum         0
# 3  6McBFhOohQvx0zWkoISnap               Dum Dum - English Version         0
# 4  0xUeLKG6g1vGXSlHDsLKAf                              The Garden         0
#
#    available_markets  popularity                album_id  \
# 0                181          67  4fU1IAiidcbKjProAZuoLF
# 1                183          70  7J7redEXgOUEsUBXukhkUF
# 2                183          56  4sNLO2KeOADZykYBkqclN1
# 3                183          54  4sNLO2KeOADZykYBkqclN1
# 4                184          50  1epwNzmWdqkBQQZpTa8KJD
#
#                                           artists_id extract_date
# 0                           [164Uj4eKjl6zTBKfJLFKKK]   2023-03-22
# 1  [4oLeXFyACqeem2VImYeBFe, 5he5w2lnU9x7JFhnwcekX...   2023-03-22
# 2                           [5xq3BK55BJmutN0X7eTyQB]   2023-03-22
# 3                           [5xq3BK55BJmutN0X7eTyQB]   2023-03-22
# 4                           [1LeVJ5GPeYDOVUjxx1y7Rp]   2023-03-22

# %% [markdown]
# # Load New Track Info
# - input clean_new_tracks (df)
# - load
# - end

# %% [markdown]
# # Extract Audio Features
# - input new_track_ids (df)
# - output audio_features (list of dictionaries)

# %%
sp.audio_features(new_track_ids['track_id'].tolist())
# Out:
# [{'danceability': 0.602,
#   'energy': 0.493,
#   'key': 5,
#   'loudness': -5.695,
#   'mode': 1,
#   'speechiness': 0.0443,
#   'acousticness': 0.825,
#   'instrumentalness': 0,
#   'liveness': 0.364,
#   'valence': 0.281,
#   'tempo': 128.577,
#   'type': 'audio_features',
#   'id': '38tKvVe3iURKRFm5X50zLZ',
#   'uri': 'spotify:track:38tKvVe3iURKRFm5X50zLZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/38tKvVe3iURKRFm5X50zLZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/38tKvVe3iURKRFm5X50zLZ',
#   'duration_ms': 172326,
#   'time_signature': 4},
#  {'danceability': 0.847,
#   'energy': 0.724,
#   'key': 2,
#   'loudness': -7.668,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.00355,
#   'instrumentalness': 0.00339,
#   'liveness': 0.0731,
#   'valence': 0.326,
#   'tempo': 126.983,
#   'type': 'audio_features',
#   'id': '4zlbKky2yA657Sk5rekZoR',
#   'uri': 'spotify:track:4zlbKky2yA657Sk5rekZoR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zlbKky2yA657Sk5rekZoR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zlbKky2yA657Sk5rekZoR',
#   'duration_ms': 319964,
#   'time_signature': 4},
#  {'danceability': 0.619,
#   'energy': 0.437,
#   'key': 4,
#   'loudness': -7.623,
#   'mode': 0,
#   'speechiness': 0.0244,
#   'acousticness': 0.449,
#   'instrumentalness': 0.00184,
#   'liveness': 0.292,
#   'valence': 0.536,
#   'tempo': 90.972,
#   'type': 'audio_features',
#   'id': '4XhdM1Ku9JM4abVuRWAsgk',
#   'uri': 'spotify:track:4XhdM1Ku9JM4abVuRWAsgk',
#   'track_href': 'https://api.spotify.com/v1/tracks/4XhdM1Ku9JM4abVuRWAsgk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4XhdM1Ku9JM4abVuRWAsgk',
#   'duration_ms': 195164,
#   'time_signature': 4},
#  {'danceability': 0.613,
#   'energy': 0.443,
#   'key': 4,
#   'loudness': -7.502,
#   'mode': 0,
#   'speechiness': 0.0247,
#   'acousticness': 0.349,
#   'instrumentalness': 0,
#   'liveness': 0.237,
#   'valence': 0.604,
#   'tempo': 91.044,
#   'type': 'audio_features',
#   'id': '6McBFhOohQvx0zWkoISnap',
#   'uri': 'spotify:track:6McBFhOohQvx0zWkoISnap',
#   'track_href': 'https://api.spotify.com/v1/tracks/6McBFhOohQvx0zWkoISnap',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6McBFhOohQvx0zWkoISnap',
#   'duration_ms': 195164,
#   'time_signature': 4},
#  {'danceability': 0.507,
#   'energy': 0.741,
#   'key': 1,
#   'loudness': -4.857,
#   'mode': 1,
#   'speechiness': 0.0648,
#   'acousticness': 0.184,
#   'instrumentalness': 0.0104,
#   'liveness': 0.0916,
#   'valence': 0.257,
#   'tempo': 78.465,
#   'type': 'audio_features',
#   'id': '0xUeLKG6g1vGXSlHDsLKAf',
#   'uri': 'spotify:track:0xUeLKG6g1vGXSlHDsLKAf',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xUeLKG6g1vGXSlHDsLKAf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xUeLKG6g1vGXSlHDsLKAf',
#   'duration_ms': 380880,
#   'time_signature': 4},
#  {'danceability': 0.78,
#   'energy': 0.55,
#   'key': 10,
#   'loudness': -5.486,
#   'mode': 1,
#   'speechiness': 0.0428,
#   'acousticness': 0.522,
#   'instrumentalness': 0.692,
#   'liveness': 0.114,
#   'valence': 0.516,
#   'tempo': 145.033,
#   'type': 'audio_features',
#   'id': '1LFaiknfJkpWsPPNjNVKIW',
#   'uri': 'spotify:track:1LFaiknfJkpWsPPNjNVKIW',
#   'track_href': 'https://api.spotify.com/v1/tracks/1LFaiknfJkpWsPPNjNVKIW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1LFaiknfJkpWsPPNjNVKIW',
#   'duration_ms': 208720,
#   'time_signature': 3},
#  {'danceability': 0.764,
#   'energy': 0.567,
#   'key': 6,
#   'loudness': -7.493,
#   'mode': 1,
#   'speechiness': 0.0577,
#   'acousticness': 0.241,
#   'instrumentalness': 0.369,
#   'liveness': 0.324,
#   'valence': 0.412,
#   'tempo': 122.513,
#   'type': 'audio_features',
#   'id': '7FpD6W73sZuEEp4dNRCwy9',
#   'uri': 'spotify:track:7FpD6W73sZuEEp4dNRCwy9',
#   'track_href': 'https://api.spotify.com/v1/tracks/7FpD6W73sZuEEp4dNRCwy9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7FpD6W73sZuEEp4dNRCwy9',
#   'duration_ms': 277987,
#   'time_signature': 4},
#  {'danceability': 0.826,
#   'energy': 0.559,
#   'key': 1,
#   'loudness': -4.687,
#   'mode': 1,
#   'speechiness': 0.0388,
#   'acousticness': 0.59,
#   'instrumentalness': 0.926,
#   'liveness': 0.0918,
#   'valence': 0.399,
#   'tempo': 89.714,
#   'type': 'audio_features',
#   'id': '4Kga4UsecRjySf9xj2gQ0I',
#   'uri': 'spotify:track:4Kga4UsecRjySf9xj2gQ0I',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Kga4UsecRjySf9xj2gQ0I',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Kga4UsecRjySf9xj2gQ0I',
#   'duration_ms': 310973,
#   'time_signature': 4},
#  {'danceability': 0.723,
#   'energy': 0.593,
#   'key': 1,
#   'loudness': -9.632,
#   'mode': 1,
#   'speechiness': 0.0604,
#   'acousticness': 0.893,
#   'instrumentalness': 0.864,
#   'liveness': 0.119,
#   'valence': 0.304,
#   'tempo': 82.957,
#   'type': 'audio_features',
#   'id': '4kgXwktpr7IqnhPo84v6ul',
#   'uri': 'spotify:track:4kgXwktpr7IqnhPo84v6ul',
#   'track_href': 'https://api.spotify.com/v1/tracks/4kgXwktpr7IqnhPo84v6ul',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4kgXwktpr7IqnhPo84v6ul',
#   'duration_ms': 244747,
#   'time_signature': 4},
#  {'danceability': 0.927,
#   'energy': 0.631,
#   'key': 3,
#   'loudness': -5.245,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.0706,
#   'instrumentalness': 0.00536,
#   'liveness': 0.107,
#   'valence': 0.935,
#   'tempo': 123.316,
#   'type': 'audio_features',
#   'id': '0M2hckQzSt0AZFytuTC2Hp',
#   'uri': 'spotify:track:0M2hckQzSt0AZFytuTC2Hp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0M2hckQzSt0AZFytuTC2Hp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0M2hckQzSt0AZFytuTC2Hp',
#   'duration_ms': 215867,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.741,
#   'key': 8,
#   'loudness': -8.16,
#   'mode': 0,
#   'speechiness': 0.057,
#   'acousticness': 0.341,
#   'instrumentalness': 0.0344,
#   'liveness': 0.11,
#   'valence': 0.621,
#   'tempo': 126.985,
#   'type': 'audio_features',
#   'id': '3VZrMjHeYvUrFGKeG7B62D',
#   'uri': 'spotify:track:3VZrMjHeYvUrFGKeG7B62D',
#   'track_href': 'https://api.spotify.com/v1/tracks/3VZrMjHeYvUrFGKeG7B62D',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3VZrMjHeYvUrFGKeG7B62D',
#   'duration_ms': 250013,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.533,
#   'key': 6,
#   'loudness': -11.148,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.577,
#   'instrumentalness': 0.901,
#   'liveness': 0.0966,
#   'valence': 0.43,
#   'tempo': 139.997,
#   'type': 'audio_features',
#   'id': '2HHAVa6LIF4xGChgZNElpE',
#   'uri': 'spotify:track:2HHAVa6LIF4xGChgZNElpE',
#   'track_href': 'https://api.spotify.com/v1/tracks/2HHAVa6LIF4xGChgZNElpE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HHAVa6LIF4xGChgZNElpE',
#   'duration_ms': 289667,
#   'time_signature': 4},
#  {'danceability': 0.813,
#   'energy': 0.702,
#   'key': 6,
#   'loudness': -5.523,
#   'mode': 0,
#   'speechiness': 0.0366,
#   'acousticness': 0.357,
#   'instrumentalness': 0.376,
#   'liveness': 0.108,
#   'valence': 0.874,
#   'tempo': 124.117,
#   'type': 'audio_features',
#   'id': '7kdSrL0tJ5JMpL4GbvuKDy',
#   'uri': 'spotify:track:7kdSrL0tJ5JMpL4GbvuKDy',
#   'track_href': 'https://api.spotify.com/v1/tracks/7kdSrL0tJ5JMpL4GbvuKDy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7kdSrL0tJ5JMpL4GbvuKDy',
#   'duration_ms': 287520,
#   'time_signature': 4},
#  {'danceability': 0.766,
#   'energy': 0.378,
#   'key': 11,
#   'loudness': -10.54,
#   'mode': 0,
#   'speechiness': 0.101,
#   'acousticness': 0.772,
#   'instrumentalness': 0.886,
#   'liveness': 0.0854,
#   'valence': 0.478,
#   'tempo': 119.777,
#   'type': 'audio_features',
#   'id': '6SW2xr82FISqZtcAjE4Rl9',
#   'uri': 'spotify:track:6SW2xr82FISqZtcAjE4Rl9',
#   'track_href': 'https://api.spotify.com/v1/tracks/6SW2xr82FISqZtcAjE4Rl9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SW2xr82FISqZtcAjE4Rl9',
#   'duration_ms': 197827,
#   'time_signature': 3},
#  {'danceability': 0.833,
#   'energy': 0.362,
#   'key': 10,
#   'loudness': -7.856,
#   'mode': 0,
#   'speechiness': 0.0524,
#   'acousticness': 0.851,
#   'instrumentalness': 0.551,
#   'liveness': 0.105,
#   'valence': 0.598,
#   'tempo': 79.987,
#   'type': 'audio_features',
#   'id': '2AojQfi1k8pgwyg1Ii0Ly8',
#   'uri': 'spotify:track:2AojQfi1k8pgwyg1Ii0Ly8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2AojQfi1k8pgwyg1Ii0Ly8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2AojQfi1k8pgwyg1Ii0Ly8',
#   'duration_ms': 246720,
#   'time_signature': 4},
#  {'danceability': 0.269,
#   'energy': 0.0982,
#   'key': 10,
#   'loudness': -24.922,
#   'mode': 0,
#   'speechiness': 0.0436,
#   'acousticness': 0.945,
#   'instrumentalness': 0.878,
#   'liveness': 0.1,
#   'valence': 0.0492,
#   'tempo': 156.519,
#   'type': 'audio_features',
#   'id': '4daybsVF8kYbFhyjjcSOg0',
#   'uri': 'spotify:track:4daybsVF8kYbFhyjjcSOg0',
#   'track_href': 'https://api.spotify.com/v1/tracks/4daybsVF8kYbFhyjjcSOg0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4daybsVF8kYbFhyjjcSOg0',
#   'duration_ms': 134133,
#   'time_signature': 3},
#  {'danceability': 0.695,
#   'energy': 0.259,
#   'key': 6,
#   'loudness': -14.314,
#   'mode': 1,
#   'speechiness': 0.0572,
#   'acousticness': 0.923,
#   'instrumentalness': 0.00946,
#   'liveness': 0.107,
#   'valence': 0.272,
#   'tempo': 138.683,
#   'type': 'audio_features',
#   'id': '0lsAmBdyQqJz2adVowutMq',
#   'uri': 'spotify:track:0lsAmBdyQqJz2adVowutMq',
#   'track_href': 'https://api.spotify.com/v1/tracks/0lsAmBdyQqJz2adVowutMq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0lsAmBdyQqJz2adVowutMq',
#   'duration_ms': 208760,
#   'time_signature': 4},
#  {'danceability': 0.924,
#   'energy': 0.535,
#   'key': 6,
#   'loudness': -8.625,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.0285,
#   'instrumentalness': 0.821,
#   'liveness': 0.0898,
#   'valence': 0.737,
#   'tempo': 99.931,
#   'type': 'audio_features',
#   'id': '43FJKuRmiFls5gn19ydPa5',
#   'uri': 'spotify:track:43FJKuRmiFls5gn19ydPa5',
#   'track_href': 'https://api.spotify.com/v1/tracks/43FJKuRmiFls5gn19ydPa5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43FJKuRmiFls5gn19ydPa5',
#   'duration_ms': 356520,
#   'time_signature': 4},
#  {'danceability': 0.716,
#   'energy': 0.559,
#   'key': 7,
#   'loudness': -5.773,
#   'mode': 1,
#   'speechiness': 0.0541,
#   'acousticness': 0.26,
#   'instrumentalness': 0.000356,
#   'liveness': 0.0961,
#   'valence': 0.683,
#   'tempo': 132.102,
#   'type': 'audio_features',
#   'id': '4vIYNMhW588JXOlBlEQqrq',
#   'uri': 'spotify:track:4vIYNMhW588JXOlBlEQqrq',
#   'track_href': 'https://api.spotify.com/v1/tracks/4vIYNMhW588JXOlBlEQqrq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vIYNMhW588JXOlBlEQqrq',
#   'duration_ms': 161091,
#   'time_signature': 4},
#  {'danceability': 0.722,
#   'energy': 0.682,
#   'key': 5,
#   'loudness': -6.1,
#   'mode': 0,
#   'speechiness': 0.161,
#   'acousticness': 0.258,
#   'instrumentalness': 0.000397,
#   'liveness': 0.292,
#   'valence': 0.549,
#   'tempo': 90.016,
#   'type': 'audio_features',
#   'id': '6l0iiXFo28AG370kbE1gRE',
#   'uri': 'spotify:track:6l0iiXFo28AG370kbE1gRE',
#   'track_href': 'https://api.spotify.com/v1/tracks/6l0iiXFo28AG370kbE1gRE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6l0iiXFo28AG370kbE1gRE',
#   'duration_ms': 186753,
#   'time_signature': 4},
#  {'danceability': 0.576,
#   'energy': 0.555,
#   'key': 6,
#   'loudness': -12.02,
#   'mode': 1,
#   'speechiness': 0.173,
#   'acousticness': 0.41,
#   'instrumentalness': 7.78e-05,
#   'liveness': 0.289,
#   'valence': 0.366,
#   'tempo': 79.073,
#   'type': 'audio_features',
#   'id': '1XlrLdjGuzv2zspinPwilS',
#   'uri': 'spotify:track:1XlrLdjGuzv2zspinPwilS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1XlrLdjGuzv2zspinPwilS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1XlrLdjGuzv2zspinPwilS',
#   'duration_ms': 185829,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.866,
#   'key': 6,
#   'loudness': -4.461,
#   'mode': 0,
#   'speechiness': 0.0695,
#   'acousticness': 0.136,
#   'instrumentalness': 0,
#   'liveness': 0.0697,
#   'valence': 0.871,
#   'tempo': 166.975,
#   'type': 'audio_features',
#   'id': '19rYI8oRZAdz0gQIQ2yHld',
#   'uri': 'spotify:track:19rYI8oRZAdz0gQIQ2yHld',
#   'track_href': 'https://api.spotify.com/v1/tracks/19rYI8oRZAdz0gQIQ2yHld',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/19rYI8oRZAdz0gQIQ2yHld',
#   'duration_ms': 199935,
#   'time_signature': 4},
#  {'danceability': 0.756,
#   'energy': 0.921,
#   'key': 11,
#   'loudness': -6.196,
#   'mode': 0,
#   'speechiness': 0.0508,
#   'acousticness': 0.0386,
#   'instrumentalness': 0.0546,
#   'liveness': 0.327,
#   'valence': 0.384,
#   'tempo': 124.981,
#   'type': 'audio_features',
#   'id': '7bqg7RANz4RaboN0Ga1Miq',
#   'uri': 'spotify:track:7bqg7RANz4RaboN0Ga1Miq',
#   'track_href': 'https://api.spotify.com/v1/tracks/7bqg7RANz4RaboN0Ga1Miq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7bqg7RANz4RaboN0Ga1Miq',
#   'duration_ms': 134880,
#   'time_signature': 4},
#  {'danceability': 0.696,
#   'energy': 0.793,
#   'key': 8,
#   'loudness': -5.733,
#   'mode': 1,
#   'speechiness': 0.097,
#   'acousticness': 0.0683,
#   'instrumentalness': 3.78e-06,
#   'liveness': 0.18,
#   'valence': 0.698,
#   'tempo': 120.003,
#   'type': 'audio_features',
#   'id': '2bQTsDvV2GwdSqeUEzFYxD',
#   'uri': 'spotify:track:2bQTsDvV2GwdSqeUEzFYxD',
#   'track_href': 'https://api.spotify.com/v1/tracks/2bQTsDvV2GwdSqeUEzFYxD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2bQTsDvV2GwdSqeUEzFYxD',
#   'duration_ms': 172253,
#   'time_signature': 4},
#  {'danceability': 0.798,
#   'energy': 0.62,
#   'key': 8,
#   'loudness': -7.079,
#   'mode': 0,
#   'speechiness': 0.232,
#   'acousticness': 0.414,
#   'instrumentalness': 0.0192,
#   'liveness': 0.112,
#   'valence': 0.235,
#   'tempo': 120.031,
#   'type': 'audio_features',
#   'id': '3BiXjadPhHdG21xeREkWxI',
#   'uri': 'spotify:track:3BiXjadPhHdG21xeREkWxI',
#   'track_href': 'https://api.spotify.com/v1/tracks/3BiXjadPhHdG21xeREkWxI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BiXjadPhHdG21xeREkWxI',
#   'duration_ms': 164000,
#   'time_signature': 4},
#  {'danceability': 0.754,
#   'energy': 0.763,
#   'key': 7,
#   'loudness': -4.627,
#   'mode': 0,
#   'speechiness': 0.0435,
#   'acousticness': 0.0301,
#   'instrumentalness': 2.23e-05,
#   'liveness': 0.0901,
#   'valence': 0.464,
#   'tempo': 117.953,
#   'type': 'audio_features',
#   'id': '47Wat72GUkKVMCZuUqZvgN',
#   'uri': 'spotify:track:47Wat72GUkKVMCZuUqZvgN',
#   'track_href': 'https://api.spotify.com/v1/tracks/47Wat72GUkKVMCZuUqZvgN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47Wat72GUkKVMCZuUqZvgN',
#   'duration_ms': 164819,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.787,
#   'key': 11,
#   'loudness': -3.748,
#   'mode': 0,
#   'speechiness': 0.0583,
#   'acousticness': 0.198,
#   'instrumentalness': 0,
#   'liveness': 0.262,
#   'valence': 0.513,
#   'tempo': 119.986,
#   'type': 'audio_features',
#   'id': '2k02P0wC93X5mCg3oniJod',
#   'uri': 'spotify:track:2k02P0wC93X5mCg3oniJod',
#   'track_href': 'https://api.spotify.com/v1/tracks/2k02P0wC93X5mCg3oniJod',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2k02P0wC93X5mCg3oniJod',
#   'duration_ms': 140500,
#   'time_signature': 4},
#  {'danceability': 0.748,
#   'energy': 0.841,
#   'key': 7,
#   'loudness': -5.08,
#   'mode': 1,
#   'speechiness': 0.177,
#   'acousticness': 0.00445,
#   'instrumentalness': 1.33e-06,
#   'liveness': 0.0413,
#   'valence': 0.717,
#   'tempo': 123.045,
#   'type': 'audio_features',
#   'id': '5Ny7i7K1ZrgTM1zdYF7zDd',
#   'uri': 'spotify:track:5Ny7i7K1ZrgTM1zdYF7zDd',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Ny7i7K1ZrgTM1zdYF7zDd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Ny7i7K1ZrgTM1zdYF7zDd',
#   'duration_ms': 129817,
#   'time_signature': 4},
#  {'danceability': 0.66,
#   'energy': 0.942,
#   'key': 4,
#   'loudness': -2.273,
#   'mode': 1,
#   'speechiness': 0.185,
#   'acousticness': 0.00789,
#   'instrumentalness': 1.76e-05,
#   'liveness': 0.834,
#   'valence': 0.543,
#   'tempo': 126.017,
#   'type': 'audio_features',
#   'id': '7MjgZQFFoWVbIK1eVMLJH1',
#   'uri': 'spotify:track:7MjgZQFFoWVbIK1eVMLJH1',
#   'track_href': 'https://api.spotify.com/v1/tracks/7MjgZQFFoWVbIK1eVMLJH1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MjgZQFFoWVbIK1eVMLJH1',
#   'duration_ms': 158571,
#   'time_signature': 4},
#  {'danceability': 0.358,
#   'energy': 0.232,
#   'key': 5,
#   'loudness': -10.764,
#   'mode': 1,
#   'speechiness': 0.0369,
#   'acousticness': 0.945,
#   'instrumentalness': 0,
#   'liveness': 0.474,
#   'valence': 0.206,
#   'tempo': 78.01,
#   'type': 'audio_features',
#   'id': '7xEhAN3TS7D7IG3hW385lg',
#   'uri': 'spotify:track:7xEhAN3TS7D7IG3hW385lg',
#   'track_href': 'https://api.spotify.com/v1/tracks/7xEhAN3TS7D7IG3hW385lg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7xEhAN3TS7D7IG3hW385lg',
#   'duration_ms': 303587,
#   'time_signature': 1},
#  {'danceability': 0.528,
#   'energy': 0.511,
#   'key': 5,
#   'loudness': -6.955,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'acousticness': 0.737,
#   'instrumentalness': 0,
#   'liveness': 0.948,
#   'valence': 0.442,
#   'tempo': 120.242,
#   'type': 'audio_features',
#   'id': '3i6XfS8y09AMRwoTcFDctU',
#   'uri': 'spotify:track:3i6XfS8y09AMRwoTcFDctU',
#   'track_href': 'https://api.spotify.com/v1/tracks/3i6XfS8y09AMRwoTcFDctU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3i6XfS8y09AMRwoTcFDctU',
#   'duration_ms': 269387,
#   'time_signature': 3},
#  {'danceability': 0.306,
#   'energy': 0.3,
#   'key': 5,
#   'loudness': -8.26,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.942,
#   'instrumentalness': 6.47e-06,
#   'liveness': 0.686,
#   'valence': 0.252,
#   'tempo': 92.103,
#   'type': 'audio_features',
#   'id': '0063HDCrnGiUSLwyKuf80P',
#   'uri': 'spotify:track:0063HDCrnGiUSLwyKuf80P',
#   'track_href': 'https://api.spotify.com/v1/tracks/0063HDCrnGiUSLwyKuf80P',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0063HDCrnGiUSLwyKuf80P',
#   'duration_ms': 272853,
#   'time_signature': 4},
#  {'danceability': 0.406,
#   'energy': 0.282,
#   'key': 2,
#   'loudness': -10.76,
#   'mode': 1,
#   'speechiness': 0.0445,
#   'acousticness': 0.944,
#   'instrumentalness': 3.92e-06,
#   'liveness': 0.961,
#   'valence': 0.19,
#   'tempo': 95.384,
#   'type': 'audio_features',
#   'id': '06JRqSprCFMkwInuaGoMDy',
#   'uri': 'spotify:track:06JRqSprCFMkwInuaGoMDy',
#   'track_href': 'https://api.spotify.com/v1/tracks/06JRqSprCFMkwInuaGoMDy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06JRqSprCFMkwInuaGoMDy',
#   'duration_ms': 258800,
#   'time_signature': 4},
#  {'danceability': 0.428,
#   'energy': 0.749,
#   'key': 5,
#   'loudness': -6.23,
#   'mode': 1,
#   'speechiness': 0.0653,
#   'acousticness': 0.417,
#   'instrumentalness': 0,
#   'liveness': 0.927,
#   'valence': 0.62,
#   'tempo': 100.996,
#   'type': 'audio_features',
#   'id': '0QkAl81msBqoBeU3mJpTJa',
#   'uri': 'spotify:track:0QkAl81msBqoBeU3mJpTJa',
#   'track_href': 'https://api.spotify.com/v1/tracks/0QkAl81msBqoBeU3mJpTJa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0QkAl81msBqoBeU3mJpTJa',
#   'duration_ms': 323160,
#   'time_signature': 4},
#  {'danceability': 0.45,
#   'energy': 0.505,
#   'key': 5,
#   'loudness': -6.496,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.797,
#   'instrumentalness': 0,
#   'liveness': 0.964,
#   'valence': 0.215,
#   'tempo': 84.966,
#   'type': 'audio_features',
#   'id': '3I0YwxT3u4QvbGrqkByv9Y',
#   'uri': 'spotify:track:3I0YwxT3u4QvbGrqkByv9Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/3I0YwxT3u4QvbGrqkByv9Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3I0YwxT3u4QvbGrqkByv9Y',
#   'duration_ms': 305093,
#   'time_signature': 4},
#  {'danceability': 0.463,
#   'energy': 0.455,
#   'key': 5,
#   'loudness': -6.206,
#   'mode': 1,
#   'speechiness': 0.0354,
#   'acousticness': 0.893,
#   'instrumentalness': 0,
#   'liveness': 0.708,
#   'valence': 0.493,
#   'tempo': 114.182,
#   'type': 'audio_features',
#   'id': '1gb48iNJukhARhXMcck1WP',
#   'uri': 'spotify:track:1gb48iNJukhARhXMcck1WP',
#   'track_href': 'https://api.spotify.com/v1/tracks/1gb48iNJukhARhXMcck1WP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1gb48iNJukhARhXMcck1WP',
#   'duration_ms': 289973,
#   'time_signature': 4},
#  {'danceability': 0.333,
#   'energy': 0.259,
#   'key': 2,
#   'loudness': -11.219,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.966,
#   'instrumentalness': 1.81e-06,
#   'liveness': 0.835,
#   'valence': 0.259,
#   'tempo': 170.734,
#   'type': 'audio_features',
#   'id': '1K9grgM1ZDnbJlDhCv1YA3',
#   'uri': 'spotify:track:1K9grgM1ZDnbJlDhCv1YA3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1K9grgM1ZDnbJlDhCv1YA3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1K9grgM1ZDnbJlDhCv1YA3',
#   'duration_ms': 237200,
#   'time_signature': 4},
#  {'danceability': 0.377,
#   'energy': 0.425,
#   'key': 2,
#   'loudness': -8.197,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.897,
#   'instrumentalness': 5.86e-06,
#   'liveness': 0.793,
#   'valence': 0.154,
#   'tempo': 125.626,
#   'type': 'audio_features',
#   'id': '7tEDDskQUkkZRwYTyWd23E',
#   'uri': 'spotify:track:7tEDDskQUkkZRwYTyWd23E',
#   'track_href': 'https://api.spotify.com/v1/tracks/7tEDDskQUkkZRwYTyWd23E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tEDDskQUkkZRwYTyWd23E',
#   'duration_ms': 380773,
#   'time_signature': 4},
#  {'danceability': 0.501,
#   'energy': 0.537,
#   'key': 5,
#   'loudness': -11.235,
#   'mode': 1,
#   'speechiness': 0.308,
#   'acousticness': 0.823,
#   'instrumentalness': 0,
#   'liveness': 0.378,
#   'valence': 0.674,
#   'tempo': 79.929,
#   'type': 'audio_features',
#   'id': '0BphtX8slKuFxD6kTDgznS',
#   'uri': 'spotify:track:0BphtX8slKuFxD6kTDgznS',
#   'track_href': 'https://api.spotify.com/v1/tracks/0BphtX8slKuFxD6kTDgznS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BphtX8slKuFxD6kTDgznS',
#   'duration_ms': 103787,
#   'time_signature': 4},
#  {'danceability': 0.306,
#   'energy': 0.135,
#   'key': 5,
#   'loudness': -16.9,
#   'mode': 1,
#   'speechiness': 0.0411,
#   'acousticness': 0.987,
#   'instrumentalness': 0.00347,
#   'liveness': 0.715,
#   'valence': 0.262,
#   'tempo': 75.147,
#   'type': 'audio_features',
#   'id': '2pNfG5Oum8263gMAqgqLVA',
#   'uri': 'spotify:track:2pNfG5Oum8263gMAqgqLVA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2pNfG5Oum8263gMAqgqLVA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2pNfG5Oum8263gMAqgqLVA',
#   'duration_ms': 156040,
#   'time_signature': 4},
#  {'danceability': 0.636,
#   'energy': 0.869,
#   'key': 9,
#   'loudness': -5.289,
#   'mode': 1,
#   'speechiness': 0.0412,
#   'acousticness': 0.0378,
#   'instrumentalness': 0.0446,
#   'liveness': 0.0808,
#   'valence': 0.306,
#   'tempo': 143.011,
#   'type': 'audio_features',
#   'id': '5eTaQYBE1yrActixMAeLcZ',
#   'uri': 'spotify:track:5eTaQYBE1yrActixMAeLcZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5eTaQYBE1yrActixMAeLcZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5eTaQYBE1yrActixMAeLcZ',
#   'duration_ms': 186496,
#   'time_signature': 4},
#  {'danceability': 0.752,
#   'energy': 0.693,
#   'key': 4,
#   'loudness': -5.392,
#   'mode': 0,
#   'speechiness': 0.0793,
#   'acousticness': 0.0313,
#   'instrumentalness': 0,
#   'liveness': 0.146,
#   'valence': 0.675,
#   'tempo': 120.011,
#   'type': 'audio_features',
#   'id': '0HJ4Tedj2QSKLQJWRH30Aw',
#   'uri': 'spotify:track:0HJ4Tedj2QSKLQJWRH30Aw',
#   'track_href': 'https://api.spotify.com/v1/tracks/0HJ4Tedj2QSKLQJWRH30Aw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0HJ4Tedj2QSKLQJWRH30Aw',
#   'duration_ms': 139875,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.935,
#   'key': 2,
#   'loudness': -6.751,
#   'mode': 1,
#   'speechiness': 0.072,
#   'acousticness': 0.0123,
#   'instrumentalness': 0.000167,
#   'liveness': 0.131,
#   'valence': 0.3,
#   'tempo': 125.937,
#   'type': 'audio_features',
#   'id': '5nUyqq07mqo7dt8xd7BfYP',
#   'uri': 'spotify:track:5nUyqq07mqo7dt8xd7BfYP',
#   'track_href': 'https://api.spotify.com/v1/tracks/5nUyqq07mqo7dt8xd7BfYP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nUyqq07mqo7dt8xd7BfYP',
#   'duration_ms': 140477,
#   'time_signature': 4},
#  {'danceability': 0.68,
#   'energy': 0.867,
#   'key': 2,
#   'loudness': -6.805,
#   'mode': 1,
#   'speechiness': 0.0586,
#   'acousticness': 0.00272,
#   'instrumentalness': 0.015,
#   'liveness': 0.0468,
#   'valence': 0.57,
#   'tempo': 125.95,
#   'type': 'audio_features',
#   'id': '5UUSzeG8VzcuiqaIVlCZPb',
#   'uri': 'spotify:track:5UUSzeG8VzcuiqaIVlCZPb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5UUSzeG8VzcuiqaIVlCZPb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5UUSzeG8VzcuiqaIVlCZPb',
#   'duration_ms': 230104,
#   'time_signature': 4},
#  {'danceability': 0.301,
#   'energy': 0.488,
#   'key': 9,
#   'loudness': -8.459,
#   'mode': 0,
#   'speechiness': 0.0499,
#   'acousticness': 0.0756,
#   'instrumentalness': 0.000131,
#   'liveness': 0.077,
#   'valence': 0.139,
#   'tempo': 123.568,
#   'type': 'audio_features',
#   'id': '1Wh0AteEdZkd7wLrXfTpaN',
#   'uri': 'spotify:track:1Wh0AteEdZkd7wLrXfTpaN',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Wh0AteEdZkd7wLrXfTpaN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Wh0AteEdZkd7wLrXfTpaN',
#   'duration_ms': 267342,
#   'time_signature': 4},
#  {'danceability': 0.307,
#   'energy': 0.795,
#   'key': 9,
#   'loudness': -7.834,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.000953,
#   'instrumentalness': 0.0436,
#   'liveness': 0.191,
#   'valence': 0.233,
#   'tempo': 76.003,
#   'type': 'audio_features',
#   'id': '4eD5EYgHx2HJ6OKEduR8dc',
#   'uri': 'spotify:track:4eD5EYgHx2HJ6OKEduR8dc',
#   'track_href': 'https://api.spotify.com/v1/tracks/4eD5EYgHx2HJ6OKEduR8dc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eD5EYgHx2HJ6OKEduR8dc',
#   'duration_ms': 246751,
#   'time_signature': 4},
#  {'danceability': 0.467,
#   'energy': 0.383,
#   'key': 0,
#   'loudness': -7.188,
#   'mode': 1,
#   'speechiness': 0.0662,
#   'acousticness': 0.0644,
#   'instrumentalness': 8.99e-06,
#   'liveness': 0.132,
#   'valence': 0.205,
#   'tempo': 117.131,
#   'type': 'audio_features',
#   'id': '5rQZRubTfK9oa13vbgVs69',
#   'uri': 'spotify:track:5rQZRubTfK9oa13vbgVs69',
#   'track_href': 'https://api.spotify.com/v1/tracks/5rQZRubTfK9oa13vbgVs69',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rQZRubTfK9oa13vbgVs69',
#   'duration_ms': 214000,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.704,
#   'key': 9,
#   'loudness': -7.41,
#   'mode': 1,
#   'speechiness': 0.0944,
#   'acousticness': 0.00207,
#   'instrumentalness': 8.99e-06,
#   'liveness': 0.147,
#   'valence': 0.258,
#   'tempo': 89.992,
#   'type': 'audio_features',
#   'id': '2RCcpAEj643kbGSfgNOTch',
#   'uri': 'spotify:track:2RCcpAEj643kbGSfgNOTch',
#   'track_href': 'https://api.spotify.com/v1/tracks/2RCcpAEj643kbGSfgNOTch',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2RCcpAEj643kbGSfgNOTch',
#   'duration_ms': 134398,
#   'time_signature': 4},
#  {'danceability': 0.584,
#   'energy': 0.726,
#   'key': 7,
#   'loudness': -2.773,
#   'mode': 1,
#   'speechiness': 0.207,
#   'acousticness': 0.494,
#   'instrumentalness': 0,
#   'liveness': 0.591,
#   'valence': 0.6,
#   'tempo': 158.182,
#   'type': 'audio_features',
#   'id': '5LaT6csofzDEaFf8cmqoaQ',
#   'uri': 'spotify:track:5LaT6csofzDEaFf8cmqoaQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5LaT6csofzDEaFf8cmqoaQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5LaT6csofzDEaFf8cmqoaQ',
#   'duration_ms': 167835,
#   'time_signature': 4},
#  {'danceability': 0.748,
#   'energy': 0.782,
#   'key': 6,
#   'loudness': -5.423,
#   'mode': 1,
#   'speechiness': 0.163,
#   'acousticness': 0.108,
#   'instrumentalness': 0.035,
#   'liveness': 0.236,
#   'valence': 0.6,
#   'tempo': 139.902,
#   'type': 'audio_features',
#   'id': '2I8kUUKfC7h0QY3Qpfd0iq',
#   'uri': 'spotify:track:2I8kUUKfC7h0QY3Qpfd0iq',
#   'track_href': 'https://api.spotify.com/v1/tracks/2I8kUUKfC7h0QY3Qpfd0iq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2I8kUUKfC7h0QY3Qpfd0iq',
#   'duration_ms': 182090,
#   'time_signature': 4},
#  {'danceability': 0.468,
#   'energy': 0.889,
#   'key': 11,
#   'loudness': -4.958,
#   'mode': 0,
#   'speechiness': 0.275,
#   'acousticness': 0.000934,
#   'instrumentalness': 0.00857,
#   'liveness': 0.159,
#   'valence': 0.191,
#   'tempo': 160.168,
#   'type': 'audio_features',
#   'id': '7BnKLvcU4UK59XS0rkbDWu',
#   'uri': 'spotify:track:7BnKLvcU4UK59XS0rkbDWu',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BnKLvcU4UK59XS0rkbDWu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BnKLvcU4UK59XS0rkbDWu',
#   'duration_ms': 127921,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.921,
#   'key': 1,
#   'loudness': -4.882,
#   'mode': 0,
#   'speechiness': 0.06,
#   'acousticness': 0.012,
#   'instrumentalness': 0.0473,
#   'liveness': 0.0418,
#   'valence': 0.864,
#   'tempo': 165.003,
#   'type': 'audio_features',
#   'id': '7ii0G8eCY3L2yeDxZwEwtV',
#   'uri': 'spotify:track:7ii0G8eCY3L2yeDxZwEwtV',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ii0G8eCY3L2yeDxZwEwtV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ii0G8eCY3L2yeDxZwEwtV',
#   'duration_ms': 166727,
#   'time_signature': 3},
#  {'danceability': 0.542,
#   'energy': 0.901,
#   'key': 4,
#   'loudness': -2.065,
#   'mode': 0,
#   'speechiness': 0.101,
#   'acousticness': 0.172,
#   'instrumentalness': 0,
#   'liveness': 0.804,
#   'valence': 0.55,
#   'tempo': 158.024,
#   'type': 'audio_features',
#   'id': '09DGovANkw9vormaIc652y',
#   'uri': 'spotify:track:09DGovANkw9vormaIc652y',
#   'track_href': 'https://api.spotify.com/v1/tracks/09DGovANkw9vormaIc652y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09DGovANkw9vormaIc652y',
#   'duration_ms': 146240,
#   'time_signature': 4},
#  {'danceability': 0.451,
#   'energy': 0.235,
#   'key': 7,
#   'loudness': -10.53,
#   'mode': 1,
#   'speechiness': 0.0949,
#   'acousticness': 0.651,
#   'instrumentalness': 1.48e-05,
#   'liveness': 0.173,
#   'valence': 0.929,
#   'tempo': 160.135,
#   'type': 'audio_features',
#   'id': '05ywQE8gm0veaUecmUMX56',
#   'uri': 'spotify:track:05ywQE8gm0veaUecmUMX56',
#   'track_href': 'https://api.spotify.com/v1/tracks/05ywQE8gm0veaUecmUMX56',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05ywQE8gm0veaUecmUMX56',
#   'duration_ms': 45000,
#   'time_signature': 3},
#  {'danceability': 0.185,
#   'energy': 0.631,
#   'key': 9,
#   'loudness': -6.679,
#   'mode': 0,
#   'speechiness': 0.0354,
#   'acousticness': 0.00107,
#   'instrumentalness': 0.765,
#   'liveness': 0.543,
#   'valence': 0.148,
#   'tempo': 83.926,
#   'type': 'audio_features',
#   'id': '0l4s1zVinY9jEYJecDDlaQ',
#   'uri': 'spotify:track:0l4s1zVinY9jEYJecDDlaQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0l4s1zVinY9jEYJecDDlaQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0l4s1zVinY9jEYJecDDlaQ',
#   'duration_ms': 177559,
#   'time_signature': 4},
#  {'danceability': 0.742,
#   'energy': 0.663,
#   'key': 6,
#   'loudness': -7.14,
#   'mode': 0,
#   'speechiness': 0.107,
#   'acousticness': 0.0316,
#   'instrumentalness': 3.75e-05,
#   'liveness': 0.216,
#   'valence': 0.364,
#   'tempo': 124.023,
#   'type': 'audio_features',
#   'id': '6yTaG6eJDi6T0VSawfMTQy',
#   'uri': 'spotify:track:6yTaG6eJDi6T0VSawfMTQy',
#   'track_href': 'https://api.spotify.com/v1/tracks/6yTaG6eJDi6T0VSawfMTQy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yTaG6eJDi6T0VSawfMTQy',
#   'duration_ms': 153871,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.756,
#   'key': 2,
#   'loudness': -4.787,
#   'mode': 1,
#   'speechiness': 0.0996,
#   'acousticness': 0.0766,
#   'instrumentalness': 0,
#   'liveness': 0.0543,
#   'valence': 0.532,
#   'tempo': 128.004,
#   'type': 'audio_features',
#   'id': '6JqJ2DMu7B2PddAdNAVmYy',
#   'uri': 'spotify:track:6JqJ2DMu7B2PddAdNAVmYy',
#   'track_href': 'https://api.spotify.com/v1/tracks/6JqJ2DMu7B2PddAdNAVmYy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JqJ2DMu7B2PddAdNAVmYy',
#   'duration_ms': 182918,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.746,
#   'key': 2,
#   'loudness': -6.235,
#   'mode': 1,
#   'speechiness': 0.0656,
#   'acousticness': 0.103,
#   'instrumentalness': 1.4e-05,
#   'liveness': 0.0925,
#   'valence': 0.484,
#   'tempo': 140.09,
#   'type': 'audio_features',
#   'id': '1XXKon3zGTHj1LCTpwrWXE',
#   'uri': 'spotify:track:1XXKon3zGTHj1LCTpwrWXE',
#   'track_href': 'https://api.spotify.com/v1/tracks/1XXKon3zGTHj1LCTpwrWXE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1XXKon3zGTHj1LCTpwrWXE',
#   'duration_ms': 224801,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.917,
#   'key': 6,
#   'loudness': -2.095,
#   'mode': 0,
#   'speechiness': 0.0964,
#   'acousticness': 0.0273,
#   'instrumentalness': 0,
#   'liveness': 0.521,
#   'valence': 0.627,
#   'tempo': 124.024,
#   'type': 'audio_features',
#   'id': '5JL0aPP9mvMHx0IGXqcI5C',
#   'uri': 'spotify:track:5JL0aPP9mvMHx0IGXqcI5C',
#   'track_href': 'https://api.spotify.com/v1/tracks/5JL0aPP9mvMHx0IGXqcI5C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5JL0aPP9mvMHx0IGXqcI5C',
#   'duration_ms': 190609,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.822,
#   'key': 7,
#   'loudness': -6.431,
#   'mode': 0,
#   'speechiness': 0.0594,
#   'acousticness': 0.0416,
#   'instrumentalness': 0.00574,
#   'liveness': 0.174,
#   'valence': 0.619,
#   'tempo': 126.999,
#   'type': 'audio_features',
#   'id': '0rHT3KSdQn3JvGPwe5EH2Y',
#   'uri': 'spotify:track:0rHT3KSdQn3JvGPwe5EH2Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rHT3KSdQn3JvGPwe5EH2Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rHT3KSdQn3JvGPwe5EH2Y',
#   'duration_ms': 162520,
#   'time_signature': 4}]

# %%
audio_features = []
for i in range(0, len(new_track_ids), 100):
    audio_features += sp.audio_features(new_track_ids.iloc[i:i+100]['track_id'])
audio_features
# Out:
# [{'danceability': 0.602,
#   'energy': 0.493,
#   'key': 5,
#   'loudness': -5.695,
#   'mode': 1,
#   'speechiness': 0.0443,
#   'acousticness': 0.825,
#   'instrumentalness': 0,
#   'liveness': 0.364,
#   'valence': 0.281,
#   'tempo': 128.577,
#   'type': 'audio_features',
#   'id': '38tKvVe3iURKRFm5X50zLZ',
#   'uri': 'spotify:track:38tKvVe3iURKRFm5X50zLZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/38tKvVe3iURKRFm5X50zLZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/38tKvVe3iURKRFm5X50zLZ',
#   'duration_ms': 172326,
#   'time_signature': 4},
#  {'danceability': 0.847,
#   'energy': 0.724,
#   'key': 2,
#   'loudness': -7.668,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.00355,
#   'instrumentalness': 0.00339,
#   'liveness': 0.0731,
#   'valence': 0.326,
#   'tempo': 126.983,
#   'type': 'audio_features',
#   'id': '4zlbKky2yA657Sk5rekZoR',
#   'uri': 'spotify:track:4zlbKky2yA657Sk5rekZoR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zlbKky2yA657Sk5rekZoR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zlbKky2yA657Sk5rekZoR',
#   'duration_ms': 319964,
#   'time_signature': 4},
#  {'danceability': 0.619,
#   'energy': 0.437,
#   'key': 4,
#   'loudness': -7.623,
#   'mode': 0,
#   'speechiness': 0.0244,
#   'acousticness': 0.449,
#   'instrumentalness': 0.00184,
#   'liveness': 0.292,
#   'valence': 0.536,
#   'tempo': 90.972,
#   'type': 'audio_features',
#   'id': '4XhdM1Ku9JM4abVuRWAsgk',
#   'uri': 'spotify:track:4XhdM1Ku9JM4abVuRWAsgk',
#   'track_href': 'https://api.spotify.com/v1/tracks/4XhdM1Ku9JM4abVuRWAsgk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4XhdM1Ku9JM4abVuRWAsgk',
#   'duration_ms': 195164,
#   'time_signature': 4},
#  {'danceability': 0.613,
#   'energy': 0.443,
#   'key': 4,
#   'loudness': -7.502,
#   'mode': 0,
#   'speechiness': 0.0247,
#   'acousticness': 0.349,
#   'instrumentalness': 0,
#   'liveness': 0.237,
#   'valence': 0.604,
#   'tempo': 91.044,
#   'type': 'audio_features',
#   'id': '6McBFhOohQvx0zWkoISnap',
#   'uri': 'spotify:track:6McBFhOohQvx0zWkoISnap',
#   'track_href': 'https://api.spotify.com/v1/tracks/6McBFhOohQvx0zWkoISnap',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6McBFhOohQvx0zWkoISnap',
#   'duration_ms': 195164,
#   'time_signature': 4},
#  {'danceability': 0.507,
#   'energy': 0.741,
#   'key': 1,
#   'loudness': -4.857,
#   'mode': 1,
#   'speechiness': 0.0648,
#   'acousticness': 0.184,
#   'instrumentalness': 0.0104,
#   'liveness': 0.0916,
#   'valence': 0.257,
#   'tempo': 78.465,
#   'type': 'audio_features',
#   'id': '0xUeLKG6g1vGXSlHDsLKAf',
#   'uri': 'spotify:track:0xUeLKG6g1vGXSlHDsLKAf',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xUeLKG6g1vGXSlHDsLKAf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xUeLKG6g1vGXSlHDsLKAf',
#   'duration_ms': 380880,
#   'time_signature': 4},
#  {'danceability': 0.78,
#   'energy': 0.55,
#   'key': 10,
#   'loudness': -5.486,
#   'mode': 1,
#   'speechiness': 0.0428,
#   'acousticness': 0.522,
#   'instrumentalness': 0.692,
#   'liveness': 0.114,
#   'valence': 0.516,
#   'tempo': 145.033,
#   'type': 'audio_features',
#   'id': '1LFaiknfJkpWsPPNjNVKIW',
#   'uri': 'spotify:track:1LFaiknfJkpWsPPNjNVKIW',
#   'track_href': 'https://api.spotify.com/v1/tracks/1LFaiknfJkpWsPPNjNVKIW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1LFaiknfJkpWsPPNjNVKIW',
#   'duration_ms': 208720,
#   'time_signature': 3},
#  {'danceability': 0.764,
#   'energy': 0.567,
#   'key': 6,
#   'loudness': -7.493,
#   'mode': 1,
#   'speechiness': 0.0577,
#   'acousticness': 0.241,
#   'instrumentalness': 0.369,
#   'liveness': 0.324,
#   'valence': 0.412,
#   'tempo': 122.513,
#   'type': 'audio_features',
#   'id': '7FpD6W73sZuEEp4dNRCwy9',
#   'uri': 'spotify:track:7FpD6W73sZuEEp4dNRCwy9',
#   'track_href': 'https://api.spotify.com/v1/tracks/7FpD6W73sZuEEp4dNRCwy9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7FpD6W73sZuEEp4dNRCwy9',
#   'duration_ms': 277987,
#   'time_signature': 4},
#  {'danceability': 0.826,
#   'energy': 0.559,
#   'key': 1,
#   'loudness': -4.687,
#   'mode': 1,
#   'speechiness': 0.0388,
#   'acousticness': 0.59,
#   'instrumentalness': 0.926,
#   'liveness': 0.0918,
#   'valence': 0.399,
#   'tempo': 89.714,
#   'type': 'audio_features',
#   'id': '4Kga4UsecRjySf9xj2gQ0I',
#   'uri': 'spotify:track:4Kga4UsecRjySf9xj2gQ0I',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Kga4UsecRjySf9xj2gQ0I',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Kga4UsecRjySf9xj2gQ0I',
#   'duration_ms': 310973,
#   'time_signature': 4},
#  {'danceability': 0.723,
#   'energy': 0.593,
#   'key': 1,
#   'loudness': -9.632,
#   'mode': 1,
#   'speechiness': 0.0604,
#   'acousticness': 0.893,
#   'instrumentalness': 0.864,
#   'liveness': 0.119,
#   'valence': 0.304,
#   'tempo': 82.957,
#   'type': 'audio_features',
#   'id': '4kgXwktpr7IqnhPo84v6ul',
#   'uri': 'spotify:track:4kgXwktpr7IqnhPo84v6ul',
#   'track_href': 'https://api.spotify.com/v1/tracks/4kgXwktpr7IqnhPo84v6ul',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4kgXwktpr7IqnhPo84v6ul',
#   'duration_ms': 244747,
#   'time_signature': 4},
#  {'danceability': 0.927,
#   'energy': 0.631,
#   'key': 3,
#   'loudness': -5.245,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.0706,
#   'instrumentalness': 0.00536,
#   'liveness': 0.107,
#   'valence': 0.935,
#   'tempo': 123.316,
#   'type': 'audio_features',
#   'id': '0M2hckQzSt0AZFytuTC2Hp',
#   'uri': 'spotify:track:0M2hckQzSt0AZFytuTC2Hp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0M2hckQzSt0AZFytuTC2Hp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0M2hckQzSt0AZFytuTC2Hp',
#   'duration_ms': 215867,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.741,
#   'key': 8,
#   'loudness': -8.16,
#   'mode': 0,
#   'speechiness': 0.057,
#   'acousticness': 0.341,
#   'instrumentalness': 0.0344,
#   'liveness': 0.11,
#   'valence': 0.621,
#   'tempo': 126.985,
#   'type': 'audio_features',
#   'id': '3VZrMjHeYvUrFGKeG7B62D',
#   'uri': 'spotify:track:3VZrMjHeYvUrFGKeG7B62D',
#   'track_href': 'https://api.spotify.com/v1/tracks/3VZrMjHeYvUrFGKeG7B62D',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3VZrMjHeYvUrFGKeG7B62D',
#   'duration_ms': 250013,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.533,
#   'key': 6,
#   'loudness': -11.148,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.577,
#   'instrumentalness': 0.901,
#   'liveness': 0.0966,
#   'valence': 0.43,
#   'tempo': 139.997,
#   'type': 'audio_features',
#   'id': '2HHAVa6LIF4xGChgZNElpE',
#   'uri': 'spotify:track:2HHAVa6LIF4xGChgZNElpE',
#   'track_href': 'https://api.spotify.com/v1/tracks/2HHAVa6LIF4xGChgZNElpE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HHAVa6LIF4xGChgZNElpE',
#   'duration_ms': 289667,
#   'time_signature': 4},
#  {'danceability': 0.813,
#   'energy': 0.702,
#   'key': 6,
#   'loudness': -5.523,
#   'mode': 0,
#   'speechiness': 0.0366,
#   'acousticness': 0.357,
#   'instrumentalness': 0.376,
#   'liveness': 0.108,
#   'valence': 0.874,
#   'tempo': 124.117,
#   'type': 'audio_features',
#   'id': '7kdSrL0tJ5JMpL4GbvuKDy',
#   'uri': 'spotify:track:7kdSrL0tJ5JMpL4GbvuKDy',
#   'track_href': 'https://api.spotify.com/v1/tracks/7kdSrL0tJ5JMpL4GbvuKDy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7kdSrL0tJ5JMpL4GbvuKDy',
#   'duration_ms': 287520,
#   'time_signature': 4},
#  {'danceability': 0.766,
#   'energy': 0.378,
#   'key': 11,
#   'loudness': -10.54,
#   'mode': 0,
#   'speechiness': 0.101,
#   'acousticness': 0.772,
#   'instrumentalness': 0.886,
#   'liveness': 0.0854,
#   'valence': 0.478,
#   'tempo': 119.777,
#   'type': 'audio_features',
#   'id': '6SW2xr82FISqZtcAjE4Rl9',
#   'uri': 'spotify:track:6SW2xr82FISqZtcAjE4Rl9',
#   'track_href': 'https://api.spotify.com/v1/tracks/6SW2xr82FISqZtcAjE4Rl9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SW2xr82FISqZtcAjE4Rl9',
#   'duration_ms': 197827,
#   'time_signature': 3},
#  {'danceability': 0.833,
#   'energy': 0.362,
#   'key': 10,
#   'loudness': -7.856,
#   'mode': 0,
#   'speechiness': 0.0524,
#   'acousticness': 0.851,
#   'instrumentalness': 0.551,
#   'liveness': 0.105,
#   'valence': 0.598,
#   'tempo': 79.987,
#   'type': 'audio_features',
#   'id': '2AojQfi1k8pgwyg1Ii0Ly8',
#   'uri': 'spotify:track:2AojQfi1k8pgwyg1Ii0Ly8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2AojQfi1k8pgwyg1Ii0Ly8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2AojQfi1k8pgwyg1Ii0Ly8',
#   'duration_ms': 246720,
#   'time_signature': 4},
#  {'danceability': 0.269,
#   'energy': 0.0982,
#   'key': 10,
#   'loudness': -24.922,
#   'mode': 0,
#   'speechiness': 0.0436,
#   'acousticness': 0.945,
#   'instrumentalness': 0.878,
#   'liveness': 0.1,
#   'valence': 0.0492,
#   'tempo': 156.519,
#   'type': 'audio_features',
#   'id': '4daybsVF8kYbFhyjjcSOg0',
#   'uri': 'spotify:track:4daybsVF8kYbFhyjjcSOg0',
#   'track_href': 'https://api.spotify.com/v1/tracks/4daybsVF8kYbFhyjjcSOg0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4daybsVF8kYbFhyjjcSOg0',
#   'duration_ms': 134133,
#   'time_signature': 3},
#  {'danceability': 0.695,
#   'energy': 0.259,
#   'key': 6,
#   'loudness': -14.314,
#   'mode': 1,
#   'speechiness': 0.0572,
#   'acousticness': 0.923,
#   'instrumentalness': 0.00946,
#   'liveness': 0.107,
#   'valence': 0.272,
#   'tempo': 138.683,
#   'type': 'audio_features',
#   'id': '0lsAmBdyQqJz2adVowutMq',
#   'uri': 'spotify:track:0lsAmBdyQqJz2adVowutMq',
#   'track_href': 'https://api.spotify.com/v1/tracks/0lsAmBdyQqJz2adVowutMq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0lsAmBdyQqJz2adVowutMq',
#   'duration_ms': 208760,
#   'time_signature': 4},
#  {'danceability': 0.924,
#   'energy': 0.535,
#   'key': 6,
#   'loudness': -8.625,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.0285,
#   'instrumentalness': 0.821,
#   'liveness': 0.0898,
#   'valence': 0.737,
#   'tempo': 99.931,
#   'type': 'audio_features',
#   'id': '43FJKuRmiFls5gn19ydPa5',
#   'uri': 'spotify:track:43FJKuRmiFls5gn19ydPa5',
#   'track_href': 'https://api.spotify.com/v1/tracks/43FJKuRmiFls5gn19ydPa5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43FJKuRmiFls5gn19ydPa5',
#   'duration_ms': 356520,
#   'time_signature': 4},
#  {'danceability': 0.716,
#   'energy': 0.559,
#   'key': 7,
#   'loudness': -5.773,
#   'mode': 1,
#   'speechiness': 0.0541,
#   'acousticness': 0.26,
#   'instrumentalness': 0.000356,
#   'liveness': 0.0961,
#   'valence': 0.683,
#   'tempo': 132.102,
#   'type': 'audio_features',
#   'id': '4vIYNMhW588JXOlBlEQqrq',
#   'uri': 'spotify:track:4vIYNMhW588JXOlBlEQqrq',
#   'track_href': 'https://api.spotify.com/v1/tracks/4vIYNMhW588JXOlBlEQqrq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vIYNMhW588JXOlBlEQqrq',
#   'duration_ms': 161091,
#   'time_signature': 4},
#  {'danceability': 0.722,
#   'energy': 0.682,
#   'key': 5,
#   'loudness': -6.1,
#   'mode': 0,
#   'speechiness': 0.161,
#   'acousticness': 0.258,
#   'instrumentalness': 0.000397,
#   'liveness': 0.292,
#   'valence': 0.549,
#   'tempo': 90.016,
#   'type': 'audio_features',
#   'id': '6l0iiXFo28AG370kbE1gRE',
#   'uri': 'spotify:track:6l0iiXFo28AG370kbE1gRE',
#   'track_href': 'https://api.spotify.com/v1/tracks/6l0iiXFo28AG370kbE1gRE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6l0iiXFo28AG370kbE1gRE',
#   'duration_ms': 186753,
#   'time_signature': 4},
#  {'danceability': 0.576,
#   'energy': 0.555,
#   'key': 6,
#   'loudness': -12.02,
#   'mode': 1,
#   'speechiness': 0.173,
#   'acousticness': 0.41,
#   'instrumentalness': 7.78e-05,
#   'liveness': 0.289,
#   'valence': 0.366,
#   'tempo': 79.073,
#   'type': 'audio_features',
#   'id': '1XlrLdjGuzv2zspinPwilS',
#   'uri': 'spotify:track:1XlrLdjGuzv2zspinPwilS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1XlrLdjGuzv2zspinPwilS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1XlrLdjGuzv2zspinPwilS',
#   'duration_ms': 185829,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.866,
#   'key': 6,
#   'loudness': -4.461,
#   'mode': 0,
#   'speechiness': 0.0695,
#   'acousticness': 0.136,
#   'instrumentalness': 0,
#   'liveness': 0.0697,
#   'valence': 0.871,
#   'tempo': 166.975,
#   'type': 'audio_features',
#   'id': '19rYI8oRZAdz0gQIQ2yHld',
#   'uri': 'spotify:track:19rYI8oRZAdz0gQIQ2yHld',
#   'track_href': 'https://api.spotify.com/v1/tracks/19rYI8oRZAdz0gQIQ2yHld',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/19rYI8oRZAdz0gQIQ2yHld',
#   'duration_ms': 199935,
#   'time_signature': 4},
#  {'danceability': 0.756,
#   'energy': 0.921,
#   'key': 11,
#   'loudness': -6.196,
#   'mode': 0,
#   'speechiness': 0.0508,
#   'acousticness': 0.0386,
#   'instrumentalness': 0.0546,
#   'liveness': 0.327,
#   'valence': 0.384,
#   'tempo': 124.981,
#   'type': 'audio_features',
#   'id': '7bqg7RANz4RaboN0Ga1Miq',
#   'uri': 'spotify:track:7bqg7RANz4RaboN0Ga1Miq',
#   'track_href': 'https://api.spotify.com/v1/tracks/7bqg7RANz4RaboN0Ga1Miq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7bqg7RANz4RaboN0Ga1Miq',
#   'duration_ms': 134880,
#   'time_signature': 4},
#  {'danceability': 0.696,
#   'energy': 0.793,
#   'key': 8,
#   'loudness': -5.733,
#   'mode': 1,
#   'speechiness': 0.097,
#   'acousticness': 0.0683,
#   'instrumentalness': 3.78e-06,
#   'liveness': 0.18,
#   'valence': 0.698,
#   'tempo': 120.003,
#   'type': 'audio_features',
#   'id': '2bQTsDvV2GwdSqeUEzFYxD',
#   'uri': 'spotify:track:2bQTsDvV2GwdSqeUEzFYxD',
#   'track_href': 'https://api.spotify.com/v1/tracks/2bQTsDvV2GwdSqeUEzFYxD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2bQTsDvV2GwdSqeUEzFYxD',
#   'duration_ms': 172253,
#   'time_signature': 4},
#  {'danceability': 0.798,
#   'energy': 0.62,
#   'key': 8,
#   'loudness': -7.079,
#   'mode': 0,
#   'speechiness': 0.232,
#   'acousticness': 0.414,
#   'instrumentalness': 0.0192,
#   'liveness': 0.112,
#   'valence': 0.235,
#   'tempo': 120.031,
#   'type': 'audio_features',
#   'id': '3BiXjadPhHdG21xeREkWxI',
#   'uri': 'spotify:track:3BiXjadPhHdG21xeREkWxI',
#   'track_href': 'https://api.spotify.com/v1/tracks/3BiXjadPhHdG21xeREkWxI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BiXjadPhHdG21xeREkWxI',
#   'duration_ms': 164000,
#   'time_signature': 4},
#  {'danceability': 0.754,
#   'energy': 0.763,
#   'key': 7,
#   'loudness': -4.627,
#   'mode': 0,
#   'speechiness': 0.0435,
#   'acousticness': 0.0301,
#   'instrumentalness': 2.23e-05,
#   'liveness': 0.0901,
#   'valence': 0.464,
#   'tempo': 117.953,
#   'type': 'audio_features',
#   'id': '47Wat72GUkKVMCZuUqZvgN',
#   'uri': 'spotify:track:47Wat72GUkKVMCZuUqZvgN',
#   'track_href': 'https://api.spotify.com/v1/tracks/47Wat72GUkKVMCZuUqZvgN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47Wat72GUkKVMCZuUqZvgN',
#   'duration_ms': 164819,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.787,
#   'key': 11,
#   'loudness': -3.748,
#   'mode': 0,
#   'speechiness': 0.0583,
#   'acousticness': 0.198,
#   'instrumentalness': 0,
#   'liveness': 0.262,
#   'valence': 0.513,
#   'tempo': 119.986,
#   'type': 'audio_features',
#   'id': '2k02P0wC93X5mCg3oniJod',
#   'uri': 'spotify:track:2k02P0wC93X5mCg3oniJod',
#   'track_href': 'https://api.spotify.com/v1/tracks/2k02P0wC93X5mCg3oniJod',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2k02P0wC93X5mCg3oniJod',
#   'duration_ms': 140500,
#   'time_signature': 4},
#  {'danceability': 0.748,
#   'energy': 0.841,
#   'key': 7,
#   'loudness': -5.08,
#   'mode': 1,
#   'speechiness': 0.177,
#   'acousticness': 0.00445,
#   'instrumentalness': 1.33e-06,
#   'liveness': 0.0413,
#   'valence': 0.717,
#   'tempo': 123.045,
#   'type': 'audio_features',
#   'id': '5Ny7i7K1ZrgTM1zdYF7zDd',
#   'uri': 'spotify:track:5Ny7i7K1ZrgTM1zdYF7zDd',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Ny7i7K1ZrgTM1zdYF7zDd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Ny7i7K1ZrgTM1zdYF7zDd',
#   'duration_ms': 129817,
#   'time_signature': 4},
#  {'danceability': 0.66,
#   'energy': 0.942,
#   'key': 4,
#   'loudness': -2.273,
#   'mode': 1,
#   'speechiness': 0.185,
#   'acousticness': 0.00789,
#   'instrumentalness': 1.76e-05,
#   'liveness': 0.834,
#   'valence': 0.543,
#   'tempo': 126.017,
#   'type': 'audio_features',
#   'id': '7MjgZQFFoWVbIK1eVMLJH1',
#   'uri': 'spotify:track:7MjgZQFFoWVbIK1eVMLJH1',
#   'track_href': 'https://api.spotify.com/v1/tracks/7MjgZQFFoWVbIK1eVMLJH1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MjgZQFFoWVbIK1eVMLJH1',
#   'duration_ms': 158571,
#   'time_signature': 4},
#  {'danceability': 0.358,
#   'energy': 0.232,
#   'key': 5,
#   'loudness': -10.764,
#   'mode': 1,
#   'speechiness': 0.0369,
#   'acousticness': 0.945,
#   'instrumentalness': 0,
#   'liveness': 0.474,
#   'valence': 0.206,
#   'tempo': 78.01,
#   'type': 'audio_features',
#   'id': '7xEhAN3TS7D7IG3hW385lg',
#   'uri': 'spotify:track:7xEhAN3TS7D7IG3hW385lg',
#   'track_href': 'https://api.spotify.com/v1/tracks/7xEhAN3TS7D7IG3hW385lg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7xEhAN3TS7D7IG3hW385lg',
#   'duration_ms': 303587,
#   'time_signature': 1},
#  {'danceability': 0.528,
#   'energy': 0.511,
#   'key': 5,
#   'loudness': -6.955,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'acousticness': 0.737,
#   'instrumentalness': 0,
#   'liveness': 0.948,
#   'valence': 0.442,
#   'tempo': 120.242,
#   'type': 'audio_features',
#   'id': '3i6XfS8y09AMRwoTcFDctU',
#   'uri': 'spotify:track:3i6XfS8y09AMRwoTcFDctU',
#   'track_href': 'https://api.spotify.com/v1/tracks/3i6XfS8y09AMRwoTcFDctU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3i6XfS8y09AMRwoTcFDctU',
#   'duration_ms': 269387,
#   'time_signature': 3},
#  {'danceability': 0.306,
#   'energy': 0.3,
#   'key': 5,
#   'loudness': -8.26,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.942,
#   'instrumentalness': 6.47e-06,
#   'liveness': 0.686,
#   'valence': 0.252,
#   'tempo': 92.103,
#   'type': 'audio_features',
#   'id': '0063HDCrnGiUSLwyKuf80P',
#   'uri': 'spotify:track:0063HDCrnGiUSLwyKuf80P',
#   'track_href': 'https://api.spotify.com/v1/tracks/0063HDCrnGiUSLwyKuf80P',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0063HDCrnGiUSLwyKuf80P',
#   'duration_ms': 272853,
#   'time_signature': 4},
#  {'danceability': 0.406,
#   'energy': 0.282,
#   'key': 2,
#   'loudness': -10.76,
#   'mode': 1,
#   'speechiness': 0.0445,
#   'acousticness': 0.944,
#   'instrumentalness': 3.92e-06,
#   'liveness': 0.961,
#   'valence': 0.19,
#   'tempo': 95.384,
#   'type': 'audio_features',
#   'id': '06JRqSprCFMkwInuaGoMDy',
#   'uri': 'spotify:track:06JRqSprCFMkwInuaGoMDy',
#   'track_href': 'https://api.spotify.com/v1/tracks/06JRqSprCFMkwInuaGoMDy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06JRqSprCFMkwInuaGoMDy',
#   'duration_ms': 258800,
#   'time_signature': 4},
#  {'danceability': 0.428,
#   'energy': 0.749,
#   'key': 5,
#   'loudness': -6.23,
#   'mode': 1,
#   'speechiness': 0.0653,
#   'acousticness': 0.417,
#   'instrumentalness': 0,
#   'liveness': 0.927,
#   'valence': 0.62,
#   'tempo': 100.996,
#   'type': 'audio_features',
#   'id': '0QkAl81msBqoBeU3mJpTJa',
#   'uri': 'spotify:track:0QkAl81msBqoBeU3mJpTJa',
#   'track_href': 'https://api.spotify.com/v1/tracks/0QkAl81msBqoBeU3mJpTJa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0QkAl81msBqoBeU3mJpTJa',
#   'duration_ms': 323160,
#   'time_signature': 4},
#  {'danceability': 0.45,
#   'energy': 0.505,
#   'key': 5,
#   'loudness': -6.496,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.797,
#   'instrumentalness': 0,
#   'liveness': 0.964,
#   'valence': 0.215,
#   'tempo': 84.966,
#   'type': 'audio_features',
#   'id': '3I0YwxT3u4QvbGrqkByv9Y',
#   'uri': 'spotify:track:3I0YwxT3u4QvbGrqkByv9Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/3I0YwxT3u4QvbGrqkByv9Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3I0YwxT3u4QvbGrqkByv9Y',
#   'duration_ms': 305093,
#   'time_signature': 4},
#  {'danceability': 0.463,
#   'energy': 0.455,
#   'key': 5,
#   'loudness': -6.206,
#   'mode': 1,
#   'speechiness': 0.0354,
#   'acousticness': 0.893,
#   'instrumentalness': 0,
#   'liveness': 0.708,
#   'valence': 0.493,
#   'tempo': 114.182,
#   'type': 'audio_features',
#   'id': '1gb48iNJukhARhXMcck1WP',
#   'uri': 'spotify:track:1gb48iNJukhARhXMcck1WP',
#   'track_href': 'https://api.spotify.com/v1/tracks/1gb48iNJukhARhXMcck1WP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1gb48iNJukhARhXMcck1WP',
#   'duration_ms': 289973,
#   'time_signature': 4},
#  {'danceability': 0.333,
#   'energy': 0.259,
#   'key': 2,
#   'loudness': -11.219,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.966,
#   'instrumentalness': 1.81e-06,
#   'liveness': 0.835,
#   'valence': 0.259,
#   'tempo': 170.734,
#   'type': 'audio_features',
#   'id': '1K9grgM1ZDnbJlDhCv1YA3',
#   'uri': 'spotify:track:1K9grgM1ZDnbJlDhCv1YA3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1K9grgM1ZDnbJlDhCv1YA3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1K9grgM1ZDnbJlDhCv1YA3',
#   'duration_ms': 237200,
#   'time_signature': 4},
#  {'danceability': 0.377,
#   'energy': 0.425,
#   'key': 2,
#   'loudness': -8.197,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.897,
#   'instrumentalness': 5.86e-06,
#   'liveness': 0.793,
#   'valence': 0.154,
#   'tempo': 125.626,
#   'type': 'audio_features',
#   'id': '7tEDDskQUkkZRwYTyWd23E',
#   'uri': 'spotify:track:7tEDDskQUkkZRwYTyWd23E',
#   'track_href': 'https://api.spotify.com/v1/tracks/7tEDDskQUkkZRwYTyWd23E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tEDDskQUkkZRwYTyWd23E',
#   'duration_ms': 380773,
#   'time_signature': 4},
#  {'danceability': 0.501,
#   'energy': 0.537,
#   'key': 5,
#   'loudness': -11.235,
#   'mode': 1,
#   'speechiness': 0.308,
#   'acousticness': 0.823,
#   'instrumentalness': 0,
#   'liveness': 0.378,
#   'valence': 0.674,
#   'tempo': 79.929,
#   'type': 'audio_features',
#   'id': '0BphtX8slKuFxD6kTDgznS',
#   'uri': 'spotify:track:0BphtX8slKuFxD6kTDgznS',
#   'track_href': 'https://api.spotify.com/v1/tracks/0BphtX8slKuFxD6kTDgznS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BphtX8slKuFxD6kTDgznS',
#   'duration_ms': 103787,
#   'time_signature': 4},
#  {'danceability': 0.306,
#   'energy': 0.135,
#   'key': 5,
#   'loudness': -16.9,
#   'mode': 1,
#   'speechiness': 0.0411,
#   'acousticness': 0.987,
#   'instrumentalness': 0.00347,
#   'liveness': 0.715,
#   'valence': 0.262,
#   'tempo': 75.147,
#   'type': 'audio_features',
#   'id': '2pNfG5Oum8263gMAqgqLVA',
#   'uri': 'spotify:track:2pNfG5Oum8263gMAqgqLVA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2pNfG5Oum8263gMAqgqLVA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2pNfG5Oum8263gMAqgqLVA',
#   'duration_ms': 156040,
#   'time_signature': 4},
#  {'danceability': 0.636,
#   'energy': 0.869,
#   'key': 9,
#   'loudness': -5.289,
#   'mode': 1,
#   'speechiness': 0.0412,
#   'acousticness': 0.0378,
#   'instrumentalness': 0.0446,
#   'liveness': 0.0808,
#   'valence': 0.306,
#   'tempo': 143.011,
#   'type': 'audio_features',
#   'id': '5eTaQYBE1yrActixMAeLcZ',
#   'uri': 'spotify:track:5eTaQYBE1yrActixMAeLcZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5eTaQYBE1yrActixMAeLcZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5eTaQYBE1yrActixMAeLcZ',
#   'duration_ms': 186496,
#   'time_signature': 4},
#  {'danceability': 0.752,
#   'energy': 0.693,
#   'key': 4,
#   'loudness': -5.392,
#   'mode': 0,
#   'speechiness': 0.0793,
#   'acousticness': 0.0313,
#   'instrumentalness': 0,
#   'liveness': 0.146,
#   'valence': 0.675,
#   'tempo': 120.011,
#   'type': 'audio_features',
#   'id': '0HJ4Tedj2QSKLQJWRH30Aw',
#   'uri': 'spotify:track:0HJ4Tedj2QSKLQJWRH30Aw',
#   'track_href': 'https://api.spotify.com/v1/tracks/0HJ4Tedj2QSKLQJWRH30Aw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0HJ4Tedj2QSKLQJWRH30Aw',
#   'duration_ms': 139875,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.935,
#   'key': 2,
#   'loudness': -6.751,
#   'mode': 1,
#   'speechiness': 0.072,
#   'acousticness': 0.0123,
#   'instrumentalness': 0.000167,
#   'liveness': 0.131,
#   'valence': 0.3,
#   'tempo': 125.937,
#   'type': 'audio_features',
#   'id': '5nUyqq07mqo7dt8xd7BfYP',
#   'uri': 'spotify:track:5nUyqq07mqo7dt8xd7BfYP',
#   'track_href': 'https://api.spotify.com/v1/tracks/5nUyqq07mqo7dt8xd7BfYP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nUyqq07mqo7dt8xd7BfYP',
#   'duration_ms': 140477,
#   'time_signature': 4},
#  {'danceability': 0.68,
#   'energy': 0.867,
#   'key': 2,
#   'loudness': -6.805,
#   'mode': 1,
#   'speechiness': 0.0586,
#   'acousticness': 0.00272,
#   'instrumentalness': 0.015,
#   'liveness': 0.0468,
#   'valence': 0.57,
#   'tempo': 125.95,
#   'type': 'audio_features',
#   'id': '5UUSzeG8VzcuiqaIVlCZPb',
#   'uri': 'spotify:track:5UUSzeG8VzcuiqaIVlCZPb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5UUSzeG8VzcuiqaIVlCZPb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5UUSzeG8VzcuiqaIVlCZPb',
#   'duration_ms': 230104,
#   'time_signature': 4},
#  {'danceability': 0.301,
#   'energy': 0.488,
#   'key': 9,
#   'loudness': -8.459,
#   'mode': 0,
#   'speechiness': 0.0499,
#   'acousticness': 0.0756,
#   'instrumentalness': 0.000131,
#   'liveness': 0.077,
#   'valence': 0.139,
#   'tempo': 123.568,
#   'type': 'audio_features',
#   'id': '1Wh0AteEdZkd7wLrXfTpaN',
#   'uri': 'spotify:track:1Wh0AteEdZkd7wLrXfTpaN',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Wh0AteEdZkd7wLrXfTpaN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Wh0AteEdZkd7wLrXfTpaN',
#   'duration_ms': 267342,
#   'time_signature': 4},
#  {'danceability': 0.307,
#   'energy': 0.795,
#   'key': 9,
#   'loudness': -7.834,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.000953,
#   'instrumentalness': 0.0436,
#   'liveness': 0.191,
#   'valence': 0.233,
#   'tempo': 76.003,
#   'type': 'audio_features',
#   'id': '4eD5EYgHx2HJ6OKEduR8dc',
#   'uri': 'spotify:track:4eD5EYgHx2HJ6OKEduR8dc',
#   'track_href': 'https://api.spotify.com/v1/tracks/4eD5EYgHx2HJ6OKEduR8dc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eD5EYgHx2HJ6OKEduR8dc',
#   'duration_ms': 246751,
#   'time_signature': 4},
#  {'danceability': 0.467,
#   'energy': 0.383,
#   'key': 0,
#   'loudness': -7.188,
#   'mode': 1,
#   'speechiness': 0.0662,
#   'acousticness': 0.0644,
#   'instrumentalness': 8.99e-06,
#   'liveness': 0.132,
#   'valence': 0.205,
#   'tempo': 117.131,
#   'type': 'audio_features',
#   'id': '5rQZRubTfK9oa13vbgVs69',
#   'uri': 'spotify:track:5rQZRubTfK9oa13vbgVs69',
#   'track_href': 'https://api.spotify.com/v1/tracks/5rQZRubTfK9oa13vbgVs69',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rQZRubTfK9oa13vbgVs69',
#   'duration_ms': 214000,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.704,
#   'key': 9,
#   'loudness': -7.41,
#   'mode': 1,
#   'speechiness': 0.0944,
#   'acousticness': 0.00207,
#   'instrumentalness': 8.99e-06,
#   'liveness': 0.147,
#   'valence': 0.258,
#   'tempo': 89.992,
#   'type': 'audio_features',
#   'id': '2RCcpAEj643kbGSfgNOTch',
#   'uri': 'spotify:track:2RCcpAEj643kbGSfgNOTch',
#   'track_href': 'https://api.spotify.com/v1/tracks/2RCcpAEj643kbGSfgNOTch',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2RCcpAEj643kbGSfgNOTch',
#   'duration_ms': 134398,
#   'time_signature': 4},
#  {'danceability': 0.584,
#   'energy': 0.726,
#   'key': 7,
#   'loudness': -2.773,
#   'mode': 1,
#   'speechiness': 0.207,
#   'acousticness': 0.494,
#   'instrumentalness': 0,
#   'liveness': 0.591,
#   'valence': 0.6,
#   'tempo': 158.182,
#   'type': 'audio_features',
#   'id': '5LaT6csofzDEaFf8cmqoaQ',
#   'uri': 'spotify:track:5LaT6csofzDEaFf8cmqoaQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5LaT6csofzDEaFf8cmqoaQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5LaT6csofzDEaFf8cmqoaQ',
#   'duration_ms': 167835,
#   'time_signature': 4},
#  {'danceability': 0.748,
#   'energy': 0.782,
#   'key': 6,
#   'loudness': -5.423,
#   'mode': 1,
#   'speechiness': 0.163,
#   'acousticness': 0.108,
#   'instrumentalness': 0.035,
#   'liveness': 0.236,
#   'valence': 0.6,
#   'tempo': 139.902,
#   'type': 'audio_features',
#   'id': '2I8kUUKfC7h0QY3Qpfd0iq',
#   'uri': 'spotify:track:2I8kUUKfC7h0QY3Qpfd0iq',
#   'track_href': 'https://api.spotify.com/v1/tracks/2I8kUUKfC7h0QY3Qpfd0iq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2I8kUUKfC7h0QY3Qpfd0iq',
#   'duration_ms': 182090,
#   'time_signature': 4},
#  {'danceability': 0.468,
#   'energy': 0.889,
#   'key': 11,
#   'loudness': -4.958,
#   'mode': 0,
#   'speechiness': 0.275,
#   'acousticness': 0.000934,
#   'instrumentalness': 0.00857,
#   'liveness': 0.159,
#   'valence': 0.191,
#   'tempo': 160.168,
#   'type': 'audio_features',
#   'id': '7BnKLvcU4UK59XS0rkbDWu',
#   'uri': 'spotify:track:7BnKLvcU4UK59XS0rkbDWu',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BnKLvcU4UK59XS0rkbDWu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BnKLvcU4UK59XS0rkbDWu',
#   'duration_ms': 127921,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.921,
#   'key': 1,
#   'loudness': -4.882,
#   'mode': 0,
#   'speechiness': 0.06,
#   'acousticness': 0.012,
#   'instrumentalness': 0.0473,
#   'liveness': 0.0418,
#   'valence': 0.864,
#   'tempo': 165.003,
#   'type': 'audio_features',
#   'id': '7ii0G8eCY3L2yeDxZwEwtV',
#   'uri': 'spotify:track:7ii0G8eCY3L2yeDxZwEwtV',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ii0G8eCY3L2yeDxZwEwtV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ii0G8eCY3L2yeDxZwEwtV',
#   'duration_ms': 166727,
#   'time_signature': 3},
#  {'danceability': 0.542,
#   'energy': 0.901,
#   'key': 4,
#   'loudness': -2.065,
#   'mode': 0,
#   'speechiness': 0.101,
#   'acousticness': 0.172,
#   'instrumentalness': 0,
#   'liveness': 0.804,
#   'valence': 0.55,
#   'tempo': 158.024,
#   'type': 'audio_features',
#   'id': '09DGovANkw9vormaIc652y',
#   'uri': 'spotify:track:09DGovANkw9vormaIc652y',
#   'track_href': 'https://api.spotify.com/v1/tracks/09DGovANkw9vormaIc652y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09DGovANkw9vormaIc652y',
#   'duration_ms': 146240,
#   'time_signature': 4},
#  {'danceability': 0.451,
#   'energy': 0.235,
#   'key': 7,
#   'loudness': -10.53,
#   'mode': 1,
#   'speechiness': 0.0949,
#   'acousticness': 0.651,
#   'instrumentalness': 1.48e-05,
#   'liveness': 0.173,
#   'valence': 0.929,
#   'tempo': 160.135,
#   'type': 'audio_features',
#   'id': '05ywQE8gm0veaUecmUMX56',
#   'uri': 'spotify:track:05ywQE8gm0veaUecmUMX56',
#   'track_href': 'https://api.spotify.com/v1/tracks/05ywQE8gm0veaUecmUMX56',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05ywQE8gm0veaUecmUMX56',
#   'duration_ms': 45000,
#   'time_signature': 3},
#  {'danceability': 0.185,
#   'energy': 0.631,
#   'key': 9,
#   'loudness': -6.679,
#   'mode': 0,
#   'speechiness': 0.0354,
#   'acousticness': 0.00107,
#   'instrumentalness': 0.765,
#   'liveness': 0.543,
#   'valence': 0.148,
#   'tempo': 83.926,
#   'type': 'audio_features',
#   'id': '0l4s1zVinY9jEYJecDDlaQ',
#   'uri': 'spotify:track:0l4s1zVinY9jEYJecDDlaQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0l4s1zVinY9jEYJecDDlaQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0l4s1zVinY9jEYJecDDlaQ',
#   'duration_ms': 177559,
#   'time_signature': 4},
#  {'danceability': 0.742,
#   'energy': 0.663,
#   'key': 6,
#   'loudness': -7.14,
#   'mode': 0,
#   'speechiness': 0.107,
#   'acousticness': 0.0316,
#   'instrumentalness': 3.75e-05,
#   'liveness': 0.216,
#   'valence': 0.364,
#   'tempo': 124.023,
#   'type': 'audio_features',
#   'id': '6yTaG6eJDi6T0VSawfMTQy',
#   'uri': 'spotify:track:6yTaG6eJDi6T0VSawfMTQy',
#   'track_href': 'https://api.spotify.com/v1/tracks/6yTaG6eJDi6T0VSawfMTQy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yTaG6eJDi6T0VSawfMTQy',
#   'duration_ms': 153871,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.756,
#   'key': 2,
#   'loudness': -4.787,
#   'mode': 1,
#   'speechiness': 0.0996,
#   'acousticness': 0.0766,
#   'instrumentalness': 0,
#   'liveness': 0.0543,
#   'valence': 0.532,
#   'tempo': 128.004,
#   'type': 'audio_features',
#   'id': '6JqJ2DMu7B2PddAdNAVmYy',
#   'uri': 'spotify:track:6JqJ2DMu7B2PddAdNAVmYy',
#   'track_href': 'https://api.spotify.com/v1/tracks/6JqJ2DMu7B2PddAdNAVmYy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JqJ2DMu7B2PddAdNAVmYy',
#   'duration_ms': 182918,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.746,
#   'key': 2,
#   'loudness': -6.235,
#   'mode': 1,
#   'speechiness': 0.0656,
#   'acousticness': 0.103,
#   'instrumentalness': 1.4e-05,
#   'liveness': 0.0925,
#   'valence': 0.484,
#   'tempo': 140.09,
#   'type': 'audio_features',
#   'id': '1XXKon3zGTHj1LCTpwrWXE',
#   'uri': 'spotify:track:1XXKon3zGTHj1LCTpwrWXE',
#   'track_href': 'https://api.spotify.com/v1/tracks/1XXKon3zGTHj1LCTpwrWXE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1XXKon3zGTHj1LCTpwrWXE',
#   'duration_ms': 224801,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.917,
#   'key': 6,
#   'loudness': -2.095,
#   'mode': 0,
#   'speechiness': 0.0964,
#   'acousticness': 0.0273,
#   'instrumentalness': 0,
#   'liveness': 0.521,
#   'valence': 0.627,
#   'tempo': 124.024,
#   'type': 'audio_features',
#   'id': '5JL0aPP9mvMHx0IGXqcI5C',
#   'uri': 'spotify:track:5JL0aPP9mvMHx0IGXqcI5C',
#   'track_href': 'https://api.spotify.com/v1/tracks/5JL0aPP9mvMHx0IGXqcI5C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5JL0aPP9mvMHx0IGXqcI5C',
#   'duration_ms': 190609,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.822,
#   'key': 7,
#   'loudness': -6.431,
#   'mode': 0,
#   'speechiness': 0.0594,
#   'acousticness': 0.0416,
#   'instrumentalness': 0.00574,
#   'liveness': 0.174,
#   'valence': 0.619,
#   'tempo': 126.999,
#   'type': 'audio_features',
#   'id': '0rHT3KSdQn3JvGPwe5EH2Y',
#   'uri': 'spotify:track:0rHT3KSdQn3JvGPwe5EH2Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rHT3KSdQn3JvGPwe5EH2Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rHT3KSdQn3JvGPwe5EH2Y',
#   'duration_ms': 162520,
#   'time_signature': 4}]

# %% [markdown]
# # Clean Audio Features
# - input audio_features (list of dictionaries)
# - output clean_audio_features (df)

# %%
clean_audio_features = pd.DataFrame(audio_features)
clean_audio_features.drop(['type', 'uri', 'track_href', 'analysis_url'], axis=1, inplace=True)
clean_audio_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.602   0.493    5    -5.695     1       0.0443       0.82500
# 1         0.847   0.724    2    -7.668     1       0.0470       0.00355
# 2         0.619   0.437    4    -7.623     0       0.0244       0.44900
# 3         0.613   0.443    4    -7.502     0       0.0247       0.34900
# 4         0.507   0.741    1    -4.857     1       0.0648       0.18400
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0           0.00000    0.3640    0.281  128.577  38tKvVe3iURKRFm5X50zLZ
# 1           0.00339    0.0731    0.326  126.983  4zlbKky2yA657Sk5rekZoR
# 2           0.00184    0.2920    0.536   90.972  4XhdM1Ku9JM4abVuRWAsgk
# 3           0.00000    0.2370    0.604   91.044  6McBFhOohQvx0zWkoISnap
# 4           0.01040    0.0916    0.257   78.465  0xUeLKG6g1vGXSlHDsLKAf
#
#    duration_ms  time_signature
# 0       172326               4
# 1       319964               4
# 2       195164               4
# 3       195164               4
# 4       380880               4

# %% [markdown]
# # Load Audio Features
# - input clean_audio_features(df)
# - load
# - end

# %% [markdown]
# # Draft

# %%
# album_group, album_type, artists, available_markets, external_urls, href, id, images, name, 
# release_date, release_date_precision, total_tracks, type, uri

# albums is list of dictionaries
# We need: artists, available_markets, id, name, release_date, release_date_precision, total_tracks, popularity(??)

# %%
# artists_id = []
# artists_name = []

# %%
# count = 0
# for i, element in enumerate(new_tracks["albums"]["items"]):
#     album_type.append(element["album_type"])
#     artists.append(element["artists"])
#     available_markets.append(element["available_markets"])
#     external_urls.append(element["external_urls"])
#     href.append(element["href"])
#     id.append(element["id"])
#     images.append(element["images"])
#     name.append(element["name"])
#     release_date.append(element["release_date"])
#     release_date_precision.append(element["release_date_precision"])
#     total_tracks.append(element["total_tracks"])
#     type.append(element["type"])
#     uri.append(element["uri"])
#     temp_id = []
#     temp_name = []
#     for j, artist in enumerate(element["artists"]):
#         temp_id.append(artist["id"])
#         temp_name.append(artist["name"])
#     artists_id.append(temp_id)
#     artists_name.append(temp_name)

# %%
# artists[0]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#   'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#   'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#   'name': 'Tiësto',
#   'type': 'artist',
#   'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}]

# %%
# images[0]
# Out:
# [{'height': 640,
#   'url': 'https://i.scdn.co/image/ab67616d0000b273739c17c3d6a944de9d09b07d',
#   'width': 640},
#  {'height': 300,
#   'url': 'https://i.scdn.co/image/ab67616d00001e02739c17c3d6a944de9d09b07d',
#   'width': 300},
#  {'height': 64,
#   'url': 'https://i.scdn.co/image/ab67616d00004851739c17c3d6a944de9d09b07d',
#   'width': 64}]

# %%
# newly_released_df = pd.DataFrame({"id":id, "album_type":album_type, "artists":artists, "artists_id":artists_id,
#                                  "artists_name":artists_name, "available_markets":available_markets,
#                                  "external_urls":external_urls, "href":href, "images":images, "name":name, 
#                                  "release_date":release_date, "release_date_precision":release_date_precision,
#                                  "total_tracks":total_tracks, "type":type, "uri":uri})
# newly_released_df.head()
# Out:
#                        id album_type  \
# 0  6dn1PltXAnQZB5i5jJoeN6     single
# 1  6aRMTwvizxU03QnudEZ8Hu     single
# 2  74tuwcpsRBZgjtQxja5vVb     single
# 3  31hnvDgjFArB8Xbntl48ou     single
# 4  4wtZQMNTC1O79kDxMBsEan      album
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                           artists_id  \
# 0  [73jBynjsVtofjRpdpRAJGk, 21E3waRsmPlU7jZsS13rc...
# 1  [77AiFEVeAVj2ORpC85QVJs, 4sTQVOfp9vEMCemLw50sb...
# 2  [1IueXOQyABrMOprrzwQJWN, 1BEUkE2CSUgHTLSBMZdnF...
# 3   [2V431yZGG08uroH2CZAgur, 5B4kCOhcqTywB9YwXPfFtJ]
# 4                           [3AA28KZvwAUcZuOKwyblJQ]
#
#                                       artists_name  \
# 0  [Dimitri Vegas & Like Mike, Ne-Yo, Danna Paola]
# 1            [Steve Aoki, Galantis, Hayley Kiyoko]
# 2                [Sigala, Mae Muller, Caity Baser]
# 3                  [Sarah de Warren, Weird Genius]
# 4                                       [Gorillaz]
#
#                                    available_markets  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 2  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 3  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 4  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/6d...
# 1  {'spotify': 'https://open.spotify.com/album/6a...
# 2  {'spotify': 'https://open.spotify.com/album/74...
# 3  {'spotify': 'https://open.spotify.com/album/31...
# 4  {'spotify': 'https://open.spotify.com/album/4w...
#
#                                                 href  \
# 0  https://api.spotify.com/v1/albums/6dn1PltXAnQZ...
# 1  https://api.spotify.com/v1/albums/6aRMTwvizxU0...
# 2  https://api.spotify.com/v1/albums/74tuwcpsRBZg...
# 3  https://api.spotify.com/v1/albums/31hnvDgjFArB...
# 4  https://api.spotify.com/v1/albums/4wtZQMNTC1O7...
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                              name release_date release_date_precision  \
# 0                          Mexico   2023-03-03                    day
# 1  Hungry Heart ft. Hayley Kiyoko   2023-03-03                    day
# 2                 Feels This Good   2023-03-03                    day
# 3                           Sugar   2023-02-28                    day
# 4                  Cracker Island   2023-02-24                    day
#
#    total_tracks   type                                   uri
# 0             1  album  spotify:album:6dn1PltXAnQZB5i5jJoeN6
# 1             2  album  spotify:album:6aRMTwvizxU03QnudEZ8Hu
# 2             1  album  spotify:album:74tuwcpsRBZgjtQxja5vVb
# 3             1  album  spotify:album:31hnvDgjFArB8Xbntl48ou
# 4            10  album  spotify:album:4wtZQMNTC1O79kDxMBsEan

# %%
# df = pd.DataFrame({"id":id, "name":name, "artists_name":artists_name, "release_date":release_date})
# df.head()
# Out:
#                        id                            name  \
# 0  6dn1PltXAnQZB5i5jJoeN6                          Mexico
# 1  6aRMTwvizxU03QnudEZ8Hu  Hungry Heart ft. Hayley Kiyoko
# 2  74tuwcpsRBZgjtQxja5vVb                 Feels This Good
# 3  31hnvDgjFArB8Xbntl48ou                           Sugar
# 4  4wtZQMNTC1O79kDxMBsEan                  Cracker Island
#
#                                       artists_name release_date
# 0  [Dimitri Vegas & Like Mike, Ne-Yo, Danna Paola]   2023-03-03
# 1            [Steve Aoki, Galantis, Hayley Kiyoko]   2023-03-03
# 2                [Sigala, Mae Muller, Caity Baser]   2023-03-03
# 3                  [Sarah de Warren, Weird Genius]   2023-02-28
# 4                                       [Gorillaz]   2023-02-24
