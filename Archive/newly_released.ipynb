# %% [markdown]
# # Extract New Releases
# - input json file
# - output albums (json), extract_date_album (date)

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
from datetime import date

# %%
credentials = json.load(open('../authorization.json'))
client_id = credentials['client_id']
client_secret = credentials['client_secret']
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp

# %%
albums = sp.new_releases(limit=50, offset=0)['albums']['items']

# %%
albums
# Out:
# [{'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4GvEc3ANtPPjt1ZJllr5Zl'},
#     'href': 'https://api.spotify.com/v1/artists/4GvEc3ANtPPjt1ZJllr5Zl',
#     'id': '4GvEc3ANtPPjt1ZJllr5Zl',
#     'name': 'Bazzi',
#     'type': 'artist',
#     'uri': 'spotify:artist:4GvEc3ANtPPjt1ZJllr5Zl'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
# ...

# %%
extract_date_album = date.today()

# %%
with open('albums.json', 'w', encoding='utf-8') as f:
    json.dump(albums, f, ensure_ascii=False, indent=4)

# %%
with open('albums.json', 'r', encoding='utf-8') as f:
    albums = json.load(f)
albums
# Out:
# [{'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4l1q0z9xeJcJw73Gxc6gCB'},
#     'href': 'https://api.spotify.com/v1/artists/4l1q0z9xeJcJw73Gxc6gCB',
#     'id': '4l1q0z9xeJcJw73Gxc6gCB',
#     'name': 'Mark Tuan',
#     'type': 'artist',
#     'uri': 'spotify:artist:4l1q0z9xeJcJw73Gxc6gCB'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
# ...

# %% [markdown]
# # Clean New Albums
# - input albums(json), extract_date_album (date)
# - output clean_albums (df)

# %%
import pandas as pd
from datetime import date

# %%
artists_id = [] # further division
available_markets = []
id = []
name = []
release_date = []
total_tracks = []
# popularity = []

# %%
for i, album in enumerate(albums):
    available_markets.append(len(album['available_markets']))
    id.append(album['id'])
    name.append(album['name'])
    release_date.append(album['release_date'])
    total_tracks.append(album['total_tracks'])
    
    aids = []
    for i, artist in enumerate(album['artists']):
        aids.append(artist['id'])
    artists_id.append(aids)

# %%
clean_albums = pd.DataFrame({
    'id': id,
    'name': name,
    'total_tracks': total_tracks,
    'available_markets': available_markets,
    'release_date': release_date,
    'artists_id': artists_id
})
clean_albums['extract_date'] = extract_date_album
clean_albums['release_date'] = clean_albums['release_date'].apply(lambda x: pd.to_datetime(x).date())
clean_albums
# Out:
#                         id                                               name  \
# 0   78BtIMQEsMAc7sxhFeKnRB                                       Carry Me Out
# 1   0lkZgRyVYqPgQqe8z3N0Ls                                                 謝幕
# 2   5dyyPQSKBBVcJfWZ3J9mEf                                               天晴预告
# 3   1oIy8CYApH9VUB73DqUvPT  Say Say Say (feat. Paul McCartney & Michael Ja...
# 4   67IEDkeGYxOvS2RvcarzrT       That’s Not How This Works (feat. Dan + Shay)
# 5   0CYQHh2Xwv6Jv30TUBvTjH                                       Candle Flame
# 6   5DfXqXeruwDNlfcCxxjKN9                                    No Explanations
# 7   2IKwJMDlZQxvocJgWLTDLT                                          Superblue
# 8   3RtfM1haEzNzgmANkQPcLJ                               Avatars Of The Night
# 9   1miLkkuVyfxwrJY9vsJpIO                                     Stand by Dream
# 10  0cNb1JOALBpKIZtOxxSabq                            By The End Of The Night
# ...

# %%
clean_albums.to_json('clean_albums.json', date_format='iso')

# %%
from dateutil import parser
with open('clean_albums.json', 'r') as f:
    clean_albums = json.load(f)
clean_albums = pd.DataFrame(clean_albums)
clean_albums.reset_index(drop=True, inplace=True)
clean_albums['release_date'] = clean_albums['release_date'].apply(parser.parse)
clean_albums['extract_date'] = clean_albums['extract_date'].apply(parser.parse)
clean_albums
# clean_albums[['release_date']].apply(lambda x: x.dt.strftime('%Y-%m-%d'))
# clean_albums
# Out:
#                         id                                               name  \
# 0   78BtIMQEsMAc7sxhFeKnRB                                       Carry Me Out
# 1   0lkZgRyVYqPgQqe8z3N0Ls                                                 謝幕
# 2   5dyyPQSKBBVcJfWZ3J9mEf                                               天晴预告
# 3   1oIy8CYApH9VUB73DqUvPT  Say Say Say (feat. Paul McCartney & Michael Ja...
# 4   67IEDkeGYxOvS2RvcarzrT       That’s Not How This Works (feat. Dan + Shay)
# 5   0CYQHh2Xwv6Jv30TUBvTjH                                       Candle Flame
# 6   5DfXqXeruwDNlfcCxxjKN9                                    No Explanations
# 7   2IKwJMDlZQxvocJgWLTDLT                                          Superblue
# 8   3RtfM1haEzNzgmANkQPcLJ                               Avatars Of The Night
# 9   1miLkkuVyfxwrJY9vsJpIO                                     Stand by Dream
# 10  0cNb1JOALBpKIZtOxxSabq                            By The End Of The Night
# ...

# %% [markdown]
# # Load New Albums
# - input clean albums (df)
# - load
# - **end**
#
# Should drop artists_id and load

# %%
from google.cloud import bigquery
import os

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "letsgo-snappy-boulder-378707-4b7d46801fd1.json"

# Construct a BigQuery client object.
client = bigquery.Client()

# %%
schema = [
    bigquery.SchemaField("id","STRING"),
    bigquery.SchemaField("name","STRING"),
    bigquery.SchemaField("total_tracks","INTEGER"),
    bigquery.SchemaField("available_markets","INTEGER"),
    bigquery.SchemaField("release_date","DATE"),
    bigquery.SchemaField("extract_date","DATE"),
]

job_config = bigquery.LoadJobConfig(
    schema = schema,
    source_format=bigquery.SourceFormat.CSV,
    skip_leading_rows=1,
    autodetect=True,
)

table_id = "snappy-boulder-378707.NewReleases.NewAlbums"
job = client.load_table_from_dataframe(clean_albums2, table_id, job_config=job_config)

job.result()  # Waits for the job to complete.

table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
# Loaded 19 rows and 6 columns to snappy-boulder-378707.NewReleases.NewAlbums

# %%
clean_albums2 = clean_albums.drop(columns='artists_id')
clean_albums2
# Out:
#                         id                                               name  \
# 0   0cNb1JOALBpKIZtOxxSabq                            By The End Of The Night
# 1   5HOHne1wzItQlIYmLXLYfZ  Did you know that there's a tunnel under Ocean...
# 2   7lAb1k0oyiwz7WONpINl5A                                         SunKissing
# 3   5mWnMYLnfcnkDOCojHW6O1                             So Much (For) Stardust
# 4   7t2qYxQeNwbMVdc5wwaSNa                                  With All My Heart
# 5   22MkBC5l2Zi9atm66fE0Jq                         Want It All (feat. Evalyn)
# 6   7rQcfmaOYzHKmAlyeuwdTt                                      Us Without Me
# 7   2oRM1rJALdQfceK3i7SxG3                                        Can I Jump?
# 8   6qbsZIWMMfIdwCqtpo1G3m                                            Driving
# 9   2thP70nudcFpvmRl3AsYRa                                          The Light
# 10  4dyBDF0ThEiA0o7VSzPkB5                                        Paper Plane
# ...

# %% [markdown]
# # Extract New Albums Full Info
# - input clean_albums (df)
# - output albums_full_info (json)

# %%
al = sp.album(clean_albums['id'].tolist()[0])

# %%
# albums_full_info = sp.albums(clean_albums['id'].tolist())['albums']

# %%
with open('albums_full_info_test.json', 'w', encoding='utf-8') as f:
    json.dump(albums_full_info, f, ensure_ascii=False, indent=4)

# %%
with open('albums_full_info_test.json', 'r') as f:
    albums_full_info = json.load(f)
albums_full_info
# Out:
# [{'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0X2BH1fck6amBIoJhDVmmJ'},
#     'href': 'https://api.spotify.com/v1/artists/0X2BH1fck6amBIoJhDVmmJ',
#     'id': '0X2BH1fck6amBIoJhDVmmJ',
#     'name': 'Ellie Goulding',
#     'type': 'artist',
#     'uri': 'spotify:artist:0X2BH1fck6amBIoJhDVmmJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
# ...

# %% [markdown]
# # Get New Track IDs
# - input albums_full_info (json)
# - output new_track_ids (df)

# %%
clean_albums.reset_index(drop=True, inplace=True)
clean_albums.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
track_id = []
album_id = []
artists_id = []
for i, album in enumerate(albums_full_info):
    for j, track in enumerate(album['tracks']['items']):
        track_id.append(track['id'])
        album_id.append(album['id'])
        artists_id.append(clean_albums.loc[i,'artists_id'])

# %%
new_track_ids = pd.DataFrame({
    'track_id': track_id,
    'album_id': album_id,
    'artists_id': artists_id
})
new_track_ids.head()
# Out:
#                  track_id                album_id                artists_id
# 0  0tYtfBFJLVn2ITE66FbaLT  0cNb1JOALBpKIZtOxxSabq  [4xerUCsurnILh4KpC5FVWX]
# 1  3KbOflJ5JqHWtmco4PiO3h  5HOHne1wzItQlIYmLXLYfZ  [0Q6X1jqwOVQuclYp2P1bub]
# 2  0HEzuLLojblUOaUSdmJ9gl  5HOHne1wzItQlIYmLXLYfZ  [0Q6X1jqwOVQuclYp2P1bub]
# 3  6x8g6DxglrzCSwKhv2Q1ee  5HOHne1wzItQlIYmLXLYfZ  [0Q6X1jqwOVQuclYp2P1bub]
# 4  5nW4z3pfZgJAJ2QTCz9AIE  5HOHne1wzItQlIYmLXLYfZ  [0Q6X1jqwOVQuclYp2P1bub]

# %%
new_track_ids.to_csv('new_track_ids.csv')
# Out:
#     Unnamed: 0                track_id                album_id  \
# 0            0  0tYtfBFJLVn2ITE66FbaLT  0cNb1JOALBpKIZtOxxSabq
# 1            1  3KbOflJ5JqHWtmco4PiO3h  5HOHne1wzItQlIYmLXLYfZ
# 2            2  0HEzuLLojblUOaUSdmJ9gl  5HOHne1wzItQlIYmLXLYfZ
# 3            3  6x8g6DxglrzCSwKhv2Q1ee  5HOHne1wzItQlIYmLXLYfZ
# 4            4  5nW4z3pfZgJAJ2QTCz9AIE  5HOHne1wzItQlIYmLXLYfZ
# ..         ...                     ...                     ...
# 69          69  3P0vUFGglD2FL8ErAOFoED  00cjv8haUkTVHTrMB8ZWep
# 70          70  61pVPN8WoNqWE5ATrVIKg5  00cjv8haUkTVHTrMB8ZWep
# 71          71  38tKvVe3iURKRFm5X50zLZ  4fU1IAiidcbKjProAZuoLF
# 72          72  4XhdM1Ku9JM4abVuRWAsgk  4sNLO2KeOADZykYBkqclN1
# 73          73  6McBFhOohQvx0zWkoISnap  4sNLO2KeOADZykYBkqclN1
#
#                     artists_id
# 0   ['4xerUCsurnILh4KpC5FVWX']
# 1   ['0Q6X1jqwOVQuclYp2P1bub']
# 2   ['0Q6X1jqwOVQuclYp2P1bub']
# 3   ['0Q6X1jqwOVQuclYp2P1bub']
# 4   ['0Q6X1jqwOVQuclYp2P1bub']
# ...

# %%
new_track_ids = pd.read_csv('new_track_ids.csv')
new_track_ids
# Out:
#     Unnamed: 0                track_id                album_id  \
# 0            0  0tYtfBFJLVn2ITE66FbaLT  0cNb1JOALBpKIZtOxxSabq
# 1            1  3KbOflJ5JqHWtmco4PiO3h  5HOHne1wzItQlIYmLXLYfZ
# 2            2  0HEzuLLojblUOaUSdmJ9gl  5HOHne1wzItQlIYmLXLYfZ
# 3            3  6x8g6DxglrzCSwKhv2Q1ee  5HOHne1wzItQlIYmLXLYfZ
# 4            4  5nW4z3pfZgJAJ2QTCz9AIE  5HOHne1wzItQlIYmLXLYfZ
# ..         ...                     ...                     ...
# 69          69  3P0vUFGglD2FL8ErAOFoED  00cjv8haUkTVHTrMB8ZWep
# 70          70  61pVPN8WoNqWE5ATrVIKg5  00cjv8haUkTVHTrMB8ZWep
# 71          71  38tKvVe3iURKRFm5X50zLZ  4fU1IAiidcbKjProAZuoLF
# 72          72  4XhdM1Ku9JM4abVuRWAsgk  4sNLO2KeOADZykYBkqclN1
# 73          73  6McBFhOohQvx0zWkoISnap  4sNLO2KeOADZykYBkqclN1
#
#                     artists_id
# 0   ['4xerUCsurnILh4KpC5FVWX']
# 1   ['0Q6X1jqwOVQuclYp2P1bub']
# 2   ['0Q6X1jqwOVQuclYp2P1bub']
# 3   ['0Q6X1jqwOVQuclYp2P1bub']
# 4   ['0Q6X1jqwOVQuclYp2P1bub']
# ...

# %%
new_track_ids['artists_id'] = new_track_ids['artists_id'].apply(eval)

# %%
type(new_track_ids.loc[0,'artists_id'])
# Out:
# list

# %% [markdown]
# # Extract New Track Info
# - input new_track_ids (df)
# - output new_tracks (list of dictionaries) and extract_date_track (date)

# %%
new_tracks = []
for i in range(0, len(new_track_ids), 50):
    new_tracks += sp.tracks(new_track_ids.iloc[i:i+50]['track_id'])['tracks']
new_tracks
# Out:
# [{'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0X2BH1fck6amBIoJhDVmmJ'},
#      'href': 'https://api.spotify.com/v1/artists/0X2BH1fck6amBIoJhDVmmJ',
#      'id': '0X2BH1fck6amBIoJhDVmmJ',
#      'name': 'Ellie Goulding',
#      'type': 'artist',
#      'uri': 'spotify:artist:0X2BH1fck6amBIoJhDVmmJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
# ...

# %%
extract_date_track = date.today()

# %%
with open('new_tracks.json', 'w', encoding='utf-8') as f:
    json.dump(new_tracks, f, ensure_ascii=False, indent=4)
# Out:
# [{'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0X2BH1fck6amBIoJhDVmmJ'},
#      'href': 'https://api.spotify.com/v1/artists/0X2BH1fck6amBIoJhDVmmJ',
#      'id': '0X2BH1fck6amBIoJhDVmmJ',
#      'name': 'Ellie Goulding',
#      'type': 'artist',
#      'uri': 'spotify:artist:0X2BH1fck6amBIoJhDVmmJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
# ...

# %%
with open('new_tracks.json', 'r') as f:
    new_tracks = json.load(f)
new_tracks
# Out:
# [{'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0X2BH1fck6amBIoJhDVmmJ'},
#      'href': 'https://api.spotify.com/v1/artists/0X2BH1fck6amBIoJhDVmmJ',
#      'id': '0X2BH1fck6amBIoJhDVmmJ',
#      'name': 'Ellie Goulding',
#      'type': 'artist',
#      'uri': 'spotify:artist:0X2BH1fck6amBIoJhDVmmJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
# ...

# %% [markdown]
# # Clean New Track Info
# - input new_track_ids (df), new_tracks (list of dictionaries), extract_date_track (date)
# - output clean_new_tracks (df)
#
# We need id, name, extract date, popularity, explicit, available markets, (release date should refer to album table)

# %%
id = []
name = []
explicit = []
available_markets = []
popularity = []
album_id = []

for i, track in enumerate(new_tracks):
    id.append(track['id'])
    name.append(track['name'])
    available_markets.append(len(track['available_markets']))
    explicit.append((1 if track['explicit'] else 0))
    popularity.append(track['popularity'])
    album_id.append(new_track_ids.loc[i,'album_id'])

# %%
clean_new_tracks = pd.DataFrame({
    'id': id,
    'name': name,
    'explicit': explicit,
    'available_markets': available_markets,
    'popularity': popularity,
    'album_id': album_id
})
clean_new_tracks['artist_id'] = new_track_ids['artists_id']
clean_new_tracks['artist_id'] = clean_new_tracks['artist_id'].apply(lambda x: ";".join(x))
clean_new_tracks['extract_date'] = extract_date_track
clean_new_tracks
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 11
#       9 clean_new_tracks['artist_id'] = new_track_ids['artists_id']
#      10 clean_new_tracks['artist_id'] = clean_new_tracks['artist_id'].apply(lambda x: ";".join(x))
# ---> 11 clean_new_tracks['extract_date'] = extract_date_track
#      12 clean_new_tracks
#
# NameError: name 'extract_date_track' is not defined

# %% [markdown]
# # Load New Track Info
# - input clean_new_tracks (df)
# - load
# - end

# %%
from google.cloud import bigquery
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "letsgo-snappy-boulder-378707-4b7d46801fd1.json"
# Construct a BigQuery client object.
client = bigquery.Client()

schema = [
    bigquery.SchemaField("id","STRING"),
    bigquery.SchemaField("name","STRING"),
    bigquery.SchemaField("explicit","INTEGER"),
    bigquery.SchemaField("available_markets","INTEGER"),
    bigquery.SchemaField("popularity","INTEGER"),
    bigquery.SchemaField("album_id","STRING"),
    bigquery.SchemaField("artist_id","STRING"),
    bigquery.SchemaField("extract_date","DATE"),
]

job_config = bigquery.LoadJobConfig(
    schema = schema,
    source_format=bigquery.SourceFormat.CSV,
    skip_leading_rows=1,
    autodetect=True,
)

table_id = "snappy-boulder-378707.NewReleases.NewTracks"
job = client.load_table_from_dataframe(clean_new_tracks, table_id, job_config=job_config)

job.result()  # Waits for the job to complete.

table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
# Loaded 73 rows and 8 columns to snappy-boulder-378707.NewReleases.NewTracks

# %% [markdown]
# # Extract Audio Features
# - input new_track_ids (df)
# - output audio_features (list of dictionaries)

# %%
sp.audio_features(new_track_ids['track_id'].tolist())
# Out:
# [{'danceability': 0.603,
#   'energy': 0.816,
#   'key': 1,
#   'loudness': -3.549,
#   'mode': 0,
#   'speechiness': 0.0335,
#   'acousticness': 0.0104,
#   'instrumentalness': 5.7e-05,
#   'liveness': 0.133,
#   'valence': 0.401,
#   'tempo': 149.934,
#   'type': 'audio_features',
#   'id': '0tYtfBFJLVn2ITE66FbaLT',
#   'uri': 'spotify:track:0tYtfBFJLVn2ITE66FbaLT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tYtfBFJLVn2ITE66FbaLT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tYtfBFJLVn2ITE66FbaLT',
#   'duration_ms': 188562,
#   'time_signature': 4},
#  {'danceability': 0.364,
#   'energy': 0.167,
#   'key': 7,
#   'loudness': -12.168,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.867,
#   'instrumentalness': 0.00116,
#   'liveness': 0.358,
#   'valence': 0.143,
#   'tempo': 121.218,
#   'type': 'audio_features',
#   'id': '3KbOflJ5JqHWtmco4PiO3h',
#   'uri': 'spotify:track:3KbOflJ5JqHWtmco4PiO3h',
# ...

# %%
audio_features = []
for i in range(0, len(new_track_ids), 100):
    audio_features += sp.audio_features(new_track_ids.iloc[i:i+100]['track_id'])
audio_features
# Out:
# [{'danceability': 0.603,
#   'energy': 0.816,
#   'key': 1,
#   'loudness': -3.549,
#   'mode': 0,
#   'speechiness': 0.0335,
#   'acousticness': 0.0104,
#   'instrumentalness': 5.7e-05,
#   'liveness': 0.133,
#   'valence': 0.401,
#   'tempo': 149.934,
#   'type': 'audio_features',
#   'id': '0tYtfBFJLVn2ITE66FbaLT',
#   'uri': 'spotify:track:0tYtfBFJLVn2ITE66FbaLT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tYtfBFJLVn2ITE66FbaLT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tYtfBFJLVn2ITE66FbaLT',
#   'duration_ms': 188562,
#   'time_signature': 4},
#  {'danceability': 0.364,
#   'energy': 0.167,
#   'key': 7,
#   'loudness': -12.168,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.867,
#   'instrumentalness': 0.00116,
#   'liveness': 0.358,
#   'valence': 0.143,
#   'tempo': 121.218,
#   'type': 'audio_features',
#   'id': '3KbOflJ5JqHWtmco4PiO3h',
#   'uri': 'spotify:track:3KbOflJ5JqHWtmco4PiO3h',
# ...

# %%
with open('audio_features.json', 'w', encoding='utf-8') as f:
    json.dump(audio_features, f, ensure_ascii=False, indent=4)

# %%
with open('audio_features.json', 'r') as f:
    audio_features = json.load(f)

audio_features
# Out:
# [{'danceability': 0.603,
#   'energy': 0.816,
#   'key': 1,
#   'loudness': -3.549,
#   'mode': 0,
#   'speechiness': 0.0335,
#   'acousticness': 0.0104,
#   'instrumentalness': 5.7e-05,
#   'liveness': 0.133,
#   'valence': 0.401,
#   'tempo': 149.934,
#   'type': 'audio_features',
#   'id': '0tYtfBFJLVn2ITE66FbaLT',
#   'uri': 'spotify:track:0tYtfBFJLVn2ITE66FbaLT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tYtfBFJLVn2ITE66FbaLT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tYtfBFJLVn2ITE66FbaLT',
#   'duration_ms': 188562,
#   'time_signature': 4},
#  {'danceability': 0.364,
#   'energy': 0.167,
#   'key': 7,
#   'loudness': -12.168,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.867,
#   'instrumentalness': 0.00116,
#   'liveness': 0.358,
#   'valence': 0.143,
#   'tempo': 121.218,
#   'type': 'audio_features',
#   'id': '3KbOflJ5JqHWtmco4PiO3h',
#   'uri': 'spotify:track:3KbOflJ5JqHWtmco4PiO3h',
# ...

# %% [markdown]
# # Clean Audio Features
# - input audio_features (list of dictionaries)
# - output clean_audio_features (df)

# %%
clean_audio_features = pd.DataFrame(audio_features)
clean_audio_features.reset_index(drop=True, inplace=True)
clean_audio_features.drop(['type', 'uri', 'track_href', 'analysis_url'], axis=1, inplace=True)
clean_audio_features = clean_audio_features[['id','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms','time_signature']]
clean_audio_features.head()
# Out:
#                        id  danceability  energy  key  loudness  mode  \
# 0  0tYtfBFJLVn2ITE66FbaLT         0.603   0.816    1    -3.549     0
# 1  3KbOflJ5JqHWtmco4PiO3h         0.364   0.167    7   -12.168     1
# 2  0HEzuLLojblUOaUSdmJ9gl         0.457   0.343    0    -9.387     1
# 3  6x8g6DxglrzCSwKhv2Q1ee         0.326   0.245    0   -12.337     1
# 4  5nW4z3pfZgJAJ2QTCz9AIE         0.421   0.247   10   -14.655     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0335        0.0104          0.000057     0.133   0.4010  149.934
# 1       0.0361        0.8670          0.001160     0.358   0.1430  121.218
# 2       0.0305        0.8050          0.018200     0.120   0.0562  119.940
# 3       0.0293        0.9580          0.003890     0.157   0.0695  126.725
# 4       0.1430        0.6650          0.375000     0.115   0.1390  161.468
#
#    duration_ms  time_signature
# 0       188562               4
# 1       295202               4
# ...

# %%
clean_audio_features.to_csv('clean_audio_features.csv', index=False)

# %%
clean_audio_features = pd.read_csv('clean_audio_features.csv', index_col=[0])
clean_audio_features
# Out:
#     Unnamed: 0                      id  danceability  energy  key  loudness  \
# 0            0  0tYtfBFJLVn2ITE66FbaLT         0.603   0.816    1    -3.549
# 1            1  3KbOflJ5JqHWtmco4PiO3h         0.364   0.167    7   -12.168
# 2            2  0HEzuLLojblUOaUSdmJ9gl         0.457   0.343    0    -9.387
# 3            3  6x8g6DxglrzCSwKhv2Q1ee         0.326   0.245    0   -12.337
# 4            4  5nW4z3pfZgJAJ2QTCz9AIE         0.421   0.247   10   -14.655
# ..         ...                     ...           ...     ...  ...       ...
# 69          69  3P0vUFGglD2FL8ErAOFoED         0.482   0.415    9    -9.360
# 70          70  61pVPN8WoNqWE5ATrVIKg5         0.636   0.457   10    -7.268
# 71          71  38tKvVe3iURKRFm5X50zLZ         0.602   0.493    5    -5.695
# 72          72  4XhdM1Ku9JM4abVuRWAsgk         0.619   0.437    4    -7.623
# 73          73  6McBFhOohQvx0zWkoISnap         0.613   0.443    4    -7.502
#
# ...

# %% [markdown]
# # Load Audio Features
# - input clean_audio_features(df)
# - load
# - end

# %%
from google.cloud import bigquery
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "letsgo-snappy-boulder-378707-4b7d46801fd1.json"
# Construct a BigQuery client object.
client = bigquery.Client()

schema = [
    bigquery.SchemaField("id","STRING"),
    bigquery.SchemaField("danceability","FLOAT"),
    bigquery.SchemaField("energy","FLOAT"),
    bigquery.SchemaField("key","INTEGER"),
    bigquery.SchemaField("loudness","FLOAT"),
    bigquery.SchemaField("mode","INTEGER"),
    bigquery.SchemaField("speechiness","FLOAT"),
    bigquery.SchemaField("acousticness","FLOAT"),
    bigquery.SchemaField("instrumentalness","FLOAT"),
    bigquery.SchemaField("liveness","FLOAT"),
    bigquery.SchemaField("valence","FLOAT"),
    bigquery.SchemaField("tempo","FLOAT"),
    bigquery.SchemaField("duration_ms","INTEGER"),
    bigquery.SchemaField("time_signature","INTEGER"),
]

job_config = bigquery.LoadJobConfig(
    schema = schema,
    source_format=bigquery.SourceFormat.CSV,
    skip_leading_rows=1,
    autodetect=True,
)

table_id = "snappy-boulder-378707.NewReleases.NewAudioFeatures"
job = client.load_table_from_dataframe(clean_audio_features, table_id, job_config=job_config)

job.result()  # Waits for the job to complete.

table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
# Loaded 73 rows and 14 columns to snappy-boulder-378707.NewReleases.NewAudioFeatures

# %% [markdown]
# # Extract Artist
# - input clean_albums (df)
# - output new_artists (json)

# %%
type(clean_albums.loc[1,'artists_id'])
# Out:
# list

# %%
artists = []
for i in range(len(clean_albums)):
    artists += clean_albums.loc[i,'artists_id']
new_artists = sp.artists(artists)['artists']
new_artists
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xerUCsurnILh4KpC5FVWX'},
#   'followers': {'href': None, 'total': 121541},
#   'genres': ['indonesian folk', 'indonesian indie'],
#   'href': 'https://api.spotify.com/v1/artists/4xerUCsurnILh4KpC5FVWX',
#   'id': '4xerUCsurnILh4KpC5FVWX',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebdaf081e2786f934575939442',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174daf081e2786f934575939442',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178daf081e2786f934575939442',
#     'width': 160}],
#   'name': 'Elephant Kind',
#   'popularity': 43,
#   'type': 'artist',
#   'uri': 'spotify:artist:4xerUCsurnILh4KpC5FVWX'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Q6X1jqwOVQuclYp2P1bub'},
#   'followers': {'href': None, 'total': 73321},
# ...

# %% [markdown]
# # Clean Artist
# - input new_artists (json)
# - output clean_new_artists (df)

# %%
id = []
name = []
followers = []
popularity = []

for i, artist in enumerate(new_artists):
    id.append(artist['id'])
    name.append(artist['name'])
    followers.append(artist['followers']['total'])
    popularity.append(artist['popularity'])

clean_new_artists = pd.DataFrame({
    'id': id,
    'name': name,
    'followers': followers,
    'popularity': popularity
})

clean_new_artists.drop_duplicates(subset=['id'], inplace=True)
clean_new_artists
# Out:
#                         id              name  followers  popularity
# 0   0X2BH1fck6amBIoJhDVmmJ    Ellie Goulding   11762407          82
# 1   00FQb4jTyendYWaN8pK0wa      Lana Del Rey   21989726          91
# 2   5p7f24Rk5HkUZsaS3BLG5F  Hailee Steinfeld    8502423          73
# 3   4UXqAaa6dQYAk18Lv7PEgX      Fall Out Boy    9885634          81
# 4   45eNHdiiabvmbp4erw26rg          ILLENIUM    1358679          75
# 5   164Uj4eKjl6zTBKfJLFKKK              JVKE    1912859          82
# 6   24V5UY0nChKpnb1TBPJhCw          Jai Wolf     278257          56
# 7   68WwJXWrpo1yVOOIZjLSeT            Evalyn      84964          45
# 8   73BLwSX6gsNeVzS7DgI4xe        grentperez     299107          65
# 9   5pDjmC5mRl7vDJhsjVwNfk     Freya Ridings     338584          65
# 10  2TviQllPVEQ7E68Yr4uPKR            DWLLRS      57923          52
# 11  4MCBfE4596Uoi2O4DtmEMz        Juice WRLD   28308770          91
# 12  56zJ6PZ3mNPBiBqglW2KxL       Peder Elias      38712          58
# ...

# %% [markdown]
# # Load Artist
# - input clean_new_artists (df)
# - load
# - end

# %%
from google.cloud import bigquery
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "letsgo-snappy-boulder-378707-4b7d46801fd1.json"
# Construct a BigQuery client object.
client = bigquery.Client()

schema = [
    bigquery.SchemaField("id","STRING"),
    bigquery.SchemaField("danceability","FLOAT"),
    bigquery.SchemaField("energy","FLOAT"),
    bigquery.SchemaField("key","INTEGER"),
    bigquery.SchemaField("loudness","FLOAT"),
    bigquery.SchemaField("mode","INTEGER"),
    bigquery.SchemaField("speechiness","FLOAT"),
    bigquery.SchemaField("acousticness","FLOAT"),
    bigquery.SchemaField("instrumentalness","FLOAT"),
    bigquery.SchemaField("liveness","FLOAT"),
    bigquery.SchemaField("valence","FLOAT"),
    bigquery.SchemaField("tempo","FLOAT"),
    bigquery.SchemaField("duration_ms","INTEGER"),
    bigquery.SchemaField("time_signature","INTEGER"),
]

job_config = bigquery.LoadJobConfig(
    schema = schema,
    source_format=bigquery.SourceFormat.CSV,
    skip_leading_rows=1,
    autodetect=True,
)

table_id = "snappy-boulder-378707.NewReleases.NewAudioFeatures"
job = client.load_table_from_dataframe(clean_audio_features, table_id, job_config=job_config)

job.result()  # Waits for the job to complete.

table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)

# %% [markdown]
# # Draft

# %%
# album_group, album_type, artists, available_markets, external_urls, href, id, images, name, 
# release_date, release_date_precision, total_tracks, type, uri

# albums is list of dictionaries
# We need: artists, available_markets, id, name, release_date, release_date_precision, total_tracks, popularity(??)

# %%
# artists_id = []
# artists_name = []

# %%
# count = 0
# for i, element in enumerate(new_tracks["albums"]["items"]):
#     album_type.append(element["album_type"])
#     artists.append(element["artists"])
#     available_markets.append(element["available_markets"])
#     external_urls.append(element["external_urls"])
#     href.append(element["href"])
#     id.append(element["id"])
#     images.append(element["images"])
#     name.append(element["name"])
#     release_date.append(element["release_date"])
#     release_date_precision.append(element["release_date_precision"])
#     total_tracks.append(element["total_tracks"])
#     type.append(element["type"])
#     uri.append(element["uri"])
#     temp_id = []
#     temp_name = []
#     for j, artist in enumerate(element["artists"]):
#         temp_id.append(artist["id"])
#         temp_name.append(artist["name"])
#     artists_id.append(temp_id)
#     artists_name.append(temp_name)

# %%
# artists[0]

# %%
# images[0]

# %%
# newly_released_df = pd.DataFrame({"id":id, "album_type":album_type, "artists":artists, "artists_id":artists_id,
#                                  "artists_name":artists_name, "available_markets":available_markets,
#                                  "external_urls":external_urls, "href":href, "images":images, "name":name, 
#                                  "release_date":release_date, "release_date_precision":release_date_precision,
#                                  "total_tracks":total_tracks, "type":type, "uri":uri})
# newly_released_df.head()

# %%
# df = pd.DataFrame({"id":id, "name":name, "artists_name":artists_name, "release_date":release_date})
# df.head()
