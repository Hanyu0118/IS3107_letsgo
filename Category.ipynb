# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
from spotipy.oauth2 import SpotifyOAuth

# %%
credentials = json.load(open('authorization.json'))
client_id = credentials['client_id']
client_secret = credentials['client_secret']

playlist_index = 0

playlists = json.load(open('playlist_like_dislike.json'))
playlist_uri = playlists[playlist_index]['uri']
like = playlists[playlist_index]['like']

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
cats = {}
for i in range(0, 100, 50):
    cats.update(sp.categories(limit=50, offset=i))

# %%
cats

# %%
categories = sp.categories( limit=50, offset=0)
categories
# Out:
# {'categories': {'href': 'https://api.spotify.com/v1/browse/categories?country=SG&offset=0&limit=50',
#   'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists',
#     'icons': [{'height': 275,
#       'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg',
#       'width': 275}],
#     'id': 'toplists',
#     'name': 'Top Lists'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFEC4WFtoNRpw',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/pop-274x274_447148649685019f5e2a03a39e78ba52_0_0_274_274.jpg',
#       'width': 274}],
#     'id': '0JQ5DAqbMKFEC4WFtoNRpw',
#     'name': 'Pop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFx0uLQR2okcc',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/04da469dd7be4dab96659aa1fa9f0ac9.jpeg',
#       'width': None}],
#     'id': '0JQ5DAqbMKFx0uLQR2okcc',
#     'name': 'At Home'},
# ...

# %%
pl = sp.category_playlists(category_id="toplists", limit=50, offset=0)
print(json.dumps(pl, indent=4))
# Out:
# {
#     "playlists": {
#         "href": "https://api.spotify.com/v1/browse/categories/toplists/playlists?country=SG&offset=0&limit=50",
#         "items": [
#             {
#                 "collaborative": false,
#                 "description": "PinkPantheress & Ice Spice are on top of the Hottest 50!",
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M"
#                 },
#                 "href": "https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M",
#                 "id": "37i9dQZF1DXcBWIGoYBM5M",
#                 "images": [
#                     {
#                         "height": null,
#                         "url": "https://i.scdn.co/image/ab67706f00000003ca22ddd6c22c8d2cdbeddc0a",
#                         "width": null
#                     }
#                 ],
#                 "name": "Today's Top Hits",
#                 "owner": {
# ...

# %%
play=[]
for i, t in enumerate(categories["categories"]["items"]):
    try:
        pl = sp.category_playlists(category_id=t['id'], limit=50, offset=0)
        print('total of play list {}'.format(pl["playlists"]["total"]))
        total = int(pl["playlists"]["total"])
        if total <= 50:
            play.append(pl["playlists"]['items'][0])
        else:
            for j in range(0,total,50):
                play.append(sp.category_playlists(category_id=t['id'], limit=50, offset=j)["playlists"]['items'][0])
        print('len of play list {}'.format(len(play)))
    except:
        print(t['id'])
# Out:
# total of play list 13
# len of play list 1
# total of play list 37
# len of play list 2
# total of play list 53
# len of play list 4
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFF1br7dZcRtK/playlists with Params: {'country': None, 'limit': 50, 'offset': 0} returned 404 due to Not found.
# 0JQ5DAqbMKFF1br7dZcRtK
# total of play list 72
# len of play list 6
# total of play list 50
# len of play list 7
# total of play list 55
# len of play list 9
# total of play list 213
# len of play list 14
# total of play list 48
# len of play list 15
# total of play list 98
# len of play list 17
# total of play list 12
# len of play list 18
# total of play list 103
# len of play list 21
# total of play list 82
# len of play list 23
# total of play list 63
# len of play list 25
# total of play list 52
# len of play list 27
# total of play list 139
# len of play list 30
# total of play list 83
# len of play list 32
# total of play list 65
# len of play list 34
# ...

# %%
print(json.dumps(sp.playlist_items('37i9dQZF1DXcBWIGoYBM5M')['items'], indent=4))
len(play)
# Out:
# [
#     {
#         "added_at": "2023-02-17T05:00:00Z",
#         "added_by": {
#             "external_urls": {
#                 "spotify": "https://open.spotify.com/user/"
#             },
#             "href": "https://api.spotify.com/v1/users/",
#             "id": "",
#             "type": "user",
#             "uri": "spotify:user:"
#         },
#         "is_local": false,
#         "primary_color": null,
#         "track": {
#             "album": {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/78rUTD7y6Cy67W1RVzYs7t"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/78rUTD7y6Cy67W1RVzYs7t",
#                         "id": "78rUTD7y6Cy67W1RVzYs7t",
#                         "name": "PinkPantheress",
#                         "type": "artist",
# ...

# %%
sp.playlist_items('37i9dQZF1DXcBWIGoYBM5M')['items']
# Out:
# [{'added_at': '2023-02-17T05:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/78rUTD7y6Cy67W1RVzYs7t'},
#       'href': 'https://api.spotify.com/v1/artists/78rUTD7y6Cy67W1RVzYs7t',
#       'id': '78rUTD7y6Cy67W1RVzYs7t',
#       'name': 'PinkPantheress',
#       'type': 'artist',
#       'uri': 'spotify:artist:78rUTD7y6Cy67W1RVzYs7t'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3LZZPxNDGDFVSIPqf4JuEf'},
#       'href': 'https://api.spotify.com/v1/artists/3LZZPxNDGDFVSIPqf4JuEf',
#       'id': '3LZZPxNDGDFVSIPqf4JuEf',
#       'name': 'Ice Spice',
#       'type': 'artist',
# ...

# %%
track_id=[]
track_name=[]
for i in range(len(play)):
        t = play[i]
        try:
            tracks = sp.playlist_items(t['id'])['items']
            for track in tracks:
                track_id.append(track['track']['id'])
                track_name.append(track['track']['name'])
        except:
             print("None in items")
# Out:
# None in items
# None in items
# None in items
# None in items
# None in items
# None in items

# %%
len(pd.unique(track_id))
# Out:
# 5576
