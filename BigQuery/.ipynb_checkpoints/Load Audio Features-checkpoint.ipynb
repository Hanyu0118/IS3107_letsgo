# %%
from google.cloud import bigquery
import os

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "letsgo-snappy-boulder-378707-4b7d46801fd1.json"

# Construct a BigQuery client object.
client = bigquery.Client()

# %%
dataset_id = "snappy-boulder-378707.AudioFeatures"
dataset = bigquery.Dataset(dataset_id)
dataset.location = "US"
dataset = client.create_dataset(dataset, timeout=30)
print("Created dataset {}.{}".format(client.project, dataset.dataset_id))
# Out:
# Created dataset snappy-boulder-378707.AudioFeatures

# %%
import pandas as pd
pd.read_csv("../Data/audio feat 2017.csv")
# Out:
#        Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0               0         0.852   0.773    8    -2.921     0       0.0776
# 1               1         0.663   0.920   11    -4.070     0       0.2260
# 2               2         0.761   0.838    4    -3.073     0       0.0502
# 3               3         0.508   0.687    0    -4.361     1       0.3260
# 4               4         0.899   0.626    6    -4.228     0       0.2920
# ...           ...           ...     ...  ...       ...   ...          ...
# 40101       40101         0.716   0.955    7    -1.636     1       0.1120
# 40102       40102         0.783   0.618    2   -10.372     1       0.0430
# 40103       40103         0.689   0.909    9    -6.057     0       0.0570
# 40104       40104         0.618   0.348    2    -9.307     1       0.0353
# 40105       40105         0.616   0.834    7    -2.085     1       0.0315
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0           0.18700          0.000030    0.1590    0.907  102.034
# 1           0.00431          0.000017    0.1010    0.533   99.935
# 2           0.40000          0.000000    0.1760    0.710   93.974
# 3           0.55100          0.000003    0.1260    0.555  180.044
# 4           0.07600          0.000000    0.0631    0.873   88.007
# ...             ...               ...       ...      ...      ...
# 40101       0.27200          0.000003    0.4730    0.716   99.001
# 40102       0.53000          0.841000    0.0891    0.664   94.208
# 40103       0.05700          0.000002    0.2570    0.850  143.911
# 40104       0.85400          0.011700    0.0917    0.317  118.612
# 40105       0.00331          0.000010    0.4030    0.440  129.985
#
#                  type                      id  \
# 0      audio_features  6mICuAdrwEjh6Y6lroV2Kg
# 1      audio_features  7DM4BPaS7uofFul3ywMe46
# 2      audio_features  3AEZUABDXNtecAOSC1qTfo
# 3      audio_features  6rQSrBHf7HlZjtcMZ4S4bO
# 4      audio_features  58IL315gMSTD37DOZPJ2hf
# ...               ...                     ...
# 40101  audio_features  1q0Qj0PW7qsfaEvZE0wWsV
# 40102  audio_features  3xesmCtVNLeZiXjNcfs6Tf
# 40103  audio_features  05EypeGQ9wezXtrsgUKjKc
# 40104  audio_features  4pxPlfILTAdqETp6FCfqj7
# 40105  audio_features  6TbcStw9QXDfJQPIhyEXeP
#
#                                         uri  \
# 0      spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 1      spotify:track:7DM4BPaS7uofFul3ywMe46
# 2      spotify:track:3AEZUABDXNtecAOSC1qTfo
# 3      spotify:track:6rQSrBHf7HlZjtcMZ4S4bO
# 4      spotify:track:58IL315gMSTD37DOZPJ2hf
# ...                                     ...
# 40101  spotify:track:1q0Qj0PW7qsfaEvZE0wWsV
# 40102  spotify:track:3xesmCtVNLeZiXjNcfs6Tf
# 40103  spotify:track:05EypeGQ9wezXtrsgUKjKc
# 40104  spotify:track:4pxPlfILTAdqETp6FCfqj7
# 40105  spotify:track:6TbcStw9QXDfJQPIhyEXeP
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 1      https://api.spotify.com/v1/tracks/7DM4BPaS7uof...
# 2      https://api.spotify.com/v1/tracks/3AEZUABDXNte...
# 3      https://api.spotify.com/v1/tracks/6rQSrBHf7HlZ...
# 4      https://api.spotify.com/v1/tracks/58IL315gMSTD...
# ...                                                  ...
# 40101  https://api.spotify.com/v1/tracks/1q0Qj0PW7qsf...
# 40102  https://api.spotify.com/v1/tracks/3xesmCtVNLeZ...
# 40103  https://api.spotify.com/v1/tracks/05EypeGQ9wez...
# 40104  https://api.spotify.com/v1/tracks/4pxPlfILTAdq...
# 40105  https://api.spotify.com/v1/tracks/6TbcStw9QXDf...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/6mIC...       195840
# 1      https://api.spotify.com/v1/audio-analysis/7DM4...       259196
# 2      https://api.spotify.com/v1/audio-analysis/3AEZ...       222560
# 3      https://api.spotify.com/v1/audio-analysis/6rQS...       205600
# 4      https://api.spotify.com/v1/audio-analysis/58IL...       234320
# ...                                                  ...          ...
# 40101  https://api.spotify.com/v1/audio-analysis/1q0Q...       199413
# 40102  https://api.spotify.com/v1/audio-analysis/3xes...       230634
# 40103  https://api.spotify.com/v1/audio-analysis/05Ey...       189385
# 40104  https://api.spotify.com/v1/audio-analysis/4pxP...       252213
# 40105  https://api.spotify.com/v1/audio-analysis/6Tbc...       158769
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 40101               4
# 40102               4
# 40103               4
# 40104               4
# 40105               4
#
# [40106 rows x 19 columns]

# %%
years = [2017, 2018, 2019, 2020, 2021]
schema = [
    bigquery.SchemaField("unnamed","INTEGER"),
    bigquery.SchemaField("danceability",""),
]

for year in years:
    # TODO(developer): Set table_id to the ID of the table to create.
    table_id = "snappy-boulder-378707.TrackClearInfo.AudioFeatures{}".format(year)
    table = bigquery.Table(table_id, schema=schema)
    table = client.create_table(table, timeout=30)  # Make an API request.
    print("Created table {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
