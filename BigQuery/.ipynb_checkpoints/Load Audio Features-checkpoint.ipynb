# %%
from google.cloud import bigquery
import os

# %%
pip install --upgrade google-cloud-BigQuery-storage
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement google-cloud-BigQuery-storage-db-dtypes (from versions: none)
# ERROR: No matching distribution found for google-cloud-BigQuery-storage-db-dtypes

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "letsgo-snappy-boulder-378707-4b7d46801fd1.json"

# Construct a BigQuery client object.
client = bigquery.Client()

# %%
dataset_id = "snappy-boulder-378707.AudioFeatures"
dataset = bigquery.Dataset(dataset_id)
dataset.location = "US"
dataset = client.create_dataset(dataset, timeout=30)
print("Created dataset {}.{}".format(client.project, dataset.dataset_id))
# Out:
# ---------------------------------------------------------------------------
# Conflict                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6536\1341005647.py in <module>
#       2 dataset = bigquery.Dataset(dataset_id)
#       3 dataset.location = "US"
# ----> 4 dataset = client.create_dataset(dataset, timeout=30)
#       5 print("Created dataset {}.{}".format(client.project, dataset.dataset_id))
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\client.py in create_dataset(self, dataset, exists_ok, retry, timeout)
#     645             span_attributes = {"path": path}
#     646
# --> 647             api_response = self._call_api(
#     648                 retry,
#     649                 span_name="BigQuery.createDataset",
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\client.py in _call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
# ...

# %% [markdown]
# # Load data 2017-2021

# %%
import pandas as pd
df = pd.read_csv("../Data/audio feat 2017.csv")

# %%
df
# Out:
#        Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0               0         0.852   0.773    8    -2.921     0       0.0776
# 1               1         0.663   0.920   11    -4.070     0       0.2260
# 2               2         0.761   0.838    4    -3.073     0       0.0502
# 3               3         0.508   0.687    0    -4.361     1       0.3260
# 4               4         0.899   0.626    6    -4.228     0       0.2920
# ...           ...           ...     ...  ...       ...   ...          ...
# 40101       40101         0.716   0.955    7    -1.636     1       0.1120
# 40102       40102         0.783   0.618    2   -10.372     1       0.0430
# 40103       40103         0.689   0.909    9    -6.057     0       0.0570
# 40104       40104         0.618   0.348    2    -9.307     1       0.0353
# 40105       40105         0.616   0.834    7    -2.085     1       0.0315
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df = df.drop(['type', 'uri','track_href','analysis_url'], axis=1)

# %%
df.head(1)
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.852   0.773    8    -2.921     0       0.0776
#
#    acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.187           0.00003     0.159    0.907  102.034
#
#                        id  duration_ms  time_signature
# 0  6mICuAdrwEjh6Y6lroV2Kg       195840               4

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# pip install db-dtypes

# %%
# %%bigquery
# DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2017

# %%
pd.read_csv("../Data/audio feat 2018.csv")
# Out:
#        Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0               0         0.716   0.805    4    -3.839     1       0.0856
# 1               1         0.680   0.693    1    -5.414     1       0.1090
# 2               2         0.727   0.717    0    -6.331     0       0.0788
# 3               3         0.647   0.820    9    -5.312     0       0.0965
# 4               4         0.818   0.572    1    -7.085     1       0.2280
# ...           ...           ...     ...  ...       ...   ...          ...
# 36588       36588         0.521   0.532    6    -6.778     1       0.0302
# 36589       36589         0.525   0.723   11    -5.221     1       0.0346
# 36590       36590         0.471   0.561    5    -7.066     0       0.0414
# 36591       36591         0.806   0.862   11    -5.325     1       0.0783
# 36592       36592         0.558   0.596    9    -8.865     1       0.4190
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
years = [2017, 2018, 2019, 2020, 2021]
schema = [
    bigquery.SchemaField("unnamed","INTEGER"),
    bigquery.SchemaField("danceability","FLOAT"),
    bigquery.SchemaField("energy","FLOAT"),
    bigquery.SchemaField("key","INTEGER"),
    bigquery.SchemaField("loudness","FLOAT"),
    bigquery.SchemaField("mode","INTEGER"),
    bigquery.SchemaField("speechiness","FLOAT"),
    bigquery.SchemaField("acousticness","FLOAT"),
    bigquery.SchemaField("instrumentalness","FLOAT"),
    bigquery.SchemaField("liveness","FLOAT"),
    bigquery.SchemaField("valence","FLOAT"),
    bigquery.SchemaField("tempo","FLOAT"),
    bigquery.SchemaField("type","STRING"),
    bigquery.SchemaField("id","STRING"),
    bigquery.SchemaField("uri","STRING"),
    bigquery.SchemaField("track_href","STRING"),
    bigquery.SchemaField("analysis_url","STRING"),
    bigquery.SchemaField("duration_ms","INTEGER"),
    bigquery.SchemaField("time_signature","INTEGER"),
]

for year in years:
    # TODO(developer): Set table_id to the ID of the table to create.
    table_id = "snappy-boulder-378707.TrackClearInfo.AudioFeatures{}".format(year)
    table = bigquery.Table(table_id, schema=schema)
    table = client.create_table(table, timeout=30)  # Make an API request.
    print("Created table {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Created table snappy-boulder-378707.TrackClearInfo.AudioFeatures2017
# Created table snappy-boulder-378707.TrackClearInfo.AudioFeatures2018
# Created table snappy-boulder-378707.TrackClearInfo.AudioFeatures2019
# Created table snappy-boulder-378707.TrackClearInfo.AudioFeatures2020
# Created table snappy-boulder-378707.TrackClearInfo.AudioFeatures2021

# %%
job_config = bigquery.LoadJobConfig(
    schema = schema,
    source_format=bigquery.SourceFormat.CSV,
    skip_leading_rows=1,
    autodetect=True,
)

for year in years:
    file_path = '../Data/audio feat {}.csv'.format(year)
    table_id = "snappy-boulder-378707.TrackClearInfo.AudioFeatures{}".format(year)

    with open(file_path, "rb") as source_file:
        job = client.load_table_from_file(source_file, table_id, job_config=job_config)

    job.result()  # Waits for the job to complete.

    table = client.get_table(table_id)  # Make an API request.
    print(
        "Loaded {} rows and {} columns to {}".format(
            table.num_rows, len(table.schema), table_id
        )
    )
# Out:
# Loaded 40106 rows and 19 columns to snappy-boulder-378707.TrackClearInfo.AudioFeatures2017
# Loaded 36593 rows and 19 columns to snappy-boulder-378707.TrackClearInfo.AudioFeatures2018
# Loaded 27657 rows and 19 columns to snappy-boulder-378707.TrackClearInfo.AudioFeatures2019
# Loaded 32415 rows and 19 columns to snappy-boulder-378707.TrackClearInfo.AudioFeatures2020
# Loaded 28013 rows and 19 columns to snappy-boulder-378707.TrackClearInfo.AudioFeatures2021

# %% [markdown]
# # Join to audiofeaturestrain

# %%
schema = [
    bigquery.SchemaField("danceability","FLOAT"),
    bigquery.SchemaField("energy","FLOAT"),
    bigquery.SchemaField("key","INTEGER"),
    bigquery.SchemaField("loudness","FLOAT"),
    bigquery.SchemaField("mode","INTEGER"),
    bigquery.SchemaField("speechiness","FLOAT"),
    bigquery.SchemaField("acousticness","FLOAT"),
    bigquery.SchemaField("instrumentalness","FLOAT"),
    bigquery.SchemaField("liveness","FLOAT"),
    bigquery.SchemaField("valence","FLOAT"),
    bigquery.SchemaField("tempo","FLOAT"),
    bigquery.SchemaField("id","STRING"),
    bigquery.SchemaField("duration_ms","INTEGER"),
    bigquery.SchemaField("time_signature","INTEGER"),
]

# TODO(developer): Set table_id to the ID of the table to create.
table_id = "snappy-boulder-378707.TrackClearInfo.AudioFeaturesTrain"
table = bigquery.Table(table_id, schema=schema)
table = client.create_table(table, timeout=30)  # Make an API request.
print("Created table {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Created table snappy-boulder-378707.TrackClearInfo.AudioFeaturesTrain

# %%
# %%bigquery
# INSERT INTO snappy-boulder-378707.TrackClearInfo.AudioFeaturesTrain
# SELECT *
# FROM
# (
#     SELECT danceability,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,tempo,id,duration_ms,time_signature
#     FROM snappy-boulder-378707.TrackClearInfo.AudioFeatures2017
#     UNION ALL
#     SELECT danceability,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,tempo,id,duration_ms,time_signature
#     FROM snappy-boulder-378707.TrackClearInfo.AudioFeatures2018
#     UNION ALL
#     SELECT danceability,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,tempo,id,duration_ms,time_signature
#     FROM snappy-boulder-378707.TrackClearInfo.AudioFeatures2019
#     UNION ALL
#     SELECT danceability,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,tempo,id,duration_ms,time_signature
#     FROM snappy-boulder-378707.TrackClearInfo.AudioFeatures2020
#     UNION ALL
#     SELECT danceability,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,tempo,id,duration_ms,time_signature
#     FROM snappy-boulder-378707.TrackClearInfo.AudioFeatures2021
# ) a
# Out:
# Query is running:   0%|          |
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in <module>
#      40 try:
# ---> 41     import db_dtypes  # type: ignore
#      42
#
# ModuleNotFoundError: No module named 'db_dtypes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6536\2794771854.py in <module>
# ...

# %%
# %%bigquery
# DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2017
# Out:
# Query is running:   0%|          |
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in <module>
#      40 try:
# ---> 41     import db_dtypes  # type: ignore
#      42
#
# ModuleNotFoundError: No module named 'db_dtypes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6536\550694162.py in <module>
# ----> 1 get_ipython().run_cell_magic('bigquery', '', 'DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2017\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# ...

# %%
# %%bigquery
# DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2018
# Out:
# Query is running:   0%|          |
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in <module>
#      40 try:
# ---> 41     import db_dtypes  # type: ignore
#      42
#
# ModuleNotFoundError: No module named 'db_dtypes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6536\347049821.py in <module>
# ----> 1 get_ipython().run_cell_magic('bigquery', '', 'DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2018\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# ...

# %%
# %%bigquery
# DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2019
# Out:
# Query is running:   0%|          |
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in <module>
#      40 try:
# ---> 41     import db_dtypes  # type: ignore
#      42
#
# ModuleNotFoundError: No module named 'db_dtypes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6536\55684245.py in <module>
# ----> 1 get_ipython().run_cell_magic('bigquery', '', 'DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2019\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# ...

# %%
# %%bigquery
# DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2020
# Out:
# Query is running:   0%|          |
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in <module>
#      40 try:
# ---> 41     import db_dtypes  # type: ignore
#      42
#
# ModuleNotFoundError: No module named 'db_dtypes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6536\2961151653.py in <module>
# ----> 1 get_ipython().run_cell_magic('bigquery', '', 'DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2020\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# ...

# %%
# %%bigquery
# DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2021
# Out:
# Query is running:   0%|          |
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in <module>
#      40 try:
# ---> 41     import db_dtypes  # type: ignore
#      42
#
# ModuleNotFoundError: No module named 'db_dtypes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6536\3593473649.py in <module>
# ----> 1 get_ipython().run_cell_magic('bigquery', '', 'DROP TABLE snappy-boulder-378707.TrackClearInfo.AudioFeatures2021\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# ...

# %%
# %%bigquery
# ALTER TABLE snappy-boulder-378707.TrackClearInfo.AudioFeaturesTrain
# ADD PRIMARY KEY (id) NOT ENFORCED
# Out:
# Query is running:   0%|          |
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in <module>
#      40 try:
# ---> 41     import db_dtypes  # type: ignore
#      42
#
# ModuleNotFoundError: No module named 'db_dtypes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6536\2527809845.py in <module>
# ----> 1 get_ipython().run_cell_magic('bigquery', '', 'ALTER TABLE snappy-boulder-378707.TrackClearInfo.AudioFeaturesTrain\nADD PRIMARY KEY (id) NOT ENFORCED\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# ...
