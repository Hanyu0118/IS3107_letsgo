# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
from spotipy.oauth2 import SpotifyOAuth

# %% [markdown]
# ### Chart Data Remove Duplicate & Output Ids

# %%
data = pd.read_csv("charts.csv")
data
# Out:
#                                   title  rank        date  \
# 0               Chantaje (feat. Maluma)     1  2017-01-01
# 1           Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2            Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                                Safari     4  2017-01-01
# 4                           Shaky Shaky     5  2017-01-01
# ...                                 ...   ...         ...
# 26173509                            BYE    46  2021-07-31
# 26173510                        Pillars    47  2021-07-31
# 26173511                   Gái Độc Thân    48  2021-07-31
# 26173512  Renegade (feat. Taylor Swift)    49  2021-07-31
# 26173513                Letter to Jarad    50  2021-07-31
#
#                                          artist  \
# 0                                       Shakira
# 1                                  Ricky Martin
# 2                                          CNCO
# 3         J Balvin, Pharrell Williams, BIA, Sky
# 4                                  Daddy Yankee
# ...                                         ...
# 26173509                                  Jaden
# 26173510                                 My Anh
# 26173511                                  Tlinh
# 26173512                        Big Red Machine
# 26173513              LRN Slime, Shiloh Dynasty
#
#                                                         url     region  \
# 0         https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina
# 1         https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina
# 2         https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina
# 3         https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina
# 4         https://open.spotify.com/track/58IL315gMSTD37D...  Argentina
# ...                                                     ...        ...
# 26173509  https://open.spotify.com/track/3OUyyDN7EZrL7i0...    Vietnam
# 26173510  https://open.spotify.com/track/6eky30oFiQbHUAT...    Vietnam
# 26173511  https://open.spotify.com/track/2klsSb2iTfgDh95...    Vietnam
# 26173512  https://open.spotify.com/track/1aU1wpYBSpP0M6I...    Vietnam
# 26173513  https://open.spotify.com/track/508QhA2SncMbh5C...    Vietnam
#
#             chart          trend   streams
# 0          top200  SAME_POSITION  253019.0
# 1          top200        MOVE_UP  223988.0
# 2          top200      MOVE_DOWN  210943.0
# 3          top200  SAME_POSITION  173865.0
# 4          top200        MOVE_UP  153956.0
# ...           ...            ...       ...
# 26173509  viral50        MOVE_UP       NaN
# 26173510  viral50      NEW_ENTRY       NaN
# 26173511  viral50      MOVE_DOWN       NaN
# 26173512  viral50      MOVE_DOWN       NaN
# 26173513  viral50      MOVE_DOWN       NaN
#
# [26173514 rows x 9 columns]

# %%
songs = data.drop_duplicates(subset=['title'])
songs.reset_index(inplace=True, drop=True)
songs
# Out:
#                                              title  rank        date  \
# 0                          Chantaje (feat. Maluma)     1  2017-01-01
# 1                      Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2                       Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                                           Safari     4  2017-01-01
# 4                                      Shaky Shaky     5  2017-01-01
# ...                                            ...   ...         ...
# 164802                                      めちゃくちゃ    50  2021-07-27
# 164803                              Gris Atardecer    20  2021-07-28
# 164804                           Imparfait inconnu    28  2021-07-28
# 164805  Still Holy (feat. Ryan Ofei & Naomi Raine)    47  2021-07-28
# 164806                                          怎叹    48  2021-07-29
#
#                                        artist  \
# 0                                     Shakira
# 1                                Ricky Martin
# 2                                        CNCO
# 3       J Balvin, Pharrell Williams, BIA, Sky
# 4                                Daddy Yankee
# ...                                       ...
# 164802                               vvpskvd.
# 164803                         Los Visitantes
# 164804                                    Adé
# 164805             Tribl, Maverick City Music
# 164806                                     郑鱼
#
#                                                       url        region  \
# 0       https://open.spotify.com/track/6mICuAdrwEjh6Y6...     Argentina
# 1       https://open.spotify.com/track/7DM4BPaS7uofFul...     Argentina
# 2       https://open.spotify.com/track/3AEZUABDXNtecAO...     Argentina
# 3       https://open.spotify.com/track/6rQSrBHf7HlZjtc...     Argentina
# 4       https://open.spotify.com/track/58IL315gMSTD37D...     Argentina
# ...                                                   ...           ...
# 164802  https://open.spotify.com/track/0u0ipbfDa5uKTdG...       Ukraine
# 164803  https://open.spotify.com/track/5vsdlfsRw5SEayU...     Argentina
# 164804  https://open.spotify.com/track/3W7x967esdawMwz...        France
# 164805  https://open.spotify.com/track/4Cw36mfQ1z4JnjF...  South Africa
# 164806  https://open.spotify.com/track/02jBlxoKmrSXrHE...     Singapore
#
#           chart          trend   streams
# 0        top200  SAME_POSITION  253019.0
# 1        top200        MOVE_UP  223988.0
# 2        top200      MOVE_DOWN  210943.0
# 3        top200  SAME_POSITION  173865.0
# 4        top200        MOVE_UP  153956.0
# ...         ...            ...       ...
# 164802  viral50      NEW_ENTRY       NaN
# 164803  viral50      NEW_ENTRY       NaN
# 164804  viral50      NEW_ENTRY       NaN
# 164805  viral50      NEW_ENTRY       NaN
# 164806  viral50      NEW_ENTRY       NaN
#
# [164807 rows x 9 columns]

# %%
list(songs.columns)
# Out:
# ['title',
#  'rank',
#  'date',
#  'artist',
#  'url',
#  'region',
#  'chart',
#  'trend',
#  'streams']

# %%
songs['date_formatted'] = pd.to_datetime(songs['date'], format="%Y-%m-%d")
songs['year'] = songs['date_formatted'].dt.year
songs
# Out:
# C:\Users\12560\AppData\Local\Temp\ipykernel_5496\2122764647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   songs['date_formatted'] = pd.to_datetime(songs['date'], format="%Y-%m-%d")
# C:\Users\12560\AppData\Local\Temp\ipykernel_5496\2122764647.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   songs['year'] = songs['date_formatted'].dt.year
#                                              title  rank        date  \
# 0                          Chantaje (feat. Maluma)     1  2017-01-01
# 1                      Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2                       Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                                           Safari     4  2017-01-01
# 4                                      Shaky Shaky     5  2017-01-01
# ...                                            ...   ...         ...
# 164802                                      めちゃくちゃ    50  2021-07-27
# 164803                              Gris Atardecer    20  2021-07-28
# 164804                           Imparfait inconnu    28  2021-07-28
# 164805  Still Holy (feat. Ryan Ofei & Naomi Raine)    47  2021-07-28
# 164806                                          怎叹    48  2021-07-29
#
#                                        artist  \
# 0                                     Shakira
# 1                                Ricky Martin
# 2                                        CNCO
# 3       J Balvin, Pharrell Williams, BIA, Sky
# 4                                Daddy Yankee
# ...                                       ...
# 164802                               vvpskvd.
# 164803                         Los Visitantes
# 164804                                    Adé
# 164805             Tribl, Maverick City Music
# 164806                                     郑鱼
#
#                                                       url        region  \
# 0       https://open.spotify.com/track/6mICuAdrwEjh6Y6...     Argentina
# 1       https://open.spotify.com/track/7DM4BPaS7uofFul...     Argentina
# 2       https://open.spotify.com/track/3AEZUABDXNtecAO...     Argentina
# 3       https://open.spotify.com/track/6rQSrBHf7HlZjtc...     Argentina
# 4       https://open.spotify.com/track/58IL315gMSTD37D...     Argentina
# ...                                                   ...           ...
# 164802  https://open.spotify.com/track/0u0ipbfDa5uKTdG...       Ukraine
# 164803  https://open.spotify.com/track/5vsdlfsRw5SEayU...     Argentina
# 164804  https://open.spotify.com/track/3W7x967esdawMwz...        France
# 164805  https://open.spotify.com/track/4Cw36mfQ1z4JnjF...  South Africa
# 164806  https://open.spotify.com/track/02jBlxoKmrSXrHE...     Singapore
#
#           chart          trend   streams date_formatted  year
# 0        top200  SAME_POSITION  253019.0     2017-01-01  2017
# 1        top200        MOVE_UP  223988.0     2017-01-01  2017
# 2        top200      MOVE_DOWN  210943.0     2017-01-01  2017
# 3        top200  SAME_POSITION  173865.0     2017-01-01  2017
# 4        top200        MOVE_UP  153956.0     2017-01-01  2017
# ...         ...            ...       ...            ...   ...
# 164802  viral50      NEW_ENTRY       NaN     2021-07-27  2021
# 164803  viral50      NEW_ENTRY       NaN     2021-07-28  2021
# 164804  viral50      NEW_ENTRY       NaN     2021-07-28  2021
# 164805  viral50      NEW_ENTRY       NaN     2021-07-28  2021
# 164806  viral50      NEW_ENTRY       NaN     2021-07-29  2021
#
# [164807 rows x 11 columns]

# %%
for year in pd.unique(songs['year']):
    url = songs[songs['year'] == year][['title','date_formatted','url']]
    url.reset_index(inplace=True, drop=True)
    url.to_csv('Songs URL {}.csv'.format(year), index=False)

# %% [markdown]
# ### Credential

# %%
credentials = json.load(open('authorization.json'))
client_id = credentials['client_id']
client_secret = credentials['client_secret']

# playlist_index = 0

# playlists = json.load(open('playlist_like_dislike.json'))
# playlist_uri = playlists[playlist_index]['uri']
# like = playlists[playlist_index]['like']

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp

# %% [markdown]
# ### Read URLs

# %%
years = [2017, 2018, 2019, 2020, 2021]
url_years = {}
for year in years:
    df = pd.read_csv("Data/Songs URL {}.csv".format(year))
    df = pd.DataFrame(df)
    df['id'] = df.apply(lambda x: x['url'].split("/")[-1],axis=1)
    url_years[year] = df

# %% [markdown]
# ### 1. Tracks Information
# To avoid failure due to connection problems, etc. pull the data one year after one year

# %% [markdown]
# #### 2017

# %%
year = 2017
url = url_years[year]
len(url)
# Out:
# 40111

# %%
tracks = []
for i in range(0, len(url), 50):
    try:
        if (i+50) < len(url): 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
    except:
            client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
            sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=5, retries=5)
    finally:
        if (i+50) < len(url): 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
        tracks += info

# %%
tracks_df = pd.DataFrame(tracks)
tracks_df.to_csv('tracks info {}.csv'.format(year))
print('{} done'.format(year))
# Out:
# 2017 done

# %% [markdown]
# #### 2018

# %%
year = 2018
url = url_years[year]
len(url)
# Out:
# 36596

# %%
tracks = []
for i in range(0, 20000, 50):
    try:
        if (i+50) < 20000: 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
    except:
            client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
            sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=5, retries=5)
    finally:
        if (i+50) < len(url): 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
        tracks += info

# %%
for i in range(20000, len(url), 50):
    try:
        if (i+50) < len(url): 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
    except:
            client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
            sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=5, retries=5)
    finally:
        if (i+50) < len(url): 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
        tracks += info

# %%
tracks_df = pd.DataFrame(tracks)
tracks_df.to_csv('tracks info {}.csv'.format(year))
print('{} done'.format(year))
# Out:
# 2018 done

# %% [markdown]
# #### 2019

# %%
year = 2019
url = url_years[year]
len(url)
# Out:
# 27658

# %%
tracks = []
for i in range(0, len(url), 50):
    try:
        if (i+50) < len(url): 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
    except:
            client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
            sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=5, retries=5)
    finally:
        if (i+50) < len(url): 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
        tracks += info

# %%
tracks_df = pd.DataFrame(tracks)
tracks_df.to_csv('tracks info {}.csv'.format(year))
print('{} done'.format(year))
# Out:
# 2019 done

# %% [markdown]
# #### 2020

# %%
url_2020 = url_years[2020]
tracks_info = []
for i in range(0, 10000, 50):
    if (i+50) < len(url_2020): 
        tracks_info += sp.tracks(list(url_2020.iloc[i:(i+50)]['id']))['tracks']
    else:
        tracks_info += sp.tracks(list(url_2020.iloc[i:]['id']))['tracks']

# %%
pd.DataFrame(tracks_info).to_csv("sample_info.csv")

# %%
tracks = []
for i in range(0, len(url_2020), 50):
    try:
        if (i+50) < len(url_2020): 
            info = sp.tracks(list(url_2020.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url_2020.iloc[i:]['id']))['tracks']
    except:
            client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
            sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=5, retries=5)
    finally:
        if (i+50) < len(url_2020): 
            info = sp.tracks(list(url_2020.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url_2020.iloc[i:]['id']))['tracks']
        tracks += info

# %%
tracks_df = pd.DataFrame(tracks)
tracks_df.to_csv('tracks info 2020.csv')

# %% [markdown]
# #### 2021

# %%
year = 2021
url = url_years[year]
len(url)
# Out:
# 28024

# %%
tracks = []
for i in range(0, len(url), 50):
    try:
        if (i+50) < len(url): 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
    except:
            client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
            sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=5, retries=5)
    finally:
        if (i+50) < len(url): 
            info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
        else:
            info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
        tracks += info

# %%
tracks_df = pd.DataFrame(tracks)
tracks_df.to_csv('tracks info {}.csv'.format(year))
print('{} done'.format(year))
# Out:
# 2021 done

# %% [markdown]
# ### 2. Audio Features

# %%
for year in years:
    url = url_years[year]
    audio_feat=[]
    for i in range(0, len(url), 100):
        if (i+100) < len(url): 
            audio_feat += list(sp.audio_features(list(url.iloc[i:(i+100)]['id'])))
        else:
            audio_feat += list(sp.audio_features(list(url.iloc[i:]['id'])))
    # Deal with None objects
    audio_feat = list(filter(lambda x: x is not None, audio_feat))
    audio_feat_df = pd.DataFrame(audio_feat)
    audio_feat_df.to_csv('audio feat {}.csv'.format(year))
    print("{} done".format(year))
# Out:
# 2017 done
# 2018 done
# 2019 done
# 2020 done
# 2021 done

# %% [markdown]
# ### Try artist & album

# %%
years = [2017, 2018, 2019, 2020, 2021]
# album: [id, name, total_available_markets, total_tracks, genres, popularity]
# artist: [id, name, number of total followers, genres, popularity]

for year in years:
    url = url_years[year]
    print(len(url))
    tid = []
    albums = []
    artists = []
    for i in range(0, len(url), 50):
        try:
            if (i+50) < len(url): 
                info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
            else:
                info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
        except:
                client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
                sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=5, retries=5)
        finally:
            if (i+50) < len(url): 
                info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
            else:
                info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
            for t in info:
                tid.append(t['id'])
                albums.append(t['album']['id'])
                artists.append([x['id'] for x in t['artists']])
    pd.DataFrame({'track_id':tid, 'album_id': albums, 'artists_id': artists}).to_csv(f'Data/ids {year}.csv')
    print(f"{year} done")
# Out:
# 40111
# 2017 done
# 36596
# 2018 done
# 27658
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 24
#      22     info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
#      23 for t in info:
# ---> 24     tid.append(t['id'])
#      25     albums.append(t['album']['id'])
#      26     artists.append([x['id'] for x in t['artists']])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
years = [2019, 2020, 2021]
for year in years:
    url = url_years[year]
    print(len(url))
    tid = []
    albums = []
    artists = []
    for i in range(0, len(url), 50):
        try:
            print(i)
            if (i+50) < len(url): 
                info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
            else:
                info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
        except:
                client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
                sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=5, retries=5)
        finally:
            if (i+50) < len(url): 
                info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
            else:
                info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
            for t in info:
                
                tid.append(t['id'])
                albums.append(t['album']['id'])
                artists.append([x['id'] for x in t['artists']])
    pd.DataFrame({'track_id':tid, 'album_id': albums, 'artists_id': artists}).to_csv(f'Data/ids {year}.csv')
    print(f"{year} done")
# Out:
# 27658
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 10050
# 10100
# 10150
# 10200
# 10250
# 10300
# 10350
# 10400
# 10450
# 10500
# 10550
# 10600
# 10650
# 10700
# 10750
# 10800
# 10850
# 10900
# 10950
# 11000
# 11050
# 11100
# 11150
# 11200
# 11250
# 11300
# 11350
# 11400
# 11450
# 11500
# 11550
# 11600
# 11650
# 11700
# 11750
# 11800
# 11850
# 11900
# 11950
# 12000
# 12050
# 12100
# 12150
# 12200
# 12250
# 12300
# 12350
# 12400
# 12450
# 12500
# 12550
# 12600
# 12650
# 12700
# 12750
# 12800
# 12850
# 12900
# 12950
# 13000
# 13050
# 13100
# 13150
# 13200
# 13250
# 13300
# 13350
# 13400
# 13450
# 13500
# 13550
# 13600
# 13650
# 13700
# 13750
# 13800
# 13850
# 13900
# 13950
# 14000
# 14050
# 14100
# 14150
# 14200
# 14250
# 14300
# 14350
# 14400
# 14450
# 14500
# 14550
# 14600
# 14650
# 14700
# 14750
# 14800
# 14850
# 14900
# 14950
# 15000
# 15050
# 15100
# 15150
# 15200
# 15250
# 15300
# 15350
# 15400
# 15450
# 15500
# 15550
# 15600
# 15650
# 15700
# 15750
# 15800
# 15850
# 15900
# 15950
# 16000
# 16050
# 16100
# 16150
# 16200
# 16250
# 16300
# 16350
# 16400
# 16450
# 16500
# 16550
# 16600
# 16650
# 16700
# 16750
# 16800
# 16850
# 16900
# 16950
# 17000
# 17050
# 17100
# 17150
# 17200
# 17250
# 17300
# 17350
# 17400
# 17450
# 17500
# 17550
# 17600
# 17650
# 17700
# 17750
# 17800
# 17850
# 17900
# 17950
# 18000
# 18050
# 18100
# 18150
# 18200
# 18250
# 18300
# 18350
# 18400
# 18450
# 18500
# 18550
# 18600
# 18650
# 18700
# 18750
# 18800
# 18850
# 18900
# 18950
# 19000
# 19050
# 19100
# 19150
# 19200
# 19250
# 19300
# 19350
# 19400
# 19450
# 19500
# 19550
# 19600
# 19650
# 19700
# 19750
# 19800
# 19850
# 19900
# 19950
# 20000
# 20050
# 20100
# 20150
# 20200
# 20250
# 20300
# 20350
# 20400
# 20450
# 20500
# 20550
# 20600
# 20650
# 20700
# 20750
# 20800
# 20850
# 20900
# 20950
# 21000
# 21050
# 21100
# 21150
# 21200
# 21250
# 21300
# 21350
# 21400
# 21450
# 21500
# 21550
# 21600
# 21650
# 21700
# 21750
# 21800
# 21850
# 21900
# 21950
# 22000
# 22050
# 22100
# 22150
# 22200
# 22250
# 22300
# 22350
# 22400
# 22450
# 22500
# 22550
# 22600
# 22650
# 22700
# 22750
# 22800
# 22850
# 22900
# 22950
# 23000
# 23050
# 23100
# 23150
# 23200
# 23250
# 23300
# 23350
# 23400
# 23450
# 23500
# 23550
# 23600
# 23650
# 23700
# 23750
# 23800
# 23850
# 23900
# 23950
# 24000
# 24050
# 24100
# 24150
# 24200
# 24250
# 24300
# 24350
# 24400
# 24450
# 24500
# 18050
# 18100
# 18150
# 18200
# 18250
# 18300
# 18350
# 18400
# 18450
# 18500
# 18550
# 18600
# 18650
# 18700
# 18750
# 18800
# 18850
# 18900
# 18950
# 19000
# 19050
# 19100
# 19150
# 19200
# 19250
# 19300
# 19350
# 19400
# 19450
# 19500
# 19550
# 19600
# 19650
# 19700
# 19750
# 19800
# 19850
# 19900
# 19950
# 20000
# 20050
# 20100
# 20150
# 20200
# 20250
# 20300
# 20350
# 20400
# 20450
# 20500
# 20550
# 20600
# 20650
# 20700
# 20750
# 20800
# 20850
# 20900
# 20950
# 21000
# 21050
# 21100
# 21150
# 21200
# 21250
# 21300
# 21350
# 21400
# 21450
# 21500
# 21550
# 21600
# 21650
# 21700
# 21750
# 21800
# 21850
# 21900
# 21950
# 22000
# 22050
# 22100
# 22150
# 22200
# 22250
# 22300
# 22350
# 22400
# 22450
# 22500
# 22550
# 22600
# 22650
# 22700
# 22750
# 22800
# 22850
# 22900
# 22950
# 23000
# 23050
# 23100
# 23150
# 23200
# 23250
# 23300
# 23350
# 23400
# 23450
# 23500
# 23550
# 23600
# 23650
# 23700
# 23750
# 23800
# 23850
# 23900
# 23950
# 24000
# 24050
# 24100
# 24150
# 24200
# 24250
# 24300
# 24350
# 24400
# 24450
# 24500
# 24550
# 24600
# 24650
# 24700
# 24750
# 24800
# 24850
# 24900
# 24950
# 25000
# 25050
# 25100
# 25150
# 25200
# 25250
# 25300
# 25350
# 25400
# 25450
# 25500
# 25550
# 25600
# 25650
# 25700
# 25750
# 25800
# 25850
# 25900
# 25950
# 26000
# 26050
# 26100
# 26150
# 26200
# 26250
# 26300
# 26350
# 26400
# 26450
# 26500
# 26550
# 26600
# 26650
# 26700
# 26750
# 26800
# 26850
# 26900
# 26950
# 27000
# 27050
# 27100
# 27150
# 27200
# 27250
# 27300
# 27350
# 27400
# 27450
# 27500
# 27550
# 27600
# 27650
# 27700
# 27750
# 27800
# 27850
# 27900
# 27950
# 28000
# 2021 done

# %%
sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks'][0]
# Out:
# {'album': {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Ga1P7PMIsmqEZqhYZQgDo'},
#     'href': 'https://api.spotify.com/v1/artists/4Ga1P7PMIsmqEZqhYZQgDo',
#     'id': '4Ga1P7PMIsmqEZqhYZQgDo',
#     'name': 'Lil Tecca',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Ga1P7PMIsmqEZqhYZQgDo'}],
#   'available_markets': [],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/65T18oWoikW2MAilg9j8lW'},
#   'href': 'https://api.spotify.com/v1/albums/65T18oWoikW2MAilg9j8lW',
#   'id': '65T18oWoikW2MAilg9j8lW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27334cf953f3b4e965c1559dabe',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0234cf953f3b4e965c1559dabe',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485134cf953f3b4e965c1559dabe',
#     'width': 64}],
#   'name': 'We Love You Tecca',
#   'release_date': '2019-08-30',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:65T18oWoikW2MAilg9j8lW'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Ga1P7PMIsmqEZqhYZQgDo'},
#    'href': 'https://api.spotify.com/v1/artists/4Ga1P7PMIsmqEZqhYZQgDo',
#    'id': '4Ga1P7PMIsmqEZqhYZQgDo',
#    'name': 'Lil Tecca',
#    'type': 'artist',
#    'uri': 'spotify:artist:4Ga1P7PMIsmqEZqhYZQgDo'}],
#  'available_markets': [],
#  'disc_number': 1,
#  'duration_ms': 131240,
#  'explicit': True,
#  'external_ids': {'isrc': 'QZ85M1940160'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6EOKwHETwSkZ9gW2b6ASE0'},
#  'href': 'https://api.spotify.com/v1/tracks/6EOKwHETwSkZ9gW2b6ASE0',
#  'id': '6EOKwHETwSkZ9gW2b6ASE0',
#  'is_local': False,
#  'name': 'Ransom',
#  'popularity': 3,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:6EOKwHETwSkZ9gW2b6ASE0'}

# %% [markdown]
# ### Trash

# %%
# album: [id, name, total_available_markets, total_tracks, genres, popularity]
# artist: [id, name, number of total followers, genres, popularity]

for year in years:
    url = url_years[year]
    print(len(url))
    tid = []
    
    # albums
    albums = {
        'id' = [],
        'name' = [],
        'num_markets' = [],
        'num_tracks' = [],
        'genres' = [],
        'popularity' = []
             }
    # artists
    artists = {
        'id' = [],
        'name' = [],
        'num_followers' = [],
        'genres' = [],
        'popularity' = []
    }
    
    for i in range(0, len(url), 50):
        try:
            if (i+50) < len(url): 
                info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
            else:
                info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
        except:
                client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
                sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=5, retries=5)
        finally:
            if (i+50) < len(url): 
                info = sp.tracks(list(url.iloc[i:(i+50)]['id']))['tracks']
            else:
                info = sp.tracks(list(url.iloc[i:]['id']))['tracks']
            for t in info:
                tid.append(t['id'])
                albums['id'].append(t['album']['id'])
                albums['name'].append(t['album']['name'])
                albums['num_markets'].append(len(t['available_markets']))
                albums['num_tracks'].append(t['album']['total_tracks'])
                albums['genres'].append(t['album'][0]['name'])
                artists += t['artists']
            break
    print(pd.DataFrame(albums))
    #pd.concat([pd.DataFrame(tid),pd.DataFrame({'album': albums})], axis=1).to_csv(f'Data/try {year}.csv')
    print(f"{year} done")
    break
# Out:
# 27658
#     album_group   album_type  \
# 0         album        album
# 1        single       single
# 2        single       single
# 3        single       single
# 4        single       single
# 5   compilation  compilation
# 6        single       single
# 7        single       single
# 8        single       single
# 9         album        album
# 10       single       single
# 11       single       single
# 12       single       single
# 13        album        album
# 14        album        album
# 15        album        album
# 16       single       single
# 17  compilation  compilation
# 18  compilation  compilation
# 19        album        album
# 20       single       single
# 21       single       single
# 22        album        album
# 23       single       single
# 24        album        album
# 25        album        album
# 26       single       single
# 27        album        album
# 28  compilation  compilation
# 29        album        album
# 30       single       single
# 31        album        album
# 32       single       single
# 33        album        album
# 34       single       single
# 35        album        album
# 36        album        album
# 37       single       single
# 38        album        album
# 39        album        album
# 40        album        album
# 41        album        album
# 42  compilation  compilation
# 43       single       single
# 44       single       single
# 45       single       single
# 46       single       single
# 47       single       single
# 48       single       single
# 49        album        album
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
# 20  [{'external_urls': {'spotify': 'https://open.s...
# 21  [{'external_urls': {'spotify': 'https://open.s...
# 22  [{'external_urls': {'spotify': 'https://open.s...
# 23  [{'external_urls': {'spotify': 'https://open.s...
# 24  [{'external_urls': {'spotify': 'https://open.s...
# 25  [{'external_urls': {'spotify': 'https://open.s...
# 26  [{'external_urls': {'spotify': 'https://open.s...
# 27  [{'external_urls': {'spotify': 'https://open.s...
# 28  [{'external_urls': {'spotify': 'https://open.s...
# 29  [{'external_urls': {'spotify': 'https://open.s...
# 30  [{'external_urls': {'spotify': 'https://open.s...
# 31  [{'external_urls': {'spotify': 'https://open.s...
# 32  [{'external_urls': {'spotify': 'https://open.s...
# 33  [{'external_urls': {'spotify': 'https://open.s...
# 34  [{'external_urls': {'spotify': 'https://open.s...
# 35  [{'external_urls': {'spotify': 'https://open.s...
# 36  [{'external_urls': {'spotify': 'https://open.s...
# 37  [{'external_urls': {'spotify': 'https://open.s...
# 38  [{'external_urls': {'spotify': 'https://open.s...
# 39  [{'external_urls': {'spotify': 'https://open.s...
# 40  [{'external_urls': {'spotify': 'https://open.s...
# 41  [{'external_urls': {'spotify': 'https://open.s...
# 42  [{'external_urls': {'spotify': 'https://open.s...
# 43  [{'external_urls': {'spotify': 'https://open.s...
# 44  [{'external_urls': {'spotify': 'https://open.s...
# 45  [{'external_urls': {'spotify': 'https://open.s...
# 46  [{'external_urls': {'spotify': 'https://open.s...
# 47  [{'external_urls': {'spotify': 'https://open.s...
# 48  [{'external_urls': {'spotify': 'https://open.s...
# 49  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  \
# 0                                                  []
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 9   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 10                                                 []
# 11  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 17  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 18  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 19                                                 []
# 20  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 26                                                 []
# 27  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 28                                                 []
# 29  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 30  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 31  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 32                                                 []
# 33  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 34                                           [GB, IE]
# 35  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 36  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 37  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 38  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 39  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 40  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 41                                                 []
# 42  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 43  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 44                                                 []
# 45  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 46                                                 []
# 47                                                 []
# 48                                                 []
# 49  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/album/65...
# 1   {'spotify': 'https://open.spotify.com/album/5e...
# 2   {'spotify': 'https://open.spotify.com/album/0s...
# 3   {'spotify': 'https://open.spotify.com/album/1f...
# 4   {'spotify': 'https://open.spotify.com/album/2y...
# 5   {'spotify': 'https://open.spotify.com/album/2m...
# 6   {'spotify': 'https://open.spotify.com/album/1a...
# 7   {'spotify': 'https://open.spotify.com/album/1F...
# 8   {'spotify': 'https://open.spotify.com/album/2V...
# 9   {'spotify': 'https://open.spotify.com/album/4z...
# 10  {'spotify': 'https://open.spotify.com/album/4k...
# 11  {'spotify': 'https://open.spotify.com/album/0H...
# 12  {'spotify': 'https://open.spotify.com/album/00...
# 13  {'spotify': 'https://open.spotify.com/album/24...
# 14  {'spotify': 'https://open.spotify.com/album/65...
# 15  {'spotify': 'https://open.spotify.com/album/5s...
# 16  {'spotify': 'https://open.spotify.com/album/00...
# 17  {'spotify': 'https://open.spotify.com/album/10...
# 18  {'spotify': 'https://open.spotify.com/album/7H...
# 19  {'spotify': 'https://open.spotify.com/album/5P...
# 20  {'spotify': 'https://open.spotify.com/album/3M...
# 21  {'spotify': 'https://open.spotify.com/album/3g...
# 22  {'spotify': 'https://open.spotify.com/album/5f...
# 23  {'spotify': 'https://open.spotify.com/album/1k...
# 24  {'spotify': 'https://open.spotify.com/album/3W...
# 25  {'spotify': 'https://open.spotify.com/album/1B...
# 26  {'spotify': 'https://open.spotify.com/album/7d...
# 27  {'spotify': 'https://open.spotify.com/album/1r...
# 28  {'spotify': 'https://open.spotify.com/album/5g...
# 29  {'spotify': 'https://open.spotify.com/album/4Q...
# 30  {'spotify': 'https://open.spotify.com/album/66...
# 31  {'spotify': 'https://open.spotify.com/album/5A...
# 32  {'spotify': 'https://open.spotify.com/album/61...
# 33  {'spotify': 'https://open.spotify.com/album/1q...
# 34  {'spotify': 'https://open.spotify.com/album/5Y...
# 35  {'spotify': 'https://open.spotify.com/album/00...
# 36  {'spotify': 'https://open.spotify.com/album/6Z...
# 37  {'spotify': 'https://open.spotify.com/album/1T...
# 38  {'spotify': 'https://open.spotify.com/album/7d...
# 39  {'spotify': 'https://open.spotify.com/album/3r...
# 40  {'spotify': 'https://open.spotify.com/album/3r...
# 41  {'spotify': 'https://open.spotify.com/album/37...
# 42  {'spotify': 'https://open.spotify.com/album/35...
# 43  {'spotify': 'https://open.spotify.com/album/0c...
# 44  {'spotify': 'https://open.spotify.com/album/4f...
# 45  {'spotify': 'https://open.spotify.com/album/32...
# 46  {'spotify': 'https://open.spotify.com/album/00...
# 47  {'spotify': 'https://open.spotify.com/album/6l...
# 48  {'spotify': 'https://open.spotify.com/album/5b...
# 49  {'spotify': 'https://open.spotify.com/album/5A...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/albums/65T18oWoikW2...  65T18oWoikW2MAilg9j8lW
# 1   https://api.spotify.com/v1/albums/5eDB3cEFNX5W...  5eDB3cEFNX5W10auAjFPQk
# 2   https://api.spotify.com/v1/albums/0sbwoolm9aZG...  0sbwoolm9aZGBPBEqoU3CX
# 31  https://api.spotify.com/v1/albums/5A0jz6qj9yux...  5A0jz6qj9yuxVpQxahbC0x
# 32  https://api.spotify.com/v1/albums/61c5zqfBCSPO...  61c5zqfBCSPO1tb3DFbbFB
# 33  https://api.spotify.com/v1/albums/1qsQOC4Jn0fn...  1qsQOC4Jn0fnaUZLAbs4dz
# 34  https://api.spotify.com/v1/albums/5YCdlD3eREt7...  5YCdlD3eREt72lTZxNL7id
# 35  https://api.spotify.com/v1/albums/007DWn799UWv...  007DWn799UWvfY1wwZeENR
# 36  https://api.spotify.com/v1/albums/6ZvDJs17O3wo...  6ZvDJs17O3woQirttKRYCG
# 37  https://api.spotify.com/v1/albums/1TwCR17ZsRgW...  1TwCR17ZsRgWTo00mmlzqq
# 38  https://api.spotify.com/v1/albums/7dQ734EW0iLv...  7dQ734EW0iLvQfF6vBFNiZ
# 39  https://api.spotify.com/v1/albums/3r5hf3Cj3EMh...  3r5hf3Cj3EMh1C2saQ8jyt
# 40  https://api.spotify.com/v1/albums/3r5hf3Cj3EMh...  3r5hf3Cj3EMh1C2saQ8jyt
# 41  https://api.spotify.com/v1/albums/37PlDQrSCWOi...  37PlDQrSCWOiQlrA1AvUqx
# 42  https://api.spotify.com/v1/albums/35s58BRTGAEW...  35s58BRTGAEWztPo9WqCIs
# 43  https://api.spotify.com/v1/albums/0cJaDZsTnVdP...  0cJaDZsTnVdPISLCE57ZCd
# 44  https://api.spotify.com/v1/albums/4fLBtr12qHed...  4fLBtr12qHedCFEC8WOGoE
# 45  https://api.spotify.com/v1/albums/32uLGZoejiNF...  32uLGZoejiNFoqp8BvrogN
# 46  https://api.spotify.com/v1/albums/006lI9qEClLE...  006lI9qEClLEEax4Y4wx4L
# 47  https://api.spotify.com/v1/albums/6leaP5XOAiDx...  6leaP5XOAiDxj5tJsHI2F0
# 48  https://api.spotify.com/v1/albums/5b7TYeACzzjO...  5b7TYeACzzjO2oJHaB1Ebb
# 49  https://api.spotify.com/v1/albums/5AktdfKrkMov...  5AktdfKrkMovI4fu1UtmDR
#
#                                                images  \
# 0   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 5   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 6   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 7   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 8   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 9   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 10  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 11  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 12  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 13  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 14  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 15  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 16  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 17  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 18  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 19  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 20  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 21  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 22  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 23  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 24  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 25  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 26  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 27  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 28  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 29  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 30  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 31  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 32  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 33  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 34  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 35  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 36  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 37  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 38  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 39  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 40  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 41  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 42  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 43  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 44  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 45  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 46  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 47  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 48  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 49  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                                  name release_date  \
# 0                                   We Love You Tecca   2019-08-30
# 1                                            Io e lei   2019-04-05
# 2                                               VOICE   2019-05-13
# 3                                          Siren Song   2019-02-13
# 4                                            IT'z ICY   2019-07-29
# 5                                   20 Grandes Exitos   1980-01-01
# 6                                 Leña para el Carbón   2018-11-23
# 7                         Sin Culpa (feat. DrefQuila)   2018-12-07
# 8                                    Mala Mía (Remix)   2018-12-21
# 9          Los Campeones del Pueblo "The Big Leagues"   2018-12-14
# 10                                      A Solas Remix   2018-12-07
# 11                                             Dímelo   2018-05-08
# 12                                      Árabe (Remix)   2018-08-24
# 13                                      A Pura Sangre   1980-01-01
# 14                                   Los Más Queridos         2008
# 15                                        Sin Limites   2011-01-01
# 16                               Cauty VS Young Cauty   2018-12-07
# 17  Hitazos: Amores Como el Nuestro / Que Fue / Al...   2017-12-26
# 18                          Grandes Éxitos Regrabados   2017-12-29
# 19                                     Un Sentimiento   2005-11-04
# 20                          El Baile de las Egresadas   2018-12-24
# 21                                             LeBron   2019-01-01
# 22                               Un Homenaje Al Cielo   1980-01-01
# 23                              Pla Cacha Pla (Remix)   2018-12-25
# 24                                   Corazón Valiente   1980-01-01
# 25                                    No Es Tan Fácil   2017-10-10
# 26                 DJ ALEX - Asesina [Fiestero Remix]   2018-09-10
# 27                                La Pollera Amarilla   1992-11-12
# 28                                  20 Grandes Exitos         2005
# 29                                      Los Maleantes   2012-10-18
# 30                           Condenado Para El Millón   2018-11-03
# 31                                      El Bonaerense   2003-01-14
# 32                                            imagine   2018-12-14
# 33                                              SKINS   2018-12-07
# 34                dont smile at me (Expanded Edition)   2017-08-11
# 35                                       i am > i was   2018-12-21
# 36                                           Sick Boy   2018-12-14
# 37                                               Grip   2018-12-06
# 38                               FRIENDS KEEP SECRETS   2018-12-07
# 39                                         Hoodie SZN   2018-12-21
# 40                                         Hoodie SZN   2018-12-21
# 41                                       Icarus Falls   2018-12-13
# 42  Spider-Man: Into the Spider-Verse (Soundtrack ...   2018-12-14
# 43                             HaifischNikez Allstars   2018-12-28
# 44                                             Lelele   2018-12-20
# 45                                               Zoey   2018-12-14
# 46                                 MILLIONDOLLAR$MILE   2018-12-07
# 47                                             Farben   2018-12-14
# 48                      PARA ILLEGAL (feat. Lil Lano)   2018-12-07
# 49                                           Timeless   2017-07-26
#
#    release_date_precision  total_tracks   type  \
# 0                     day            17  album
# 1                     day             1  album
# 2                     day             6  album
# 3                     day             1  album
# 4                     day             5  album
# 5                     day            20  album
# 6                     day             1  album
# 7                     day             1  album
# 8                     day             1  album
# 9                     day            14  album
# 10                    day             1  album
# 11                    day             1  album
# 12                    day             1  album
# 13                    day            15  album
# 14                   year            12  album
# 15                    day            14  album
# 16                    day             4  album
# 17                    day             1  album
# 18                    day             7  album
# 19                    day            16  album
# 20                    day             1  album
# 21                    day             1  album
# 22                    day            12  album
# 23                    day             1  album
# 24                    day            12  album
# 25                    day            16  album
# 26                    day             1  album
# 27                    day            11  album
# 28                   year            20  album
# 29                    day            13  album
# 30                    day             1  album
# 31                    day            10  album
# 32                    day             1  album
# 33                    day            10  album
# 34                    day            11  album
# 35                    day            15  album
# 36                    day            10  album
# 37                    day             1  album
# 38                    day             7  album
# 39                    day            20  album
# 40                    day            20  album
# 41                    day            27  album
# 42                    day            13  album
# 43                    day             1  album
# 44                    day             1  album
# 45                    day             1  album
# 46                    day             1  album
# 47                    day             1  album
# 48                    day             1  album
# 49                    day            12  album
#
#                                      uri
# 0   spotify:album:65T18oWoikW2MAilg9j8lW
# 1   spotify:album:5eDB3cEFNX5W10auAjFPQk
# 2   spotify:album:0sbwoolm9aZGBPBEqoU3CX
# 3   spotify:album:1fK3kyhjoaQBDofh8Ppfjl
# 4   spotify:album:2y2Nuvvw5xNDYOunTSsgf1
# 5   spotify:album:2m6gFPx1GNwcVNsjNSPQ6C
# 6   spotify:album:1aEHMLU6feBBLGMPMNtZRH
# 7   spotify:album:1FvTfT61pqrVLvT0G6SZrI
# 8   spotify:album:2Vuq0IsELmGGmdoBqvgaYC
# 9   spotify:album:4zbMionGv9W33xjQfoMyuo
# 10  spotify:album:4kkZsCc8FiqMmq1sLBk6Na
# 11  spotify:album:0H6WiJAgs0D0bH8ObA7xBc
# 12  spotify:album:00pZdI6oi6NPc9rJsyB0Le
# 13  spotify:album:24UNJ5xGStzLSTCSaELuJi
# 14  spotify:album:65Z4VN8ZKEYkqM6K2yNoRl
# 15  spotify:album:5sWkzmy3eJNYFPcVcqlbl3
# 16  spotify:album:00op2xzUMjsxCj6aCmcnFJ
# 17  spotify:album:103gKD0qsWOSKEvgRnKjJi
# 18  spotify:album:7Hui8LAkH3zKpZMIztPYLr
# 19  spotify:album:5Pw7NFds3tRzOKWB0M1z03
# 20  spotify:album:3M6L2peQKmTxdvJpiB61Ku
# 21  spotify:album:3gMnERVCnd3UEDAieJkuRY
# 22  spotify:album:5fPNASmvNeT43QSYp6Asd2
# 23  spotify:album:1khWyuEDvHj907kCW4ZZQW
# 24  spotify:album:3WuwesFp1zHaIQa98Y3Fcn
# 25  spotify:album:1BtjQQmVRRs5m7AoBh81Xv
# 26  spotify:album:7d4fudNO8112vlsHMyFaEq
# 27  spotify:album:1r02rGE96IPnrhhcHbZdWE
# 28  spotify:album:5geMZxxpE1Sdb28KBGzblh
# 29  spotify:album:4Qjy0jhjBUFH1btd8lmg6Q
# 30  spotify:album:66rMML0MqFyPkNgL3n98qQ
# 31  spotify:album:5A0jz6qj9yuxVpQxahbC0x
# 32  spotify:album:61c5zqfBCSPO1tb3DFbbFB
# 33  spotify:album:1qsQOC4Jn0fnaUZLAbs4dz
# 34  spotify:album:5YCdlD3eREt72lTZxNL7id
# 35  spotify:album:007DWn799UWvfY1wwZeENR
# 36  spotify:album:6ZvDJs17O3woQirttKRYCG
# 37  spotify:album:1TwCR17ZsRgWTo00mmlzqq
# 38  spotify:album:7dQ734EW0iLvQfF6vBFNiZ
# 39  spotify:album:3r5hf3Cj3EMh1C2saQ8jyt
# 40  spotify:album:3r5hf3Cj3EMh1C2saQ8jyt
# 41  spotify:album:37PlDQrSCWOiQlrA1AvUqx
# 42  spotify:album:35s58BRTGAEWztPo9WqCIs
# 43  spotify:album:0cJaDZsTnVdPISLCE57ZCd
# 44  spotify:album:4fLBtr12qHedCFEC8WOGoE
# 45  spotify:album:32uLGZoejiNFoqp8BvrogN
# 46  spotify:album:006lI9qEClLEEax4Y4wx4L
# 47  spotify:album:6leaP5XOAiDxj5tJsHI2F0
# 48  spotify:album:5b7TYeACzzjO2oJHaB1Ebb
# 49  spotify:album:5AktdfKrkMovI4fu1UtmDR
# 2019 done
